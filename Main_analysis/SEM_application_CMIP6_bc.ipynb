# %% [markdown]
# Title: SEM_application_CMIP6_bc.ipynb
#
# Purpose: Apply the simple energy model to the bias corrected CMIP6 data
#
# Author: Onno Nennecke on 19.03.2025 Modified: 17.06.2025
#
# Input data:
#
# - Debiased CMIP6 Data
#     - This file lies here:
# - ERA5 Data
#     - This file lies here:
# - Capacity data
#     - This file lies here:
#
# Output data:
#
# - Timeseries of production, demand and RL
#     - This file lies here: f'/climca/people/onennecke/model_output/bias_corrected_masked_ibicus/full_year/{ESM}_{run}_timeseries.nc'

# %% [markdown]
# ### Load libraries and functions

# %%
# Importing libraries
import xarray as xr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import os
import glob
import time

# Importing functions
import Functions.wind_model_func as wind_model_func
import Functions.solar_model_func as solar_model_func
import Functions.demand as demand_func
import Functions.grid_func as grid_func
import Functions.config as config
# Out:
# /home/onennecke/.conda/envs/env_ma_on/lib/python3.12/site-packages/esmpy/interface/loadESMF.py:94: VersionWarning: ESMF installation version 8.8.0, ESMPy version 8.8.0b0
#   warnings.warn("ESMF installation version {}, ESMPy version {}".format(

# %% [markdown]
# Define variables (all in the config file)
#
#
# ```python
# Wind:
# - alpha_on = 1/7    # Roughness parameter onshore
# - alpha_off = 0.11  # Roughness parameter offshore
# - ref_height = 10   # Height of wind data
# - v_cutin = 3.5     # Minimum wind speed to start producing power
# - v_cutout = 25     # Maximum wind speed to produce power
# - v_rated = 13      # Wind speed at which the turbine produces maximum power
# - time_oper = 24    # operational time of hub [h/day]
# - Hub Height:
#     - # hub_height_on = 80    # Approximation: Onshore 80 m --> Bad Approximation --> Used own grid data instead
#     - # hub_height_off = 120  # Approximation: Offshore 120 m --> Bad Approximation --> Used own grid data instead
#
# Solar:
#
# - cT_c1 = 4.3       # constant [dC]
# - cT_c2 = 0.943     # constant [-]
# - cT_c3 = 0.028     # constant [dC m2 W-1]
# - cT_c4 = -1.528    # constant [dC s m-1]
# - gamma = -0.005    # constant [--]
# - temp_ref = 25     # reference temperature [dC]
# - gstc = 1000       # standard test conditions [W m-2]
# - shift_doy = 186   # if HadGEM : 180
# ```

# %% [markdown]
# ### Load datasets

# %%
# Load installed capacity data
grid_offshore = xr.open_dataset('/climca/people/onennecke/Wind_Solar_MaStR/processed_data/wind_offshore_ic.nc')
grid_offshore = grid_offshore['wind_off_cap']
mask_offshore = xr.where(np.isfinite(grid_offshore), 1, 0)
grid_onshore = xr.open_dataset('/climca/people/onennecke/Wind_Solar_MaStR/processed_data/wind_onshore_ic.nc')
grid_onshore = grid_onshore['wind_on_cap']
mask_onshore = xr.where(np.isfinite(grid_onshore), 1, 0)
grid_solar = xr.open_dataset('/climca/people/onennecke/Wind_Solar_MaStR/processed_data/solar_ic.nc')
grid_solar = grid_solar['solar_cap']
mask_solar = xr.where(np.isfinite(grid_solar), 1, 0)
population = xr.open_dataset('/climca/people/onennecke/population_data/population_regrid_weights.nc')
population = population['population']
mask_population = xr.where(np.isfinite(population), 1, 0)
# Overall mask
overall_mask = mask_offshore + mask_onshore + mask_solar + mask_population
overall_mask = xr.where(overall_mask > 0, 1, 0)

# %%
# Load wind height data
grid_onsh_hub_height = xr.open_dataset('/climca/people/onennecke/Wind_Solar_MaStR/processed_data/wind_onshore_height_weighted.nc')
grid_offsh_hub_height = xr.open_dataset('/climca/people/onennecke/Wind_Solar_MaStR/processed_data/wind_offshore_height_weighted.nc')

hub_height_on = grid_onsh_hub_height['wind_on_hub_height']
hub_height_off = grid_offsh_hub_height['wind_off_hub_height']

# %%
# Load regridded population weights data
pop_regr_CIESIN_weights = xr.open_dataset('/climca/people/onennecke/population_data/population_regrid_weights.nc')

# Load fit values from vdW Paper
demand_fit_values = xr.open_dataset('/climca/people/onennecke/population_data/demand_fit_values_week.nc')

# %% [markdown]
# ### Define used models

# %%
# Read the dataframe from the csv file
used_runs = pd.read_csv('/home/onennecke/CMIP_models/CMIP6_runs.csv')

# Change the ref column to 1 for the first instance of each model
used_runs['Ref'] = used_runs.groupby(['ESM', 'Institution']).cumcount().apply(lambda x: 1 if x == 0 else 0)

used_runs
# Out:
#             ESM   Institution        run  Ref
# 0    ACCESS-CM2  CSIRO-ARCCSS   r4i1p1f1    1
# 1    ACCESS-CM2  CSIRO-ARCCSS   r5i1p1f1    0
# 2    ACCESS-CM2  CSIRO-ARCCSS   r1i1p1f1    0
# 3   BCC-CSM2-MR           BCC   r1i1p1f1    1
# 4         CESM2          NCAR   r4i1p1f1    1
# ..          ...           ...        ...  ...
# 94  UKESM1-0-LL          MOHC   r3i1p1f2    0
# 95  UKESM1-0-LL          MOHC   r8i1p1f2    0
# 96  UKESM1-0-LL      NIMS-KMA  r15i1p1f2    1
# 97  UKESM1-0-LL      NIMS-KMA  r13i1p1f2    0
# 98  UKESM1-0-LL      NIMS-KMA  r14i1p1f2    0
#
# [99 rows x 4 columns]

# %%
# Load climate data

MIP = 'ScenarioMIP' # CMIP
scenario = 'ssp370'
# run = 'r1i1p1f1'
time_res = 'day'
variables = ['sfcWind', 'rsds', 'tas', 'tasmax'] # List of variables
grid_def = '*'
version = '*'

# %%
for i in range(len(used_runs)):
    run_time = time.time()
    ESM = used_runs['ESM'][i]
    Inst = used_runs['Institution'][i]
    run = used_runs['run'][i]
    print(f'Processing Run Nr. {i+1}, {ESM}, {Inst}, {run}, \n')
    base_path = '/climca/people/onennecke/debiased_data/'
    sel_run = glob.glob(os.path.join(base_path, f"{ESM}_{run}_*"))

    # now drop any psl files
    sel_run = [fn for fn in sel_run if '_psl_' not in os.path.basename(fn)]
    print(sel_run)
    combined_ds = xr.open_mfdataset(sel_run)
    combined_ds = combined_ds.assign_coords(run = run, ESM = ESM, ESM_run = f'{ESM}_{run}')
    # Filter to only winter months (October to March)
    # combined_ds = combined_ds.sel(time=combined_ds.time.dt.month.isin([10, 11, 12, 1, 2, 3]))
    
    combined_ds['tas'] = combined_ds['tas'] - 273.15 # Convert temperature from Kelvin to Celsius
    combined_ds['tasmax'] = combined_ds['tasmax'] - 273.15 # Convert maximum temperature from Kelvin to Celsius
    
    wepot_off = wind_model_func.compute_wind_energy_potential(combined_ds['sfcWind'], grid_offsh_hub_height, config.a_offshore, config.height_ref)
    wepot_on = wind_model_func.compute_wind_energy_potential(combined_ds['sfcWind'], grid_onsh_hub_height, config.a_onshore, config.height_ref)

    combined_ds['wind_off_pot'] = wepot_off['wind_off_pot']
    combined_ds['wind_on_pot'] = wepot_on['wind_on_pot']

    weprod_off = wind_model_func.compute_wind_energy_production(wepot_off, grid_offshore)
    weprod_on = wind_model_func.compute_wind_energy_production(wepot_on, grid_onshore)

    combined_ds['wind_off_prod'] = weprod_off['wind_off_prod']
    combined_ds['wind_on_prod'] = weprod_on['wind_on_prod']

    sepot = solar_model_func.compute_solar_energy_potential(combined_ds['rsds'], combined_ds['tas'], combined_ds['tasmax'], combined_ds['sfcWind'])

    # combined_ds['solar_pot'] = sepot['solar_pot'] 
    combined_ds['solar_pot'] = sepot

    seprod = solar_model_func.compute_solar_energy_production(sepot, grid_solar)

    # combined_ds['solar_prod'] = seprod['solar_prod']
    combined_ds['solar_prod'] = seprod


    # Calculate weighted sum
    weighted_temp_list = []
    for y in np.unique(combined_ds['tas']["time.year"].values):
        # print(y)
        ds_weigh_temp_0 = xr.Dataset()
        ds_weigh_temp_0['temp'] = (combined_ds['tas'].sel(time=str(y)) * pop_regr_CIESIN_weights['population']).sum(dim=['lat', 'lon'])
        weighted_temp_list.append(ds_weigh_temp_0)
        
    ds_weighted_temp = xr.concat(weighted_temp_list, dim="time") 

    # Calculate demand
    demand_ds = demand_func.compute_demand(ds_weighted_temp, demand_fit_values.sel(country = 9, period = 'week'))

    timeseries_ds = demand_ds.copy()

    # timeseries_ds['sfcWind_ntmsk'] = combined_ds['sfcWind'].mean(dim=['lat', 'lon'])
    # timeseries_ds['rsds_ntmsk'] = combined_ds['rsds'].mean(dim=['lat', 'lon'])
    # timeseries_ds['tas_ntmsk'] = combined_ds['tas'].mean(dim=['lat', 'lon'])
    # timeseries_ds['tasmax_ntmsk'] = combined_ds['tasmax'].mean(dim=['lat', 'lon'])
    timeseries_ds['sfcWind'] = combined_ds['sfcWind'].where(overall_mask == 1).mean(dim=['lat', 'lon'], skipna=True)
    timeseries_ds['rsds']    = combined_ds['rsds'].where(overall_mask == 1).mean(dim=['lat', 'lon'], skipna=True)
    timeseries_ds['tas']     = combined_ds['tas'].where(overall_mask == 1).mean(dim=['lat', 'lon'], skipna=True)
    timeseries_ds['tasmax']  = combined_ds['tasmax'].where(overall_mask == 1).mean(dim=['lat', 'lon'], skipna=True)

    timeseries_ds['wind_off_prod'] = combined_ds['wind_off_prod'].sum(dim=['lat', 'lon']) / 1000000
    timeseries_ds['wind_on_prod'] = combined_ds['wind_on_prod'].sum(dim=['lat', 'lon']) / 1000000
    timeseries_ds['solar_prod'] = combined_ds['solar_prod'].sum(dim=['lat', 'lon']) / 1000000

    timeseries_ds['total_prod'] = timeseries_ds['wind_off_prod'] + timeseries_ds['wind_on_prod'] + timeseries_ds['solar_prod']
    timeseries_ds['Netto'] = timeseries_ds['total_prod'] - timeseries_ds['demand']
    timeseries_ds['Residual_load'] = timeseries_ds['demand'] - timeseries_ds['total_prod']

    ts_output = timeseries_ds.assign_coords(run = run, ESM = ESM, ESM_run = f'{ESM}_{run}')
    ts_output.load()
    ts_output.to_netcdf(f'/climca/people/onennecke/model_output/bias_corrected_masked_ibicus/full_year/{ESM}_{run}_timeseries.nc')


    print('Run time: ', int(np.floor((time.time()  - run_time) / 60)),'m', round((time.time()  - run_time) % 60,1),'s')
    # break
# Out:
# Processing Run Nr. 1, ACCESS-CM2, CSIRO-ARCCSS, r4i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/ACCESS-CM2_r4i1p1f1_tas_debiased.nc', '/climca/people/onennecke/debiased_data/ACCESS-CM2_r4i1p1f1_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/ACCESS-CM2_r4i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/ACCESS-CM2_r4i1p1f1_tasmax_debiased.nc']
# Run time:  0 m 0.9 s
# Processing Run Nr. 2, ACCESS-CM2, CSIRO-ARCCSS, r5i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/ACCESS-CM2_r5i1p1f1_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/ACCESS-CM2_r5i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/ACCESS-CM2_r5i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/ACCESS-CM2_r5i1p1f1_tas_debiased.nc']
# Run time:  0 m 0.7 s
# Processing Run Nr. 3, ACCESS-CM2, CSIRO-ARCCSS, r1i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/ACCESS-CM2_r1i1p1f1_tas_debiased.nc', '/climca/people/onennecke/debiased_data/ACCESS-CM2_r1i1p1f1_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/ACCESS-CM2_r1i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/ACCESS-CM2_r1i1p1f1_tasmax_debiased.nc']
# Run time:  0 m 0.9 s
# Processing Run Nr. 4, BCC-CSM2-MR, BCC, r1i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/BCC-CSM2-MR_r1i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/BCC-CSM2-MR_r1i1p1f1_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/BCC-CSM2-MR_r1i1p1f1_tas_debiased.nc', '/climca/people/onennecke/debiased_data/BCC-CSM2-MR_r1i1p1f1_tasmax_debiased.nc']
# Run time:  0 m 0.7 s
# Processing Run Nr. 5, CESM2, NCAR, r4i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/CESM2_r4i1p1f1_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/CESM2_r4i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/CESM2_r4i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/CESM2_r4i1p1f1_tas_debiased.nc']
# Run time:  0 m 0.6 s
# Processing Run Nr. 6, CESM2, NCAR, r10i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/CESM2_r10i1p1f1_tas_debiased.nc', '/climca/people/onennecke/debiased_data/CESM2_r10i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/CESM2_r10i1p1f1_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/CESM2_r10i1p1f1_rsds_debiased.nc']
# Run time:  0 m 0.7 s
# Processing Run Nr. 7, CESM2, NCAR, r11i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/CESM2_r11i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/CESM2_r11i1p1f1_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/CESM2_r11i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/CESM2_r11i1p1f1_tas_debiased.nc']
# Run time:  0 m 0.6 s
# Processing Run Nr. 8, EC-Earth3, EC-Earth-Consortium, r149i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/EC-Earth3_r149i1p1f1_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r149i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r149i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r149i1p1f1_tas_debiased.nc']
# Run time:  0 m 0.7 s
# Processing Run Nr. 9, EC-Earth3, EC-Earth-Consortium, r4i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/EC-Earth3_r4i1p1f1_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r4i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r4i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r4i1p1f1_tas_debiased.nc']
# Run time:  0 m 0.7 s
# Processing Run Nr. 10, EC-Earth3, EC-Earth-Consortium, r148i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/EC-Earth3_r148i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r148i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r148i1p1f1_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r148i1p1f1_tas_debiased.nc']
# Run time:  0 m 0.9 s
# Processing Run Nr. 11, EC-Earth3, EC-Earth-Consortium, r105i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/EC-Earth3_r105i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r105i1p1f1_tas_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r105i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r105i1p1f1_sfcWind_debiased.nc']
# Run time:  0 m 0.7 s
# Processing Run Nr. 12, EC-Earth3, EC-Earth-Consortium, r134i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/EC-Earth3_r134i1p1f1_tas_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r134i1p1f1_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r134i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r134i1p1f1_tasmax_debiased.nc']
# Run time:  0 m 0.6 s
# Processing Run Nr. 13, EC-Earth3, EC-Earth-Consortium, r141i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/EC-Earth3_r141i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r141i1p1f1_tas_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r141i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r141i1p1f1_sfcWind_debiased.nc']
# Run time:  0 m 0.6 s
# Processing Run Nr. 14, EC-Earth3, EC-Earth-Consortium, r146i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/EC-Earth3_r146i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r146i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r146i1p1f1_tas_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r146i1p1f1_sfcWind_debiased.nc']
# Run time:  0 m 0.7 s
# Processing Run Nr. 15, EC-Earth3, EC-Earth-Consortium, r112i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/EC-Earth3_r112i1p1f1_tas_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r112i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r112i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r112i1p1f1_sfcWind_debiased.nc']
# Run time:  0 m 0.7 s
# Processing Run Nr. 16, EC-Earth3, EC-Earth-Consortium, r117i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/EC-Earth3_r117i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r117i1p1f1_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r117i1p1f1_tas_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r117i1p1f1_rsds_debiased.nc']
# Run time:  0 m 0.7 s
# Processing Run Nr. 17, EC-Earth3, EC-Earth-Consortium, r125i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/EC-Earth3_r125i1p1f1_tas_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r125i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r125i1p1f1_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r125i1p1f1_tasmax_debiased.nc']
# Run time:  0 m 0.7 s
# Processing Run Nr. 18, EC-Earth3, EC-Earth-Consortium, r113i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/EC-Earth3_r113i1p1f1_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r113i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r113i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r113i1p1f1_tas_debiased.nc']
# Run time:  0 m 0.7 s
# Processing Run Nr. 19, EC-Earth3, EC-Earth-Consortium, r106i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/EC-Earth3_r106i1p1f1_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r106i1p1f1_tas_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r106i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r106i1p1f1_rsds_debiased.nc']
# Run time:  0 m 0.6 s
# Processing Run Nr. 20, EC-Earth3, EC-Earth-Consortium, r138i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/EC-Earth3_r138i1p1f1_tas_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r138i1p1f1_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r138i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r138i1p1f1_rsds_debiased.nc']
# Run time:  0 m 0.6 s
# Processing Run Nr. 21, EC-Earth3, EC-Earth-Consortium, r5i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/EC-Earth3_r5i1p1f1_tas_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r5i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r5i1p1f1_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r5i1p1f1_rsds_debiased.nc']
# Run time:  0 m 0.6 s
# Processing Run Nr. 22, EC-Earth3, EC-Earth-Consortium, r137i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/EC-Earth3_r137i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r137i1p1f1_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r137i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r137i1p1f1_tas_debiased.nc']
# Run time:  0 m 0.9 s
# Processing Run Nr. 23, EC-Earth3, EC-Earth-Consortium, r145i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/EC-Earth3_r145i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r145i1p1f1_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r145i1p1f1_tas_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r145i1p1f1_rsds_debiased.nc']
# Run time:  0 m 0.9 s
# Processing Run Nr. 24, EC-Earth3, EC-Earth-Consortium, r114i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/EC-Earth3_r114i1p1f1_tas_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r114i1p1f1_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r114i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r114i1p1f1_rsds_debiased.nc']
# Run time:  0 m 0.8 s
# Processing Run Nr. 25, EC-Earth3, EC-Earth-Consortium, r120i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/EC-Earth3_r120i1p1f1_tas_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r120i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r120i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r120i1p1f1_sfcWind_debiased.nc']
# Run time:  0 m 0.7 s
# Processing Run Nr. 26, EC-Earth3, EC-Earth-Consortium, r128i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/EC-Earth3_r128i1p1f1_tas_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r128i1p1f1_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r128i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r128i1p1f1_tasmax_debiased.nc']
# Run time:  0 m 0.7 s
# Processing Run Nr. 27, EC-Earth3, EC-Earth-Consortium, r135i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/EC-Earth3_r135i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r135i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r135i1p1f1_tas_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r135i1p1f1_sfcWind_debiased.nc']
# Run time:  0 m 0.8 s
# Processing Run Nr. 28, EC-Earth3, EC-Earth-Consortium, r110i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/EC-Earth3_r110i1p1f1_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r110i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r110i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r110i1p1f1_tas_debiased.nc']
# Run time:  0 m 0.9 s
# Processing Run Nr. 29, EC-Earth3, EC-Earth-Consortium, r129i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/EC-Earth3_r129i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r129i1p1f1_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r129i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r129i1p1f1_tas_debiased.nc']
# Run time:  0 m 0.8 s
# Processing Run Nr. 30, EC-Earth3, EC-Earth-Consortium, r132i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/EC-Earth3_r132i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r132i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r132i1p1f1_tas_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r132i1p1f1_sfcWind_debiased.nc']
# Run time:  0 m 0.7 s
# Processing Run Nr. 31, EC-Earth3, EC-Earth-Consortium, r101i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/EC-Earth3_r101i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r101i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r101i1p1f1_tas_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r101i1p1f1_sfcWind_debiased.nc']
# Run time:  0 m 0.8 s
# Processing Run Nr. 32, EC-Earth3, EC-Earth-Consortium, r124i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/EC-Earth3_r124i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r124i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r124i1p1f1_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r124i1p1f1_tas_debiased.nc']
# Run time:  0 m 0.6 s
# Processing Run Nr. 33, EC-Earth3, EC-Earth-Consortium, r127i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/EC-Earth3_r127i1p1f1_tas_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r127i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r127i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r127i1p1f1_sfcWind_debiased.nc']
# Run time:  0 m 0.8 s
# Processing Run Nr. 34, EC-Earth3, EC-Earth-Consortium, r116i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/EC-Earth3_r116i1p1f1_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r116i1p1f1_tas_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r116i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r116i1p1f1_rsds_debiased.nc']
# Run time:  0 m 0.9 s
# Processing Run Nr. 35, EC-Earth3, EC-Earth-Consortium, r131i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/EC-Earth3_r131i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r131i1p1f1_tas_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r131i1p1f1_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r131i1p1f1_tasmax_debiased.nc']
# Run time:  0 m 0.6 s
# Processing Run Nr. 36, EC-Earth3, EC-Earth-Consortium, r121i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/EC-Earth3_r121i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r121i1p1f1_tas_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r121i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r121i1p1f1_sfcWind_debiased.nc']
# Run time:  0 m 0.6 s
# Processing Run Nr. 37, EC-Earth3, EC-Earth-Consortium, r142i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/EC-Earth3_r142i1p1f1_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r142i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r142i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r142i1p1f1_tas_debiased.nc']
# Run time:  0 m 0.6 s
# Processing Run Nr. 38, EC-Earth3, EC-Earth-Consortium, r102i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/EC-Earth3_r102i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r102i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r102i1p1f1_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r102i1p1f1_tas_debiased.nc']
# Run time:  0 m 0.6 s
# Processing Run Nr. 39, EC-Earth3, EC-Earth-Consortium, r133i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/EC-Earth3_r133i1p1f1_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r133i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r133i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r133i1p1f1_tas_debiased.nc']
# Run time:  0 m 0.6 s
# Processing Run Nr. 40, EC-Earth3, EC-Earth-Consortium, r111i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/EC-Earth3_r111i1p1f1_tas_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r111i1p1f1_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r111i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r111i1p1f1_tasmax_debiased.nc']
# Run time:  0 m 0.7 s
# Processing Run Nr. 41, EC-Earth3, EC-Earth-Consortium, r140i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/EC-Earth3_r140i1p1f1_tas_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r140i1p1f1_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r140i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r140i1p1f1_tasmax_debiased.nc']
# Run time:  0 m 0.6 s
# Processing Run Nr. 42, EC-Earth3, EC-Earth-Consortium, r136i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/EC-Earth3_r136i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r136i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r136i1p1f1_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r136i1p1f1_tas_debiased.nc']
# Run time:  0 m 0.6 s
# Processing Run Nr. 43, EC-Earth3, EC-Earth-Consortium, r108i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/EC-Earth3_r108i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r108i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r108i1p1f1_tas_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r108i1p1f1_sfcWind_debiased.nc']
# Run time:  0 m 0.6 s
# Processing Run Nr. 44, EC-Earth3, EC-Earth-Consortium, r130i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/EC-Earth3_r130i1p1f1_tas_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r130i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r130i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r130i1p1f1_sfcWind_debiased.nc']
# Run time:  0 m 0.9 s
# Processing Run Nr. 45, EC-Earth3, EC-Earth-Consortium, r150i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/EC-Earth3_r150i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r150i1p1f1_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r150i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r150i1p1f1_tas_debiased.nc']
# Run time:  0 m 0.6 s
# Processing Run Nr. 46, EC-Earth3, EC-Earth-Consortium, r104i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/EC-Earth3_r104i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r104i1p1f1_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r104i1p1f1_tas_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r104i1p1f1_rsds_debiased.nc']
# Run time:  0 m 0.6 s
# Processing Run Nr. 47, EC-Earth3, EC-Earth-Consortium, r118i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/EC-Earth3_r118i1p1f1_tas_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r118i1p1f1_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r118i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r118i1p1f1_rsds_debiased.nc']
# Run time:  0 m 0.8 s
# Processing Run Nr. 48, EC-Earth3, EC-Earth-Consortium, r109i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/EC-Earth3_r109i1p1f1_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r109i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r109i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r109i1p1f1_tas_debiased.nc']
# Run time:  0 m 0.7 s
# Processing Run Nr. 49, EC-Earth3, EC-Earth-Consortium, r143i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/EC-Earth3_r143i1p1f1_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r143i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r143i1p1f1_tas_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r143i1p1f1_rsds_debiased.nc']
# Run time:  0 m 0.6 s
# Processing Run Nr. 50, EC-Earth3, EC-Earth-Consortium, r147i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/EC-Earth3_r147i1p1f1_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r147i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r147i1p1f1_tas_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r147i1p1f1_rsds_debiased.nc']
# Run time:  0 m 0.7 s
# Processing Run Nr. 51, EC-Earth3, EC-Earth-Consortium, r126i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/EC-Earth3_r126i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r126i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r126i1p1f1_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r126i1p1f1_tas_debiased.nc']
# Run time:  0 m 0.6 s
# Processing Run Nr. 52, EC-Earth3, EC-Earth-Consortium, r119i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/EC-Earth3_r119i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r119i1p1f1_tas_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r119i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r119i1p1f1_sfcWind_debiased.nc']
# Run time:  0 m 0.6 s
# Processing Run Nr. 53, EC-Earth3, EC-Earth-Consortium, r1i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/EC-Earth3_r1i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r1i1p1f1_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r1i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r1i1p1f1_tas_debiased.nc']
# Run time:  0 m 0.5 s
# Processing Run Nr. 54, EC-Earth3, EC-Earth-Consortium, r123i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/EC-Earth3_r123i1p1f1_tas_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r123i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r123i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r123i1p1f1_sfcWind_debiased.nc']
# Run time:  0 m 0.7 s
# Processing Run Nr. 55, EC-Earth3, EC-Earth-Consortium, r122i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/EC-Earth3_r122i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r122i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r122i1p1f1_tas_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r122i1p1f1_sfcWind_debiased.nc']
# Run time:  0 m 0.7 s
# Processing Run Nr. 56, EC-Earth3, EC-Earth-Consortium, r115i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/EC-Earth3_r115i1p1f1_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r115i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r115i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r115i1p1f1_tas_debiased.nc']
# Run time:  0 m 0.8 s
# Processing Run Nr. 57, EC-Earth3, EC-Earth-Consortium, r103i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/EC-Earth3_r103i1p1f1_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r103i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r103i1p1f1_tas_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r103i1p1f1_tasmax_debiased.nc']
# Run time:  0 m 0.6 s
# Processing Run Nr. 58, EC-Earth3, EC-Earth-Consortium, r144i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/EC-Earth3_r144i1p1f1_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r144i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r144i1p1f1_tas_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r144i1p1f1_tasmax_debiased.nc']
# Run time:  0 m 0.6 s
# Processing Run Nr. 59, EC-Earth3, EC-Earth-Consortium, r139i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/EC-Earth3_r139i1p1f1_tas_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r139i1p1f1_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r139i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r139i1p1f1_rsds_debiased.nc']
# Run time:  0 m 0.5 s
# Processing Run Nr. 60, EC-Earth3, EC-Earth-Consortium, r107i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/EC-Earth3_r107i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r107i1p1f1_tas_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r107i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/EC-Earth3_r107i1p1f1_sfcWind_debiased.nc']
# Run time:  0 m 0.6 s
# Processing Run Nr. 61, GFDL-ESM4, NOAA-GFDL, r1i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/GFDL-ESM4_r1i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/GFDL-ESM4_r1i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/GFDL-ESM4_r1i1p1f1_tas_debiased.nc', '/climca/people/onennecke/debiased_data/GFDL-ESM4_r1i1p1f1_sfcWind_debiased.nc']
# Run time:  0 m 0.6 s
# Processing Run Nr. 62, KACE-1-0-G, NIMS-KMA, r2i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/KACE-1-0-G_r2i1p1f1_tas_debiased.nc', '/climca/people/onennecke/debiased_data/KACE-1-0-G_r2i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/KACE-1-0-G_r2i1p1f1_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/KACE-1-0-G_r2i1p1f1_tasmax_debiased.nc']
# Run time:  0 m 0.7 s
# Processing Run Nr. 63, KACE-1-0-G, NIMS-KMA, r3i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/KACE-1-0-G_r3i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/KACE-1-0-G_r3i1p1f1_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/KACE-1-0-G_r3i1p1f1_tas_debiased.nc', '/climca/people/onennecke/debiased_data/KACE-1-0-G_r3i1p1f1_tasmax_debiased.nc']
# Run time:  0 m 0.9 s
# Processing Run Nr. 64, KACE-1-0-G, NIMS-KMA, r1i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/KACE-1-0-G_r1i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/KACE-1-0-G_r1i1p1f1_tas_debiased.nc', '/climca/people/onennecke/debiased_data/KACE-1-0-G_r1i1p1f1_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/KACE-1-0-G_r1i1p1f1_rsds_debiased.nc']
# Run time:  0 m 0.7 s
# Processing Run Nr. 65, MPI-ESM1-2-HR, DKRZ, r6i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/MPI-ESM1-2-HR_r6i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/MPI-ESM1-2-HR_r6i1p1f1_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/MPI-ESM1-2-HR_r6i1p1f1_tas_debiased.nc', '/climca/people/onennecke/debiased_data/MPI-ESM1-2-HR_r6i1p1f1_tasmax_debiased.nc']
# Run time:  0 m 0.6 s
# Processing Run Nr. 66, MPI-ESM1-2-HR, DKRZ, r4i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/MPI-ESM1-2-HR_r4i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/MPI-ESM1-2-HR_r4i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/MPI-ESM1-2-HR_r4i1p1f1_tas_debiased.nc', '/climca/people/onennecke/debiased_data/MPI-ESM1-2-HR_r4i1p1f1_sfcWind_debiased.nc']
# Run time:  0 m 0.8 s
# Processing Run Nr. 67, MPI-ESM1-2-HR, DKRZ, r9i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/MPI-ESM1-2-HR_r9i1p1f1_tas_debiased.nc', '/climca/people/onennecke/debiased_data/MPI-ESM1-2-HR_r9i1p1f1_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/MPI-ESM1-2-HR_r9i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/MPI-ESM1-2-HR_r9i1p1f1_tasmax_debiased.nc']
# Run time:  0 m 0.7 s
# Processing Run Nr. 68, MPI-ESM1-2-HR, DKRZ, r10i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/MPI-ESM1-2-HR_r10i1p1f1_tas_debiased.nc', '/climca/people/onennecke/debiased_data/MPI-ESM1-2-HR_r10i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/MPI-ESM1-2-HR_r10i1p1f1_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/MPI-ESM1-2-HR_r10i1p1f1_tasmax_debiased.nc']
# Run time:  0 m 0.6 s
# Processing Run Nr. 69, MPI-ESM1-2-HR, DKRZ, r5i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/MPI-ESM1-2-HR_r5i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/MPI-ESM1-2-HR_r5i1p1f1_tas_debiased.nc', '/climca/people/onennecke/debiased_data/MPI-ESM1-2-HR_r5i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/MPI-ESM1-2-HR_r5i1p1f1_sfcWind_debiased.nc']
# Run time:  0 m 0.9 s
# Processing Run Nr. 70, MPI-ESM1-2-HR, DKRZ, r8i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/MPI-ESM1-2-HR_r8i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/MPI-ESM1-2-HR_r8i1p1f1_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/MPI-ESM1-2-HR_r8i1p1f1_tas_debiased.nc', '/climca/people/onennecke/debiased_data/MPI-ESM1-2-HR_r8i1p1f1_rsds_debiased.nc']
# Run time:  0 m 0.9 s
# Processing Run Nr. 71, MPI-ESM1-2-HR, DKRZ, r2i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/MPI-ESM1-2-HR_r2i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/MPI-ESM1-2-HR_r2i1p1f1_tas_debiased.nc', '/climca/people/onennecke/debiased_data/MPI-ESM1-2-HR_r2i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/MPI-ESM1-2-HR_r2i1p1f1_sfcWind_debiased.nc']
# Run time:  0 m 0.7 s
# Processing Run Nr. 72, MPI-ESM1-2-HR, DKRZ, r7i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/MPI-ESM1-2-HR_r7i1p1f1_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/MPI-ESM1-2-HR_r7i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/MPI-ESM1-2-HR_r7i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/MPI-ESM1-2-HR_r7i1p1f1_tas_debiased.nc']
# Run time:  0 m 0.6 s
# Processing Run Nr. 73, MPI-ESM1-2-HR, DKRZ, r3i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/MPI-ESM1-2-HR_r3i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/MPI-ESM1-2-HR_r3i1p1f1_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/MPI-ESM1-2-HR_r3i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/MPI-ESM1-2-HR_r3i1p1f1_tas_debiased.nc']
# Run time:  0 m 0.7 s
# Processing Run Nr. 74, MPI-ESM1-2-HR, DKRZ, r1i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/MPI-ESM1-2-HR_r1i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/MPI-ESM1-2-HR_r1i1p1f1_tas_debiased.nc', '/climca/people/onennecke/debiased_data/MPI-ESM1-2-HR_r1i1p1f1_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/MPI-ESM1-2-HR_r1i1p1f1_rsds_debiased.nc']
# Run time:  0 m 0.6 s
# Processing Run Nr. 75, MRI-ESM2-0, MRI, r4i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/MRI-ESM2-0_r4i1p1f1_tas_debiased.nc', '/climca/people/onennecke/debiased_data/MRI-ESM2-0_r4i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/MRI-ESM2-0_r4i1p1f1_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/MRI-ESM2-0_r4i1p1f1_tasmax_debiased.nc']
# Run time:  0 m 0.6 s
# Processing Run Nr. 76, MRI-ESM2-0, MRI, r5i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/MRI-ESM2-0_r5i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/MRI-ESM2-0_r5i1p1f1_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/MRI-ESM2-0_r5i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/MRI-ESM2-0_r5i1p1f1_tas_debiased.nc']
# Run time:  0 m 0.6 s
# Processing Run Nr. 77, MRI-ESM2-0, MRI, r2i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/MRI-ESM2-0_r2i1p1f1_tas_debiased.nc', '/climca/people/onennecke/debiased_data/MRI-ESM2-0_r2i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/MRI-ESM2-0_r2i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/MRI-ESM2-0_r2i1p1f1_sfcWind_debiased.nc']
# Run time:  0 m 0.6 s
# Processing Run Nr. 78, MRI-ESM2-0, MRI, r3i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/MRI-ESM2-0_r3i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/MRI-ESM2-0_r3i1p1f1_tas_debiased.nc', '/climca/people/onennecke/debiased_data/MRI-ESM2-0_r3i1p1f1_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/MRI-ESM2-0_r3i1p1f1_tasmax_debiased.nc']
# Run time:  0 m 0.6 s
# Processing Run Nr. 79, MRI-ESM2-0, MRI, r1i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/MRI-ESM2-0_r1i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/MRI-ESM2-0_r1i1p1f1_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/MRI-ESM2-0_r1i1p1f1_tas_debiased.nc', '/climca/people/onennecke/debiased_data/MRI-ESM2-0_r1i1p1f1_sfcWind_debiased.nc']
# Run time:  0 m 0.7 s
# Processing Run Nr. 80, TaiESM1, AS-RCEC, r1i1p1f1,
#
# ['/climca/people/onennecke/debiased_data/TaiESM1_r1i1p1f1_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/TaiESM1_r1i1p1f1_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/TaiESM1_r1i1p1f1_tas_debiased.nc', '/climca/people/onennecke/debiased_data/TaiESM1_r1i1p1f1_rsds_debiased.nc']
# Run time:  0 m 0.6 s
# Processing Run Nr. 81, UKESM1-0-LL, MOHC, r4i1p1f2,
#
# ['/climca/people/onennecke/debiased_data/UKESM1-0-LL_r4i1p1f2_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/UKESM1-0-LL_r4i1p1f2_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/UKESM1-0-LL_r4i1p1f2_tas_debiased.nc', '/climca/people/onennecke/debiased_data/UKESM1-0-LL_r4i1p1f2_sfcWind_debiased.nc']
# Run time:  0 m 0.7 s
# Processing Run Nr. 82, UKESM1-0-LL, MOHC, r19i1p1f2,
#
# ['/climca/people/onennecke/debiased_data/UKESM1-0-LL_r19i1p1f2_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/UKESM1-0-LL_r19i1p1f2_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/UKESM1-0-LL_r19i1p1f2_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/UKESM1-0-LL_r19i1p1f2_tas_debiased.nc']
# Run time:  0 m 1.0 s
# Processing Run Nr. 83, UKESM1-0-LL, MOHC, r12i1p1f2,
#
# ['/climca/people/onennecke/debiased_data/UKESM1-0-LL_r12i1p1f2_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/UKESM1-0-LL_r12i1p1f2_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/UKESM1-0-LL_r12i1p1f2_tas_debiased.nc', '/climca/people/onennecke/debiased_data/UKESM1-0-LL_r12i1p1f2_rsds_debiased.nc']
# Run time:  0 m 0.6 s
# Processing Run Nr. 84, UKESM1-0-LL, MOHC, r1i1p1f2,
#
# ['/climca/people/onennecke/debiased_data/UKESM1-0-LL_r1i1p1f2_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/UKESM1-0-LL_r1i1p1f2_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/UKESM1-0-LL_r1i1p1f2_tas_debiased.nc', '/climca/people/onennecke/debiased_data/UKESM1-0-LL_r1i1p1f2_sfcWind_debiased.nc']
# Run time:  0 m 0.6 s
# Processing Run Nr. 85, UKESM1-0-LL, MOHC, r18i1p1f2,
#
# ['/climca/people/onennecke/debiased_data/UKESM1-0-LL_r18i1p1f2_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/UKESM1-0-LL_r18i1p1f2_tas_debiased.nc', '/climca/people/onennecke/debiased_data/UKESM1-0-LL_r18i1p1f2_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/UKESM1-0-LL_r18i1p1f2_tasmax_debiased.nc']
# Run time:  0 m 0.6 s
# Processing Run Nr. 86, UKESM1-0-LL, MOHC, r16i1p1f2,
#
# ['/climca/people/onennecke/debiased_data/UKESM1-0-LL_r16i1p1f2_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/UKESM1-0-LL_r16i1p1f2_tas_debiased.nc', '/climca/people/onennecke/debiased_data/UKESM1-0-LL_r16i1p1f2_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/UKESM1-0-LL_r16i1p1f2_rsds_debiased.nc']
# Run time:  0 m 0.7 s
# Processing Run Nr. 87, UKESM1-0-LL, MOHC, r9i1p1f2,
#
# ['/climca/people/onennecke/debiased_data/UKESM1-0-LL_r9i1p1f2_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/UKESM1-0-LL_r9i1p1f2_tas_debiased.nc', '/climca/people/onennecke/debiased_data/UKESM1-0-LL_r9i1p1f2_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/UKESM1-0-LL_r9i1p1f2_rsds_debiased.nc']
# Run time:  0 m 0.8 s
# Processing Run Nr. 88, UKESM1-0-LL, MOHC, r7i1p1f2,
#
# ['/climca/people/onennecke/debiased_data/UKESM1-0-LL_r7i1p1f2_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/UKESM1-0-LL_r7i1p1f2_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/UKESM1-0-LL_r7i1p1f2_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/UKESM1-0-LL_r7i1p1f2_tas_debiased.nc']
# Run time:  0 m 0.6 s
# Processing Run Nr. 89, UKESM1-0-LL, MOHC, r11i1p1f2,
#
# ['/climca/people/onennecke/debiased_data/UKESM1-0-LL_r11i1p1f2_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/UKESM1-0-LL_r11i1p1f2_tas_debiased.nc', '/climca/people/onennecke/debiased_data/UKESM1-0-LL_r11i1p1f2_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/UKESM1-0-LL_r11i1p1f2_tasmax_debiased.nc']
# Run time:  0 m 0.5 s
# Processing Run Nr. 90, UKESM1-0-LL, MOHC, r6i1p1f2,
#
# ['/climca/people/onennecke/debiased_data/UKESM1-0-LL_r6i1p1f2_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/UKESM1-0-LL_r6i1p1f2_tas_debiased.nc', '/climca/people/onennecke/debiased_data/UKESM1-0-LL_r6i1p1f2_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/UKESM1-0-LL_r6i1p1f2_tasmax_debiased.nc']
# Run time:  0 m 0.5 s
# Processing Run Nr. 91, UKESM1-0-LL, MOHC, r2i1p1f2,
#
# ['/climca/people/onennecke/debiased_data/UKESM1-0-LL_r2i1p1f2_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/UKESM1-0-LL_r2i1p1f2_tas_debiased.nc', '/climca/people/onennecke/debiased_data/UKESM1-0-LL_r2i1p1f2_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/UKESM1-0-LL_r2i1p1f2_rsds_debiased.nc']
# Run time:  0 m 0.5 s
# Processing Run Nr. 92, UKESM1-0-LL, MOHC, r10i1p1f2,
#
# ['/climca/people/onennecke/debiased_data/UKESM1-0-LL_r10i1p1f2_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/UKESM1-0-LL_r10i1p1f2_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/UKESM1-0-LL_r10i1p1f2_tas_debiased.nc', '/climca/people/onennecke/debiased_data/UKESM1-0-LL_r10i1p1f2_tasmax_debiased.nc']
# Run time:  0 m 0.6 s
# Processing Run Nr. 93, UKESM1-0-LL, MOHC, r17i1p1f2,
#
# ['/climca/people/onennecke/debiased_data/UKESM1-0-LL_r17i1p1f2_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/UKESM1-0-LL_r17i1p1f2_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/UKESM1-0-LL_r17i1p1f2_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/UKESM1-0-LL_r17i1p1f2_tas_debiased.nc']
# Run time:  0 m 0.5 s
# Processing Run Nr. 94, UKESM1-0-LL, MOHC, r5i1p1f2,
#
# ['/climca/people/onennecke/debiased_data/UKESM1-0-LL_r5i1p1f2_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/UKESM1-0-LL_r5i1p1f2_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/UKESM1-0-LL_r5i1p1f2_tas_debiased.nc', '/climca/people/onennecke/debiased_data/UKESM1-0-LL_r5i1p1f2_sfcWind_debiased.nc']
# Run time:  0 m 0.8 s
# Processing Run Nr. 95, UKESM1-0-LL, MOHC, r3i1p1f2,
#
# ['/climca/people/onennecke/debiased_data/UKESM1-0-LL_r3i1p1f2_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/UKESM1-0-LL_r3i1p1f2_tas_debiased.nc', '/climca/people/onennecke/debiased_data/UKESM1-0-LL_r3i1p1f2_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/UKESM1-0-LL_r3i1p1f2_tasmax_debiased.nc']
# Run time:  0 m 0.8 s
# Processing Run Nr. 96, UKESM1-0-LL, MOHC, r8i1p1f2,
#
# ['/climca/people/onennecke/debiased_data/UKESM1-0-LL_r8i1p1f2_rsds_debiased.nc', '/climca/people/onennecke/debiased_data/UKESM1-0-LL_r8i1p1f2_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/UKESM1-0-LL_r8i1p1f2_tas_debiased.nc', '/climca/people/onennecke/debiased_data/UKESM1-0-LL_r8i1p1f2_sfcWind_debiased.nc']
# Run time:  0 m 0.5 s
# Processing Run Nr. 97, UKESM1-0-LL, NIMS-KMA, r15i1p1f2,
#
# ['/climca/people/onennecke/debiased_data/UKESM1-0-LL_r15i1p1f2_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/UKESM1-0-LL_r15i1p1f2_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/UKESM1-0-LL_r15i1p1f2_tas_debiased.nc', '/climca/people/onennecke/debiased_data/UKESM1-0-LL_r15i1p1f2_rsds_debiased.nc']
# Run time:  0 m 0.7 s
# Processing Run Nr. 98, UKESM1-0-LL, NIMS-KMA, r13i1p1f2,
#
# ['/climca/people/onennecke/debiased_data/UKESM1-0-LL_r13i1p1f2_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/UKESM1-0-LL_r13i1p1f2_tas_debiased.nc', '/climca/people/onennecke/debiased_data/UKESM1-0-LL_r13i1p1f2_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/UKESM1-0-LL_r13i1p1f2_rsds_debiased.nc']
# Run time:  0 m 0.6 s
# Processing Run Nr. 99, UKESM1-0-LL, NIMS-KMA, r14i1p1f2,
#
# ['/climca/people/onennecke/debiased_data/UKESM1-0-LL_r14i1p1f2_tasmax_debiased.nc', '/climca/people/onennecke/debiased_data/UKESM1-0-LL_r14i1p1f2_tas_debiased.nc', '/climca/people/onennecke/debiased_data/UKESM1-0-LL_r14i1p1f2_sfcWind_debiased.nc', '/climca/people/onennecke/debiased_data/UKESM1-0-LL_r14i1p1f2_rsds_debiased.nc']
# Run time:  0 m 0.8 s

# %%
ts_output
# Out:
# <xarray.Dataset> Size: 321kB
# Dimensions:        (time: 3650)
# Coordinates:
#     crs            int64 8B 4326
#     gridtype       <U6 24B 'lonlat'
#   * time           (time) datetime64[ns] 29kB 2015-01-01 ... 2024-12-31
#     ESM            <U11 44B 'UKESM1-0-LL'
#     run            <U9 36B 'r14i1p1f2'
#     ESM_run        <U21 84B 'UKESM1-0-LL_r14i1p1f2'
#     country        float64 8B 9.0
#     period         <U7 28B 'week'
# Data variables:
#     temp           (time) float64 29kB 9.619 8.733 8.419 ... 7.274 7.952 7.756
#     demand         (time) float64 29kB 1.398e+03 1.41e+03 ... 1.42e+03 1.423e+03
#     sfcWind        (time) float32 15kB 8.011 7.988 9.575 ... 5.677 6.304 5.872
#     rsds           (time) float32 15kB 16.18 17.19 20.82 ... 22.64 21.91 23.93
#     tas            (time) float32 15kB 8.921 8.236 7.877 ... 6.94 7.408 7.349
#     tasmax         (time) float32 15kB 8.79 7.457 7.033 ... 5.436 5.82 5.85
#     wind_off_prod  (time) float64 29kB 191.2 205.6 212.8 ... 150.0 215.1 210.7
#     wind_on_prod   (time) float64 29kB 1.12e+03 1.101e+03 ... 666.3 507.7
#     solar_prod     (time) float64 29kB 46.33 41.71 57.3 ... 70.07 54.82 61.78
#     total_prod     (time) float64 29kB 1.358e+03 1.348e+03 ... 936.2 780.2
#     Netto          (time) float64 29kB -40.14 -61.74 307.7 ... -483.8 -642.4
#     Residual_load  (time) float64 29kB 40.14 61.74 -307.7 ... 882.0 483.8 642.4

# %% [markdown]
# #### Some plots to check everything is alright

# %%
def setup_gridlines(ax, deg = 1, alpha = 0.4):
    gl = ax.gridlines(draw_labels=True, crs=ccrs.PlateCarree(), alpha=alpha)
    gl.top_labels = False
    gl.right_labels = False
    gl.xlabel_style = {'size': 8}
    gl.ylabel_style = {'size': 8}
    gl.xformatter = LONGITUDE_FORMATTER
    gl.yformatter = LATITUDE_FORMATTER
    gl.xlocator = MultipleLocator(deg)
    gl.ylocator = MultipleLocator(deg)

# %%
# Just a plot of one timestep of the wind and the approximated on- and offshore wind power capacity

lon_edges = combined_ds['lon'].values
lat_edges = combined_ds['lat'].values

vmin = 0 
vmax = 1

# Plot the data
timestep = 201

fig, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3, figsize=(9, 6), subplot_kw={'projection': ccrs.Robinson()})

# First subplot
ax1.coastlines()
ax1.add_feature(cfeature.BORDERS, linestyle=':', edgecolor='black')
xxx1 = combined_ds['sfcWind'].isel(time=timestep)
im1 = ax1.pcolormesh(lon_edges, lat_edges, xxx1, transform=ccrs.PlateCarree(), cmap='Reds', vmin=vmin)
setup_gridlines(ax1)
cbar1 = fig.colorbar(im1, ax=ax1, orientation='horizontal', pad=0.05, shrink=0.7, aspect=50)
ax1.set_title('Surface Wind in m/s')

# Second subplot
ax2.coastlines()
ax2.add_feature(cfeature.BORDERS, linestyle=':', edgecolor='black')
xxx2 = wepot_off['wind_off_pot'].isel(time=timestep)
im2 = ax2.pcolormesh(lon_edges, lat_edges, xxx2, transform=ccrs.PlateCarree(), cmap='Reds', vmin=vmin, vmax=vmax)
setup_gridlines(ax2)
cbar2 = fig.colorbar(im2, ax=ax2, orientation='horizontal', pad=0.05, shrink=0.7, aspect=50)
ax2.set_title('Approximated Wind Power Capacity')

# Third subplot
ax3.coastlines()
ax3.add_feature(cfeature.BORDERS, linestyle=':', edgecolor='black')
xxx3 = wepot_on['wind_on_pot'].isel(time=timestep)
im3 = ax3.pcolormesh(lon_edges, lat_edges, xxx3, transform=ccrs.PlateCarree(), cmap='Reds', vmin=vmin, vmax=vmax)
setup_gridlines(ax3)
cbar3 = fig.colorbar(im3, ax=ax3, orientation='horizontal', pad=0.05, shrink=0.7, aspect=50)
ax3.set_title('Approximated Wind Power Capacity')


plt.tight_layout()
plt.show()

# %%
# Just a plot of one timestep of the solar radiation and the approximated solar power capacity
# Filter sepot so only the grids with pv data are left (mainly for plotting)
sepot_plot = sepot.where(grid_solar > 0)

# '''
lon_edges = combined_ds['lon'].values # - (combined_ds['lon'].lon.diff(dim='lon') / 2).pad({'lon': (1, 0)}, mode='edge')
lat_edges = combined_ds['lat'].values # - (combined_ds['lat'].lat.diff(dim='lat') / 2).pad({'lat': (1, 0)}, mode='edge')

vmin = 0 
vmax = 1

# Plot the data
timestep = 90# 29937# 1# 10000 # 24507

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 6), subplot_kw={'projection': ccrs.Robinson()})

# First subplot
ax1.coastlines()
ax1.add_feature(cfeature.BORDERS, linestyle=':', edgecolor='black')
xxx1 = combined_ds['rsds'].isel(time=timestep)
im1 = ax1.pcolormesh(lon_edges, lat_edges, xxx1, transform=ccrs.PlateCarree(), cmap='Reds', vmin=vmin)
setup_gridlines(ax1)
cbar1 = fig.colorbar(im1, ax=ax1, orientation='horizontal', pad=0.05, shrink=0.7, aspect=50)
ax1.set_title('Downward Short-Wave Radiation in W/m^2')

# Second subplot
ax2.coastlines()
ax2.add_feature(cfeature.BORDERS, linestyle=':', edgecolor='black')
xxx2 = sepot_plot.isel(time=timestep)
im2 = ax2.pcolormesh(lon_edges, lat_edges, xxx2, transform=ccrs.PlateCarree(), cmap='Reds', vmin=vmin, vmax=vmax)
setup_gridlines(ax2)
cbar2 = fig.colorbar(im2, ax=ax2, orientation='horizontal', pad=0.05, shrink=0.7, aspect=50)
ax2.set_title('Approximated Solar Power Capacity')

plt.tight_layout()
plt.show()
# '''

# %%
demand_ds['demand'][0:365].plot()

# %%
# Plot time series (time against temp and demand)
fig, ax1 = plt.subplots(figsize=(12, 6))

a = 0
b = 364

# Plot temperature on the first y-axis
ax1.plot(demand_ds['time'][a:b], demand_ds['temp'][a:b], label='Temperature', color='r')
ax1.set_ylabel('Temperature [°C]', color='r')
ax1.set_xlabel('Time')
ax1.tick_params(axis='y', labelcolor='r')

# Create a second y-axis to plot demand
ax2 = ax1.twinx()
ax2.plot(demand_ds['time'][a:b], demand_ds['demand'][a:b], label='Demand', color='b')
ax2.set_ylabel('Demand [GWh]', color='b')
ax2.tick_params(axis='y', labelcolor='b')
# ax2.set_ylim(1000, 2200)  # Adjust y-axis limits for demand

fig.tight_layout()
plt.show()

# %%
demand_ds['demand'].values[0:10]
# Out:
# array([1397.87993044, 1409.75886848, 1413.91648094, 1428.88655661,
#        1444.25298221, 1453.48779958, 1457.92154402, 1461.75958284,
#        1454.51339465, 1471.96461925])

# %%
# Define your slice (adjust these to your desired time range)
# a = 191 + 365 * 81
# b = 7 + 365 * 82
# a = 365 * 164
# b = 365 * 165
a = 0
b = 364
# a = 365
# b = 365 * 2

# Extract time and variables for the chosen range
time = timeseries_ds['time'][a:b]
demand = timeseries_ds['demand'][a:b]
wind_off = timeseries_ds['wind_off_prod'][a:b]
wind_on = timeseries_ds['wind_on_prod'][a:b]
solar = timeseries_ds['solar_prod'][a:b]
total_prod = timeseries_ds['total_prod'][a:b]
Residual_load = timeseries_ds['Residual_load'][a:b]

# Create the figure and axis
fig, ax = plt.subplots(figsize=(12, 6))

# Plot each variable
ax.plot(time, demand, label='Demand', color='b')
ax.plot(time, wind_off, label='Offshore Wind Production', color='g')
ax.plot(time, wind_on, label='Onshore Wind Production', color='c')
ax.plot(time, solar, label='Solar Production', color='y')
ax.plot(time, total_prod, label='Total Production', color='purple')
ax.plot(time, Residual_load, label='Residual_load', color='r')

# Labeling
ax.set_xlabel('')
ax.set_ylabel('Energy (GWh)')
ax.set_title('Time Series Plot')
ax.legend()

# Formatting
fig.tight_layout()
plt.grid(True)
plt.show()
