# %% [markdown]
# Title: SEM_application_with_CESM2LE_39_48.ipynb
#
# Purpose: Apply the simple energy model to the preprocessed CMIP6 data with warming level of 2K in comparison to preindustrial levels
#
# Author: Onno Nennecke on 19.03.2025 Modified: 20.02.2026
#
# Input data:
#
# - Preprocessed CMIP6 Data
#     - This file lies here: '/climca/people/onennecke/not_debiased_data/'
# - Preprocessed ERA5 Data
#     - This file lies here: '/climca/people/onennecke/not_debiased_data/'
# - Installed capacity grids: wind_offshore_ic.nc, wind_onshore_ic.nc, solar_ic_netto.nc
#     - These files lie here: /climca/people/onennecke/Wind_Solar_MaStR/processed_data/
# - Wind hub height grids: wind_offshore_height_weighted.nc, wind_onshore_height_weighted.nc
#     - These files lie here: /climca/people/onennecke/Wind_Solar_MaStR/processed_data/
# - Regridded population data: population_regrid_weights.nc
#     - This file lies here: /climca/people/onennecke/population_data/
# - Fit values from vdW Paper: demand_fit_values_week.nc
#     - This file lies here: /climca/people/onennecke/population_data/
#
# Output data:
#
# - Timeseries of production, demand and RL
#     - This file lies here: f'/climca/people/onennecke/model_output/not_bias_corrected/full_year/{ESM}_{run}_timeseries.nc'
#     - Bias corrected (Not used): (This file lies here: f'/climca/people/onennecke/model_output/bias_corrected_masked_ibicus/full_year/{ESM}_{run}_timeseries.nc')

# %% [markdown]
# ### Load libraries and functions

# %%
# Importing libraries
import xarray as xr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import os
import glob
import time

# Importing functions
import Functions.wind_model_func as wind_model_func
import Functions.solar_model_func as solar_model_func
import Functions.demand as demand_func
import Functions.grid_func as grid_func
import Functions.config as config
# Out:
# /home/onennecke/.conda/envs/env_ma_on/lib/python3.12/site-packages/esmpy/interface/loadESMF.py:94: VersionWarning: ESMF installation version 8.8.0, ESMPy version 8.8.0b0
#   warnings.warn("ESMF installation version {}, ESMPy version {}".format(

# %% [markdown]
# Define variables (all in the config file)
#
#
# ```python
# Wind:
# - alpha_on = 1/7    # Roughness parameter onshore
# - alpha_off = 0.11  # Roughness parameter offshore
# - ref_height = 100   # Height of wind data
# - v_cutin = 3.5     # Minimum wind speed to start producing power
# - v_cutout = 25     # Maximum wind speed to produce power
# - v_rated = 13      # Wind speed at which the turbine produces maximum power
# - time_oper = 24    # operational time of hub [h/day]
# - Hub Height:
#     - # hub_height_on = 80    # Approximation: Onshore 80 m --> Bad Approximation --> Used own grid data instead
#     - # hub_height_off = 120  # Approximation: Offshore 120 m --> Bad Approximation --> Used own grid data instead
#
# Solar:
#
# - cT_c1 = 4.3       # constant [dC]
# - cT_c2 = 0.943     # constant [-]
# - cT_c3 = 0.028     # constant [dC m2 W-1]
# - cT_c4 = -1.528    # constant [dC s m-1]
# - gamma = -0.005    # constant [--]
# - temp_ref = 25     # reference temperature [dC]
# - gstc = 1000       # standard test conditions [W m-2]
# - shift_doy = 186   # if HadGEM : 180
# ```

# %% [markdown]
# ### Load datasets

# %%
# Load installed capacity data
grid_offshore = xr.open_dataset('/climca/people/onennecke/Wind_Solar_MaStR/processed_data/wind_offshore_ic.nc')
grid_offshore = grid_offshore['wind_off_cap']
mask_offshore = xr.where(np.isfinite(grid_offshore), 1, 0)
grid_onshore = xr.open_dataset('/climca/people/onennecke/Wind_Solar_MaStR/processed_data/wind_onshore_ic.nc')
grid_onshore = grid_onshore['wind_on_cap']
mask_onshore = xr.where(np.isfinite(grid_onshore), 1, 0)
grid_solar = xr.open_dataset('/climca/people/onennecke/Wind_Solar_MaStR/processed_data/solar_ic_netto.nc')
# grid_solar = xr.open_dataset('/climca/people/onennecke/Wind_Solar_MaStR/processed_data/solar_ic.nc')
grid_solar = grid_solar['solar_cap']
mask_solar = xr.where(np.isfinite(grid_solar), 1, 0)
population = xr.open_dataset('/climca/people/onennecke/population_data/population_regrid_weights.nc')
population = population['population']
mask_population = xr.where(np.isfinite(population), 1, 0)
# Overall mask
overall_mask = mask_offshore + mask_onshore + mask_solar + mask_population
overall_mask = xr.where(overall_mask > 0, 1, 0)

# %%
# Load wind height data
grid_onsh_hub_height = xr.open_dataset('/climca/people/onennecke/Wind_Solar_MaStR/processed_data/wind_onshore_height_weighted.nc')
grid_offsh_hub_height = xr.open_dataset('/climca/people/onennecke/Wind_Solar_MaStR/processed_data/wind_offshore_height_weighted.nc')

hub_height_on = grid_onsh_hub_height['wind_on_hub_height']
hub_height_off = grid_offsh_hub_height['wind_off_hub_height']

# %%
# Load regridded population weights data
pop_regr_CIESIN_weights = xr.open_dataset('/climca/people/onennecke/population_data/population_regrid_weights.nc')

# Load fit values from vdW Paper
demand_fit_values = xr.open_dataset('/climca/people/onennecke/population_data/demand_fit_values_week.nc')

# %% [markdown]
# ### Define used models and timeframes

# %%
# Read the dataframe from the csv file
# used_runs_old = pd.read_csv('/home/onennecke/CMIP_models/CMIP6_runs.csv')
# used_runs_old
used_runs_CMIP = pd.read_csv('/home/onennecke/CMIP_models/CMIP6_runs_future.csv')

used_runs_CESM = pd.read_csv('/home/onennecke/CMIP_models/CESM2_LE_runs.csv')

used_runs = pd.concat([used_runs_CMIP, used_runs_CESM], ignore_index=True)


# Change the ref column to 1 for the first instance of each model
used_runs['Ref'] = used_runs.groupby(['ESM', 'Institution']).cumcount().apply(lambda x: 1 if x == 0 else 0)

used_runs
# Out:
#              ESM   Institution           run  Ref
# 0     ACCESS-CM2  CSIRO-ARCCSS      r4i1p1f1    1
# 1     ACCESS-CM2  CSIRO-ARCCSS      r5i1p1f1    0
# 2     ACCESS-CM2  CSIRO-ARCCSS      r1i1p1f1    0
# 3    BCC-CSM2-MR           BCC      r1i1p1f1    1
# 4          CESM2          NCAR      r4i1p1f1    1
# ..           ...           ...           ...  ...
# 187        CESM2          NCAR  LE2-1301_016    0
# 188        CESM2          NCAR  LE2-1301_017    0
# 189        CESM2          NCAR  LE2-1301_018    0
# 190        CESM2          NCAR  LE2-1301_019    0
# 191        CESM2          NCAR  LE2-1301_020    0
#
# [192 rows x 4 columns]

# %%
# Display the whole dataframe
pd.set_option('display.max_rows', None)
print(used_runs)
# Out:
#                ESM          Institution           run  Ref
# 0       ACCESS-CM2         CSIRO-ARCCSS      r4i1p1f1    1
# 1       ACCESS-CM2         CSIRO-ARCCSS      r5i1p1f1    0
# 2       ACCESS-CM2         CSIRO-ARCCSS      r1i1p1f1    0
# 3      BCC-CSM2-MR                  BCC      r1i1p1f1    1
# 4            CESM2                 NCAR      r4i1p1f1    1
# 5            CESM2                 NCAR     r10i1p1f1    0
# 6            CESM2                 NCAR     r11i1p1f1    0
# 7        EC-Earth3  EC-Earth-Consortium    r149i1p1f1    1
# 8        EC-Earth3  EC-Earth-Consortium      r4i1p1f1    0
# 9        EC-Earth3  EC-Earth-Consortium    r148i1p1f1    0
# 10       EC-Earth3  EC-Earth-Consortium    r105i1p1f1    0
# 11       EC-Earth3  EC-Earth-Consortium    r134i1p1f1    0
# 12       EC-Earth3  EC-Earth-Consortium    r141i1p1f1    0
# 13       EC-Earth3  EC-Earth-Consortium    r146i1p1f1    0
# 14       EC-Earth3  EC-Earth-Consortium    r112i1p1f1    0
# 15       EC-Earth3  EC-Earth-Consortium    r117i1p1f1    0
# 16       EC-Earth3  EC-Earth-Consortium    r125i1p1f1    0
# 17       EC-Earth3  EC-Earth-Consortium    r113i1p1f1    0
# 18       EC-Earth3  EC-Earth-Consortium    r106i1p1f1    0
# 19       EC-Earth3  EC-Earth-Consortium    r138i1p1f1    0
# 20       EC-Earth3  EC-Earth-Consortium      r5i1p1f1    0
# 21       EC-Earth3  EC-Earth-Consortium    r137i1p1f1    0
# 22       EC-Earth3  EC-Earth-Consortium    r145i1p1f1    0
# 23       EC-Earth3  EC-Earth-Consortium    r114i1p1f1    0
# 24       EC-Earth3  EC-Earth-Consortium    r120i1p1f1    0
# 25       EC-Earth3  EC-Earth-Consortium    r128i1p1f1    0
# 26       EC-Earth3  EC-Earth-Consortium    r135i1p1f1    0
# 27       EC-Earth3  EC-Earth-Consortium    r110i1p1f1    0
# 28       EC-Earth3  EC-Earth-Consortium    r129i1p1f1    0
# 29       EC-Earth3  EC-Earth-Consortium    r132i1p1f1    0
# 30       EC-Earth3  EC-Earth-Consortium    r101i1p1f1    0
# 31       EC-Earth3  EC-Earth-Consortium    r124i1p1f1    0
# 32       EC-Earth3  EC-Earth-Consortium    r127i1p1f1    0
# 33       EC-Earth3  EC-Earth-Consortium    r116i1p1f1    0
# 34       EC-Earth3  EC-Earth-Consortium    r131i1p1f1    0
# 35       EC-Earth3  EC-Earth-Consortium    r121i1p1f1    0
# 36       EC-Earth3  EC-Earth-Consortium    r142i1p1f1    0
# 37       EC-Earth3  EC-Earth-Consortium    r102i1p1f1    0
# 38       EC-Earth3  EC-Earth-Consortium    r133i1p1f1    0
# 39       EC-Earth3  EC-Earth-Consortium    r111i1p1f1    0
# 40       EC-Earth3  EC-Earth-Consortium    r140i1p1f1    0
# 41       EC-Earth3  EC-Earth-Consortium    r136i1p1f1    0
# 42       EC-Earth3  EC-Earth-Consortium    r108i1p1f1    0
# 43       EC-Earth3  EC-Earth-Consortium    r130i1p1f1    0
# 44       EC-Earth3  EC-Earth-Consortium    r150i1p1f1    0
# 45       EC-Earth3  EC-Earth-Consortium    r104i1p1f1    0
# 46       EC-Earth3  EC-Earth-Consortium    r118i1p1f1    0
# 47       EC-Earth3  EC-Earth-Consortium    r109i1p1f1    0
# 48       EC-Earth3  EC-Earth-Consortium    r143i1p1f1    0
# 49       EC-Earth3  EC-Earth-Consortium    r147i1p1f1    0
# 50       EC-Earth3  EC-Earth-Consortium      r3i1p1f1    0
# 51       EC-Earth3  EC-Earth-Consortium    r126i1p1f1    0
# 52       EC-Earth3  EC-Earth-Consortium    r119i1p1f1    0
# 53       EC-Earth3  EC-Earth-Consortium      r1i1p1f1    0
# 54       EC-Earth3  EC-Earth-Consortium    r123i1p1f1    0
# 55       EC-Earth3  EC-Earth-Consortium    r122i1p1f1    0
# 56       EC-Earth3  EC-Earth-Consortium    r115i1p1f1    0
# 57       EC-Earth3  EC-Earth-Consortium    r103i1p1f1    0
# 58       EC-Earth3  EC-Earth-Consortium    r144i1p1f1    0
# 59       EC-Earth3  EC-Earth-Consortium    r139i1p1f1    0
# 60       EC-Earth3  EC-Earth-Consortium    r107i1p1f1    0
# 61       GFDL-ESM4            NOAA-GFDL      r1i1p1f1    1
# 62      KACE-1-0-G             NIMS-KMA      r2i1p1f1    1
# 63      KACE-1-0-G             NIMS-KMA      r3i1p1f1    0
# 64      KACE-1-0-G             NIMS-KMA      r1i1p1f1    0
# 65   MPI-ESM1-2-HR                 DKRZ      r6i1p1f1    1
# 66   MPI-ESM1-2-HR                 DKRZ      r4i1p1f1    0
# 67   MPI-ESM1-2-HR                 DKRZ      r9i1p1f1    0
# 68   MPI-ESM1-2-HR                 DKRZ     r10i1p1f1    0
# 69   MPI-ESM1-2-HR                 DKRZ      r5i1p1f1    0
# 70   MPI-ESM1-2-HR                 DKRZ      r8i1p1f1    0
# 71   MPI-ESM1-2-HR                 DKRZ      r2i1p1f1    0
# 72   MPI-ESM1-2-HR                 DKRZ      r7i1p1f1    0
# 73   MPI-ESM1-2-HR                 DKRZ      r3i1p1f1    0
# 74   MPI-ESM1-2-HR                 DKRZ      r1i1p1f1    0
# 75      MRI-ESM2-0                  MRI      r4i1p1f1    1
# 76      MRI-ESM2-0                  MRI      r5i1p1f1    0
# 77      MRI-ESM2-0                  MRI      r2i1p1f1    0
# 78      MRI-ESM2-0                  MRI      r3i1p1f1    0
# 79      MRI-ESM2-0                  MRI      r1i1p1f1    0
# 80         TaiESM1              AS-RCEC      r1i1p1f1    1
# 81     UKESM1-0-LL                 MOHC      r4i1p1f2    1
# 82     UKESM1-0-LL                 MOHC      r1i1p1f2    0
# 83     UKESM1-0-LL                 MOHC      r7i1p1f2    0
# 84     UKESM1-0-LL                 MOHC      r6i1p1f2    0
# 85     UKESM1-0-LL                 MOHC      r2i1p1f2    0
# 86     UKESM1-0-LL                 MOHC      r5i1p1f2    0
# 87     UKESM1-0-LL                 MOHC      r3i1p1f2    0
# 88     UKESM1-0-LL                 MOHC      r8i1p1f2    0
# 89     UKESM1-0-LL             NIMS-KMA     r15i1p1f2    1
# 90     UKESM1-0-LL             NIMS-KMA     r13i1p1f2    0
# 91     UKESM1-0-LL             NIMS-KMA     r14i1p1f2    0
# 92           CESM2                 NCAR  LE2-1001_001    0
# 93           CESM2                 NCAR  LE2-1011_001    0
# 94           CESM2                 NCAR  LE2-1021_002    0
# 95           CESM2                 NCAR  LE2-1031_002    0
# 96           CESM2                 NCAR  LE2-1041_003    0
# 97           CESM2                 NCAR  LE2-1051_003    0
# 98           CESM2                 NCAR  LE2-1061_004    0
# 99           CESM2                 NCAR  LE2-1071_004    0
# 100          CESM2                 NCAR  LE2-1081_005    0
# 101          CESM2                 NCAR  LE2-1091_005    0
# 102          CESM2                 NCAR  LE2-1101_006    0
# 103          CESM2                 NCAR  LE2-1111_006    0
# 104          CESM2                 NCAR  LE2-1121_007    0
# 105          CESM2                 NCAR  LE2-1131_007    0
# 106          CESM2                 NCAR  LE2-1141_008    0
# 107          CESM2                 NCAR  LE2-1151_008    0
# 108          CESM2                 NCAR  LE2-1161_009    0
# 109          CESM2                 NCAR  LE2-1171_009    0
# 110          CESM2                 NCAR  LE2-1181_010    0
# 111          CESM2                 NCAR  LE2-1191_010    0
# 112          CESM2                 NCAR  LE2-1231_001    0
# 113          CESM2                 NCAR  LE2-1231_002    0
# 114          CESM2                 NCAR  LE2-1231_003    0
# 115          CESM2                 NCAR  LE2-1231_004    0
# 116          CESM2                 NCAR  LE2-1231_005    0
# 117          CESM2                 NCAR  LE2-1231_006    0
# 118          CESM2                 NCAR  LE2-1231_007    0
# 119          CESM2                 NCAR  LE2-1231_008    0
# 120          CESM2                 NCAR  LE2-1231_009    0
# 121          CESM2                 NCAR  LE2-1231_010    0
# 122          CESM2                 NCAR  LE2-1231_011    0
# 123          CESM2                 NCAR  LE2-1231_012    0
# 124          CESM2                 NCAR  LE2-1231_013    0
# 125          CESM2                 NCAR  LE2-1231_014    0
# 126          CESM2                 NCAR  LE2-1231_015    0
# 127          CESM2                 NCAR  LE2-1231_016    0
# 128          CESM2                 NCAR  LE2-1231_017    0
# 129          CESM2                 NCAR  LE2-1231_018    0
# 130          CESM2                 NCAR  LE2-1231_019    0
# 131          CESM2                 NCAR  LE2-1231_020    0
# 132          CESM2                 NCAR  LE2-1251_001    0
# 133          CESM2                 NCAR  LE2-1251_002    0
# 134          CESM2                 NCAR  LE2-1251_003    0
# 135          CESM2                 NCAR  LE2-1251_004    0
# 136          CESM2                 NCAR  LE2-1251_005    0
# 137          CESM2                 NCAR  LE2-1251_006    0
# 138          CESM2                 NCAR  LE2-1251_007    0
# 139          CESM2                 NCAR  LE2-1251_008    0
# 140          CESM2                 NCAR  LE2-1251_009    0
# 141          CESM2                 NCAR  LE2-1251_010    0
# 142          CESM2                 NCAR  LE2-1251_011    0
# 143          CESM2                 NCAR  LE2-1251_012    0
# 144          CESM2                 NCAR  LE2-1251_013    0
# 145          CESM2                 NCAR  LE2-1251_014    0
# 146          CESM2                 NCAR  LE2-1251_015    0
# 147          CESM2                 NCAR  LE2-1251_016    0
# 148          CESM2                 NCAR  LE2-1251_017    0
# 149          CESM2                 NCAR  LE2-1251_018    0
# 150          CESM2                 NCAR  LE2-1251_019    0
# 151          CESM2                 NCAR  LE2-1251_020    0
# 152          CESM2                 NCAR  LE2-1281_001    0
# 153          CESM2                 NCAR  LE2-1281_002    0
# 154          CESM2                 NCAR  LE2-1281_003    0
# 155          CESM2                 NCAR  LE2-1281_004    0
# 156          CESM2                 NCAR  LE2-1281_005    0
# 157          CESM2                 NCAR  LE2-1281_006    0
# 158          CESM2                 NCAR  LE2-1281_007    0
# 159          CESM2                 NCAR  LE2-1281_008    0
# 160          CESM2                 NCAR  LE2-1281_009    0
# 161          CESM2                 NCAR  LE2-1281_010    0
# 162          CESM2                 NCAR  LE2-1281_011    0
# 163          CESM2                 NCAR  LE2-1281_012    0
# 164          CESM2                 NCAR  LE2-1281_013    0
# 165          CESM2                 NCAR  LE2-1281_014    0
# 166          CESM2                 NCAR  LE2-1281_015    0
# 167          CESM2                 NCAR  LE2-1281_016    0
# 168          CESM2                 NCAR  LE2-1281_017    0
# 169          CESM2                 NCAR  LE2-1281_018    0
# 170          CESM2                 NCAR  LE2-1281_019    0
# 171          CESM2                 NCAR  LE2-1281_020    0
# 172          CESM2                 NCAR  LE2-1301_001    0
# 173          CESM2                 NCAR  LE2-1301_002    0
# 174          CESM2                 NCAR  LE2-1301_003    0
# 175          CESM2                 NCAR  LE2-1301_004    0
# 176          CESM2                 NCAR  LE2-1301_005    0
# 177          CESM2                 NCAR  LE2-1301_006    0
# 178          CESM2                 NCAR  LE2-1301_007    0
# 179          CESM2                 NCAR  LE2-1301_008    0
# 180          CESM2                 NCAR  LE2-1301_009    0
# 181          CESM2                 NCAR  LE2-1301_010    0
# 182          CESM2                 NCAR  LE2-1301_011    0
# 183          CESM2                 NCAR  LE2-1301_012    0
# 184          CESM2                 NCAR  LE2-1301_013    0
# 185          CESM2                 NCAR  LE2-1301_014    0
# 186          CESM2                 NCAR  LE2-1301_015    0
# 187          CESM2                 NCAR  LE2-1301_016    0
# 188          CESM2                 NCAR  LE2-1301_017    0
# 189          CESM2                 NCAR  LE2-1301_018    0
# 190          CESM2                 NCAR  LE2-1301_019    0
# 191          CESM2                 NCAR  LE2-1301_020    0

# %% [markdown]
# ### Run SEM

# %%
# path_sample_run = '/climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1001_001_rsds.nc'

# sample_run = glob.glob(path_sample_run)
# LE2-1301_011
sample_run = xr.open_dataset('/climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1301_011_rsds.nc')
# sample_run['ESM'].values

# %%
for i in range(len(used_runs)):
    run_time = time.time()
    ESM = used_runs['ESM'][i]
    print(ESM)
    Inst = used_runs['Institution'][i]
    run = used_runs['run'][i]
    print(f'Processing Run Nr. {i+1}, {ESM}, {Inst}, {run}, \n')
    base_path = '/climca/people/onennecke/not_debiased_data_future/'

    sel_run = glob.glob(os.path.join(base_path, f"{ESM}_{run}_*"))

    # now drop any psl files
    sel_run = [fn for fn in sel_run if '_psl' not in os.path.basename(fn)]
    # print(sel_run)
    
    combined_ds = xr.open_mfdataset(sel_run)
    combined_ds = combined_ds.assign_coords(run = run, ESM = ESM, ESM_run = f'{ESM}_{run}')
    # Filter to only winter months (October to March)
    # combined_ds = combined_ds.sel(time=combined_ds.time.dt.month.isin([10, 11, 12, 1, 2, 3]))
    
    combined_ds['tas'] = combined_ds['tas'] - 273.15 # Convert temperature from Kelvin to Celsius
    combined_ds['tasmax'] = combined_ds['tasmax'] - 273.15 # Convert maximum temperature from Kelvin to Celsius
    
    wepot_off = wind_model_func.compute_wind_energy_potential(combined_ds['sfcWind'], grid_offsh_hub_height, 
                                                              config.a_offshore, config.height_ref, v_cutin=config.v_cutin0_off_unb, 
                                                              v_rated=config.v_rated0_off_unb, v_cutout=config.v_cutout0_off_unb)
    wepot_on = wind_model_func.compute_wind_energy_potential(combined_ds['sfcWind'], grid_onsh_hub_height, config.a_onshore, 
                                                             config.height_ref, v_cutin=config.v_cutin0_on_weighted, 
                                                             v_rated=config.v_rated0_on_weighted, v_cutout=config.v_cutout0_on_weighted)

    combined_ds['wind_off_pot'] = wepot_off['wind_off_pot']
    combined_ds['wind_on_pot'] = wepot_on['wind_on_pot']

    weprod_off = wind_model_func.compute_wind_energy_production(wepot_off, grid_offshore)
    weprod_on = wind_model_func.compute_wind_energy_production(wepot_on, grid_onshore)

    combined_ds['wind_off_prod'] = weprod_off['wind_off_prod']
    combined_ds['wind_on_prod'] = weprod_on['wind_on_prod']

    sepot = solar_model_func.compute_solar_energy_potential(combined_ds['rsds'], combined_ds['tas'], combined_ds['tasmax'], 
                                                            combined_ds['sfcWind'], constants=config.pv_constants_unb, 
                                                            gamma=config.gamma_unb, ref_temp=config.temp_ref_unb)

    # combined_ds['solar_pot'] = sepot['solar_pot'] 
    combined_ds['solar_pot'] = sepot

    seprod = solar_model_func.compute_solar_energy_production(sepot, grid_solar)

    # combined_ds['solar_prod'] = seprod['solar_prod']
    combined_ds['solar_prod'] = seprod


    # Calculate weighted sum
    weighted_temp_list = []
    for y in np.unique(combined_ds['tas']["time.year"].values):
        # print(y)
        ds_weigh_temp_0 = xr.Dataset()
        ds_weigh_temp_0['temp'] = (combined_ds['tas'].sel(time=str(y)) * pop_regr_CIESIN_weights['population']).sum(dim=['lat', 'lon'])
        weighted_temp_list.append(ds_weigh_temp_0)
        
    ds_weighted_temp = xr.concat(weighted_temp_list, dim="time") 

    # Calculate demand
    demand_ds = demand_func.compute_demand(ds_weighted_temp, demand_fit_values.sel(country = 9, period = 'week'))

    timeseries_ds = demand_ds.copy()

    # timeseries_ds['sfcWind_ntmsk'] = combined_ds['sfcWind'].mean(dim=['lat', 'lon'])
    # timeseries_ds['rsds_ntmsk'] = combined_ds['rsds'].mean(dim=['lat', 'lon'])
    # timeseries_ds['tas_ntmsk'] = combined_ds['tas'].mean(dim=['lat', 'lon'])
    # timeseries_ds['tasmax_ntmsk'] = combined_ds['tasmax'].mean(dim=['lat', 'lon'])
    timeseries_ds['sfcWind'] = combined_ds['sfcWind'].where(overall_mask == 1).mean(dim=['lat', 'lon'], skipna=True)
    timeseries_ds['rsds']    = combined_ds['rsds'].where(overall_mask == 1).mean(dim=['lat', 'lon'], skipna=True)
    timeseries_ds['tas']     = combined_ds['tas'].where(overall_mask == 1).mean(dim=['lat', 'lon'], skipna=True)
    timeseries_ds['tasmax']  = combined_ds['tasmax'].where(overall_mask == 1).mean(dim=['lat', 'lon'], skipna=True)

    timeseries_ds['wind_off_prod'] = combined_ds['wind_off_prod'].sum(dim=['lat', 'lon']) / 1000000
    timeseries_ds['wind_on_prod'] = combined_ds['wind_on_prod'].sum(dim=['lat', 'lon']) / 1000000
    timeseries_ds['solar_prod'] = combined_ds['solar_prod'].sum(dim=['lat', 'lon']) / 1000000

    timeseries_ds['total_prod'] = timeseries_ds['wind_off_prod'] + timeseries_ds['wind_on_prod'] + timeseries_ds['solar_prod']
    timeseries_ds['Netto'] = timeseries_ds['total_prod'] - timeseries_ds['demand']
    timeseries_ds['Residual_load'] = timeseries_ds['demand'] - timeseries_ds['total_prod']


    ts_output = timeseries_ds.assign_coords(run = run, ESM = ESM, ESM_run = f'{ESM}_{run}')
    
    ts_output = ts_output.assign_coords(time=sample_run.time.data)


    
    ts_output.load()
    # ts_output.to_netcdf(f'/climca/people/onennecke/model_output/bias_corrected_masked_ibicus/full_year/{ESM}_{run}_timeseries.nc')
    # ts_output.to_netcdf(f'/climca/people/onennecke/model_output/not_bias_corrected/future_full_year/{ESM}_{run}_timeseries.nc')
    ts_output.to_netcdf(f'/climca/people/onennecke/model_output/not_bias_corrected/future_full_year_one_time/{ESM}_{run}_timeseries.nc')

    print('Run time: ', int(np.floor((time.time()  - run_time) / 60)),'m', round((time.time()  - run_time) % 60,1),'s')
    # break
# Out:
# ACCESS-CM2
# Processing Run Nr. 1, ACCESS-CM2, CSIRO-ARCCSS, r4i1p1f1,
#
# Run time:  0 m 0.6 s
# ACCESS-CM2
# Processing Run Nr. 2, ACCESS-CM2, CSIRO-ARCCSS, r5i1p1f1,
#
# Run time:  0 m 0.4 s
# ACCESS-CM2
# Processing Run Nr. 3, ACCESS-CM2, CSIRO-ARCCSS, r1i1p1f1,
#
# Run time:  0 m 0.5 s
# BCC-CSM2-MR
# Processing Run Nr. 4, BCC-CSM2-MR, BCC, r1i1p1f1,
#
# Run time:  0 m 0.3 s
# CESM2
# Processing Run Nr. 5, CESM2, NCAR, r4i1p1f1,
#
# Run time:  0 m 0.3 s
# CESM2
# Processing Run Nr. 6, CESM2, NCAR, r10i1p1f1,
#
# Run time:  0 m 0.4 s
# CESM2
# Processing Run Nr. 7, CESM2, NCAR, r11i1p1f1,
#
# Run time:  0 m 0.4 s
# EC-Earth3
# Processing Run Nr. 8, EC-Earth3, EC-Earth-Consortium, r149i1p1f1,
#
# Run time:  0 m 0.3 s
# EC-Earth3
# Processing Run Nr. 9, EC-Earth3, EC-Earth-Consortium, r4i1p1f1,
#
# Run time:  0 m 0.3 s
# EC-Earth3
# Processing Run Nr. 10, EC-Earth3, EC-Earth-Consortium, r148i1p1f1,
#
# Run time:  0 m 0.3 s
# EC-Earth3
# Processing Run Nr. 11, EC-Earth3, EC-Earth-Consortium, r105i1p1f1,
#
# Run time:  0 m 0.4 s
# EC-Earth3
# Processing Run Nr. 12, EC-Earth3, EC-Earth-Consortium, r134i1p1f1,
#
# Run time:  0 m 0.5 s
# EC-Earth3
# Processing Run Nr. 13, EC-Earth3, EC-Earth-Consortium, r141i1p1f1,
#
# Run time:  0 m 0.3 s
# EC-Earth3
# Processing Run Nr. 14, EC-Earth3, EC-Earth-Consortium, r146i1p1f1,
#
# Run time:  0 m 0.4 s
# EC-Earth3
# Processing Run Nr. 15, EC-Earth3, EC-Earth-Consortium, r112i1p1f1,
#
# Run time:  0 m 0.4 s
# EC-Earth3
# Processing Run Nr. 16, EC-Earth3, EC-Earth-Consortium, r117i1p1f1,
#
# Run time:  0 m 0.3 s
# EC-Earth3
# Processing Run Nr. 17, EC-Earth3, EC-Earth-Consortium, r125i1p1f1,
#
# Run time:  0 m 0.3 s
# EC-Earth3
# Processing Run Nr. 18, EC-Earth3, EC-Earth-Consortium, r113i1p1f1,
#
# Run time:  0 m 0.4 s
# EC-Earth3
# Processing Run Nr. 19, EC-Earth3, EC-Earth-Consortium, r106i1p1f1,
#
# Run time:  0 m 0.3 s
# EC-Earth3
# Processing Run Nr. 20, EC-Earth3, EC-Earth-Consortium, r138i1p1f1,
#
# Run time:  0 m 0.4 s
# EC-Earth3
# Processing Run Nr. 21, EC-Earth3, EC-Earth-Consortium, r5i1p1f1,
#
# Run time:  0 m 0.5 s
# EC-Earth3
# Processing Run Nr. 22, EC-Earth3, EC-Earth-Consortium, r137i1p1f1,
#
# Run time:  0 m 0.4 s
# EC-Earth3
# Processing Run Nr. 23, EC-Earth3, EC-Earth-Consortium, r145i1p1f1,
#
# Run time:  0 m 0.3 s
# EC-Earth3
# Processing Run Nr. 24, EC-Earth3, EC-Earth-Consortium, r114i1p1f1,
#
# Run time:  0 m 0.4 s
# EC-Earth3
# Processing Run Nr. 25, EC-Earth3, EC-Earth-Consortium, r120i1p1f1,
#
# Run time:  0 m 0.3 s
# EC-Earth3
# Processing Run Nr. 26, EC-Earth3, EC-Earth-Consortium, r128i1p1f1,
#
# Run time:  0 m 0.4 s
# EC-Earth3
# Processing Run Nr. 27, EC-Earth3, EC-Earth-Consortium, r135i1p1f1,
#
# Run time:  0 m 0.3 s
# EC-Earth3
# Processing Run Nr. 28, EC-Earth3, EC-Earth-Consortium, r110i1p1f1,
#
# Run time:  0 m 0.3 s
# EC-Earth3
# Processing Run Nr. 29, EC-Earth3, EC-Earth-Consortium, r129i1p1f1,
#
# Run time:  0 m 0.4 s
# EC-Earth3
# Processing Run Nr. 30, EC-Earth3, EC-Earth-Consortium, r132i1p1f1,
#
# Run time:  0 m 0.4 s
# EC-Earth3
# Processing Run Nr. 31, EC-Earth3, EC-Earth-Consortium, r101i1p1f1,
#
# Run time:  0 m 0.6 s
# EC-Earth3
# Processing Run Nr. 32, EC-Earth3, EC-Earth-Consortium, r124i1p1f1,
#
# Run time:  0 m 0.4 s
# EC-Earth3
# Processing Run Nr. 33, EC-Earth3, EC-Earth-Consortium, r127i1p1f1,
#
# Run time:  0 m 0.3 s
# EC-Earth3
# Processing Run Nr. 34, EC-Earth3, EC-Earth-Consortium, r116i1p1f1,
#
# Run time:  0 m 0.3 s
# EC-Earth3
# Processing Run Nr. 35, EC-Earth3, EC-Earth-Consortium, r131i1p1f1,
#
# Run time:  0 m 0.3 s
# EC-Earth3
# Processing Run Nr. 36, EC-Earth3, EC-Earth-Consortium, r121i1p1f1,
#
# Run time:  0 m 0.4 s
# EC-Earth3
# Processing Run Nr. 37, EC-Earth3, EC-Earth-Consortium, r142i1p1f1,
#
# Run time:  0 m 0.3 s
# EC-Earth3
# Processing Run Nr. 38, EC-Earth3, EC-Earth-Consortium, r102i1p1f1,
#
# Run time:  0 m 0.4 s
# EC-Earth3
# Processing Run Nr. 39, EC-Earth3, EC-Earth-Consortium, r133i1p1f1,
#
# Run time:  0 m 0.3 s
# EC-Earth3
# Processing Run Nr. 40, EC-Earth3, EC-Earth-Consortium, r111i1p1f1,
#
# Run time:  0 m 0.5 s
# EC-Earth3
# Processing Run Nr. 41, EC-Earth3, EC-Earth-Consortium, r140i1p1f1,
#
# Run time:  0 m 0.4 s
# EC-Earth3
# Processing Run Nr. 42, EC-Earth3, EC-Earth-Consortium, r136i1p1f1,
#
# Run time:  0 m 0.4 s
# EC-Earth3
# Processing Run Nr. 43, EC-Earth3, EC-Earth-Consortium, r108i1p1f1,
#
# Run time:  0 m 0.4 s
# EC-Earth3
# Processing Run Nr. 44, EC-Earth3, EC-Earth-Consortium, r130i1p1f1,
#
# Run time:  0 m 0.4 s
# EC-Earth3
# Processing Run Nr. 45, EC-Earth3, EC-Earth-Consortium, r150i1p1f1,
#
# Run time:  0 m 0.3 s
# EC-Earth3
# Processing Run Nr. 46, EC-Earth3, EC-Earth-Consortium, r104i1p1f1,
#
# Run time:  0 m 0.3 s
# EC-Earth3
# Processing Run Nr. 47, EC-Earth3, EC-Earth-Consortium, r118i1p1f1,
#
# Run time:  0 m 0.3 s
# EC-Earth3
# Processing Run Nr. 48, EC-Earth3, EC-Earth-Consortium, r109i1p1f1,
#
# Run time:  0 m 0.4 s
# EC-Earth3
# Processing Run Nr. 49, EC-Earth3, EC-Earth-Consortium, r143i1p1f1,
#
# Run time:  0 m 0.4 s
# EC-Earth3
# Processing Run Nr. 50, EC-Earth3, EC-Earth-Consortium, r147i1p1f1,
#
# Run time:  0 m 0.6 s
# EC-Earth3
# Processing Run Nr. 51, EC-Earth3, EC-Earth-Consortium, r3i1p1f1,
#
# Run time:  0 m 0.3 s
# EC-Earth3
# Processing Run Nr. 52, EC-Earth3, EC-Earth-Consortium, r126i1p1f1,
#
# Run time:  0 m 0.3 s
# EC-Earth3
# Processing Run Nr. 53, EC-Earth3, EC-Earth-Consortium, r119i1p1f1,
#
# Run time:  0 m 0.3 s
# EC-Earth3
# Processing Run Nr. 54, EC-Earth3, EC-Earth-Consortium, r1i1p1f1,
#
# Run time:  0 m 0.3 s
# EC-Earth3
# Processing Run Nr. 55, EC-Earth3, EC-Earth-Consortium, r123i1p1f1,
#
# Run time:  0 m 0.4 s
# EC-Earth3
# Processing Run Nr. 56, EC-Earth3, EC-Earth-Consortium, r122i1p1f1,
#
# Run time:  0 m 0.4 s
# EC-Earth3
# Processing Run Nr. 57, EC-Earth3, EC-Earth-Consortium, r115i1p1f1,
#
# Run time:  0 m 0.4 s
# EC-Earth3
# Processing Run Nr. 58, EC-Earth3, EC-Earth-Consortium, r103i1p1f1,
#
# Run time:  0 m 0.4 s
# EC-Earth3
# Processing Run Nr. 59, EC-Earth3, EC-Earth-Consortium, r144i1p1f1,
#
# Run time:  0 m 0.6 s
# EC-Earth3
# Processing Run Nr. 60, EC-Earth3, EC-Earth-Consortium, r139i1p1f1,
#
# Run time:  0 m 0.3 s
# EC-Earth3
# Processing Run Nr. 61, EC-Earth3, EC-Earth-Consortium, r107i1p1f1,
#
# Run time:  0 m 0.4 s
# GFDL-ESM4
# Processing Run Nr. 62, GFDL-ESM4, NOAA-GFDL, r1i1p1f1,
#
# Run time:  0 m 0.4 s
# KACE-1-0-G
# Processing Run Nr. 63, KACE-1-0-G, NIMS-KMA, r2i1p1f1,
#
# Run time:  0 m 0.4 s
# KACE-1-0-G
# Processing Run Nr. 64, KACE-1-0-G, NIMS-KMA, r3i1p1f1,
#
# Run time:  0 m 0.3 s
# KACE-1-0-G
# Processing Run Nr. 65, KACE-1-0-G, NIMS-KMA, r1i1p1f1,
#
# Run time:  0 m 0.4 s
# MPI-ESM1-2-HR
# Processing Run Nr. 66, MPI-ESM1-2-HR, DKRZ, r6i1p1f1,
#
# Run time:  0 m 0.4 s
# MPI-ESM1-2-HR
# Processing Run Nr. 67, MPI-ESM1-2-HR, DKRZ, r4i1p1f1,
#
# Run time:  0 m 0.3 s
# MPI-ESM1-2-HR
# Processing Run Nr. 68, MPI-ESM1-2-HR, DKRZ, r9i1p1f1,
#
# Run time:  0 m 0.4 s
# MPI-ESM1-2-HR
# Processing Run Nr. 69, MPI-ESM1-2-HR, DKRZ, r10i1p1f1,
#
# Run time:  0 m 0.6 s
# MPI-ESM1-2-HR
# Processing Run Nr. 70, MPI-ESM1-2-HR, DKRZ, r5i1p1f1,
#
# Run time:  0 m 0.3 s
# MPI-ESM1-2-HR
# Processing Run Nr. 71, MPI-ESM1-2-HR, DKRZ, r8i1p1f1,
#
# Run time:  0 m 0.4 s
# MPI-ESM1-2-HR
# Processing Run Nr. 72, MPI-ESM1-2-HR, DKRZ, r2i1p1f1,
#
# Run time:  0 m 0.4 s
# MPI-ESM1-2-HR
# Processing Run Nr. 73, MPI-ESM1-2-HR, DKRZ, r7i1p1f1,
#
# Run time:  0 m 0.3 s
# MPI-ESM1-2-HR
# Processing Run Nr. 74, MPI-ESM1-2-HR, DKRZ, r3i1p1f1,
#
# Run time:  0 m 0.4 s
# MPI-ESM1-2-HR
# Processing Run Nr. 75, MPI-ESM1-2-HR, DKRZ, r1i1p1f1,
#
# Run time:  0 m 0.4 s
# MRI-ESM2-0
# Processing Run Nr. 76, MRI-ESM2-0, MRI, r4i1p1f1,
#
# Run time:  0 m 0.4 s
# MRI-ESM2-0
# Processing Run Nr. 77, MRI-ESM2-0, MRI, r5i1p1f1,
#
# Run time:  0 m 0.4 s
# MRI-ESM2-0
# Processing Run Nr. 78, MRI-ESM2-0, MRI, r2i1p1f1,
#
# Run time:  0 m 0.6 s
# MRI-ESM2-0
# Processing Run Nr. 79, MRI-ESM2-0, MRI, r3i1p1f1,
#
# Run time:  0 m 0.4 s
# MRI-ESM2-0
# Processing Run Nr. 80, MRI-ESM2-0, MRI, r1i1p1f1,
#
# Run time:  0 m 0.3 s
# TaiESM1
# Processing Run Nr. 81, TaiESM1, AS-RCEC, r1i1p1f1,
#
# Run time:  0 m 0.3 s
# UKESM1-0-LL
# Processing Run Nr. 82, UKESM1-0-LL, MOHC, r4i1p1f2,
#
# Run time:  0 m 0.3 s
# UKESM1-0-LL
# Processing Run Nr. 83, UKESM1-0-LL, MOHC, r1i1p1f2,
#
# Run time:  0 m 0.4 s
# UKESM1-0-LL
# Processing Run Nr. 84, UKESM1-0-LL, MOHC, r7i1p1f2,
#
# Run time:  0 m 0.4 s
# UKESM1-0-LL
# Processing Run Nr. 85, UKESM1-0-LL, MOHC, r6i1p1f2,
#
# Run time:  0 m 0.4 s
# UKESM1-0-LL
# Processing Run Nr. 86, UKESM1-0-LL, MOHC, r2i1p1f2,
#
# Run time:  0 m 0.3 s
# UKESM1-0-LL
# Processing Run Nr. 87, UKESM1-0-LL, MOHC, r5i1p1f2,
#
# Run time:  0 m 0.4 s
# UKESM1-0-LL
# Processing Run Nr. 88, UKESM1-0-LL, MOHC, r3i1p1f2,
#
# Run time:  0 m 0.4 s
# UKESM1-0-LL
# Processing Run Nr. 89, UKESM1-0-LL, MOHC, r8i1p1f2,
#
# Run time:  0 m 0.5 s
# UKESM1-0-LL
# Processing Run Nr. 90, UKESM1-0-LL, NIMS-KMA, r15i1p1f2,
#
# Run time:  0 m 0.3 s
# UKESM1-0-LL
# Processing Run Nr. 91, UKESM1-0-LL, NIMS-KMA, r13i1p1f2,
#
# Run time:  0 m 0.4 s
# UKESM1-0-LL
# Processing Run Nr. 92, UKESM1-0-LL, NIMS-KMA, r14i1p1f2,
#
# Run time:  0 m 0.3 s
# CESM2
# Processing Run Nr. 93, CESM2, NCAR, LE2-1001_001,
#
# Run time:  0 m 0.4 s
# CESM2
# Processing Run Nr. 94, CESM2, NCAR, LE2-1011_001,
#
# Run time:  0 m 0.4 s
# CESM2
# Processing Run Nr. 95, CESM2, NCAR, LE2-1021_002,
#
# Run time:  0 m 0.4 s
# CESM2
# Processing Run Nr. 96, CESM2, NCAR, LE2-1031_002,
#
# Run time:  0 m 0.4 s
# CESM2
# Processing Run Nr. 97, CESM2, NCAR, LE2-1041_003,
#
# Run time:  0 m 0.6 s
# CESM2
# Processing Run Nr. 98, CESM2, NCAR, LE2-1051_003,
#
# Run time:  0 m 0.4 s
# CESM2
# Processing Run Nr. 99, CESM2, NCAR, LE2-1061_004,
#
# Run time:  0 m 0.4 s
# CESM2
# Processing Run Nr. 100, CESM2, NCAR, LE2-1071_004,
#
# Run time:  0 m 0.4 s
# CESM2
# Processing Run Nr. 101, CESM2, NCAR, LE2-1081_005,
#
# Run time:  0 m 0.4 s
# CESM2
# Processing Run Nr. 102, CESM2, NCAR, LE2-1091_005,
#
# Run time:  0 m 0.4 s
# CESM2
# Processing Run Nr. 103, CESM2, NCAR, LE2-1101_006,
#
# Run time:  0 m 0.3 s
# CESM2
# Processing Run Nr. 104, CESM2, NCAR, LE2-1111_006,
#
# Run time:  0 m 0.3 s
# CESM2
# Processing Run Nr. 105, CESM2, NCAR, LE2-1121_007,
#
# Run time:  0 m 0.3 s
# CESM2
# Processing Run Nr. 106, CESM2, NCAR, LE2-1131_007,
#
# Run time:  0 m 0.3 s
# CESM2
# Processing Run Nr. 107, CESM2, NCAR, LE2-1141_008,
#
# Run time:  0 m 0.4 s
# CESM2
# Processing Run Nr. 108, CESM2, NCAR, LE2-1151_008,
#
# Run time:  0 m 0.5 s
# CESM2
# Processing Run Nr. 109, CESM2, NCAR, LE2-1161_009,
#
# Run time:  0 m 0.4 s
# CESM2
# Processing Run Nr. 110, CESM2, NCAR, LE2-1171_009,
#
# Run time:  0 m 0.4 s
# CESM2
# Processing Run Nr. 111, CESM2, NCAR, LE2-1181_010,
#
# Run time:  0 m 0.3 s
# CESM2
# Processing Run Nr. 112, CESM2, NCAR, LE2-1191_010,
#
# Run time:  0 m 0.3 s
# CESM2
# Processing Run Nr. 113, CESM2, NCAR, LE2-1231_001,
#
# Run time:  0 m 0.4 s
# CESM2
# Processing Run Nr. 114, CESM2, NCAR, LE2-1231_002,
#
# Run time:  0 m 0.4 s
# CESM2
# Processing Run Nr. 115, CESM2, NCAR, LE2-1231_003,
#
# Run time:  0 m 0.3 s
# CESM2
# Processing Run Nr. 116, CESM2, NCAR, LE2-1231_004,
#
# Run time:  0 m 0.4 s
# CESM2
# Processing Run Nr. 117, CESM2, NCAR, LE2-1231_005,
#
# Run time:  0 m 0.4 s
# CESM2
# Processing Run Nr. 118, CESM2, NCAR, LE2-1231_006,
#
# Run time:  0 m 0.5 s
# CESM2
# Processing Run Nr. 119, CESM2, NCAR, LE2-1231_007,
#
# Run time:  0 m 0.4 s
# CESM2
# Processing Run Nr. 120, CESM2, NCAR, LE2-1231_008,
#
# Run time:  0 m 0.4 s
# CESM2
# Processing Run Nr. 121, CESM2, NCAR, LE2-1231_009,
#
# Run time:  0 m 0.4 s
# CESM2
# Processing Run Nr. 122, CESM2, NCAR, LE2-1231_010,
#
# Run time:  0 m 0.4 s
# CESM2
# Processing Run Nr. 123, CESM2, NCAR, LE2-1231_011,
#
# Run time:  0 m 0.3 s
# CESM2
# Processing Run Nr. 124, CESM2, NCAR, LE2-1231_012,
#
# Run time:  0 m 0.3 s
# CESM2
# Processing Run Nr. 125, CESM2, NCAR, LE2-1231_013,
#
# Run time:  0 m 0.3 s
# CESM2
# Processing Run Nr. 126, CESM2, NCAR, LE2-1231_014,
#
# Run time:  0 m 0.3 s
# CESM2
# Processing Run Nr. 127, CESM2, NCAR, LE2-1231_015,
#
# Run time:  0 m 0.6 s
# CESM2
# Processing Run Nr. 128, CESM2, NCAR, LE2-1231_016,
#
# Run time:  0 m 0.3 s
# CESM2
# Processing Run Nr. 129, CESM2, NCAR, LE2-1231_017,
#
# Run time:  0 m 0.3 s
# CESM2
# Processing Run Nr. 130, CESM2, NCAR, LE2-1231_018,
#
# Run time:  0 m 0.3 s
# CESM2
# Processing Run Nr. 131, CESM2, NCAR, LE2-1231_019,
#
# Run time:  0 m 0.3 s
# CESM2
# Processing Run Nr. 132, CESM2, NCAR, LE2-1231_020,
#
# Run time:  0 m 0.3 s
# CESM2
# Processing Run Nr. 133, CESM2, NCAR, LE2-1251_001,
#
# Run time:  0 m 0.4 s
# CESM2
# Processing Run Nr. 134, CESM2, NCAR, LE2-1251_002,
#
# Run time:  0 m 0.3 s
# CESM2
# Processing Run Nr. 135, CESM2, NCAR, LE2-1251_003,
#
# Run time:  0 m 0.3 s
# CESM2
# Processing Run Nr. 136, CESM2, NCAR, LE2-1251_004,
#
# Run time:  0 m 0.4 s
# CESM2
# Processing Run Nr. 137, CESM2, NCAR, LE2-1251_005,
#
# Run time:  0 m 0.5 s
# CESM2
# Processing Run Nr. 138, CESM2, NCAR, LE2-1251_006,
#
# Run time:  0 m 0.3 s
# CESM2
# Processing Run Nr. 139, CESM2, NCAR, LE2-1251_007,
#
# Run time:  0 m 0.3 s
# CESM2
# Processing Run Nr. 140, CESM2, NCAR, LE2-1251_008,
#
# Run time:  0 m 0.3 s
# CESM2
# Processing Run Nr. 141, CESM2, NCAR, LE2-1251_009,
#
# Run time:  0 m 0.4 s
# CESM2
# Processing Run Nr. 142, CESM2, NCAR, LE2-1251_010,
#
# Run time:  0 m 0.4 s
# CESM2
# Processing Run Nr. 143, CESM2, NCAR, LE2-1251_011,
#
# Run time:  0 m 0.3 s
# CESM2
# Processing Run Nr. 144, CESM2, NCAR, LE2-1251_012,
#
# Run time:  0 m 0.3 s
# CESM2
# Processing Run Nr. 145, CESM2, NCAR, LE2-1251_013,
#
# Run time:  0 m 0.4 s
# CESM2
# Processing Run Nr. 146, CESM2, NCAR, LE2-1251_014,
#
# Run time:  0 m 0.6 s
# CESM2
# Processing Run Nr. 147, CESM2, NCAR, LE2-1251_015,
#
# Run time:  0 m 0.3 s
# CESM2
# Processing Run Nr. 148, CESM2, NCAR, LE2-1251_016,
#
# Run time:  0 m 0.3 s
# CESM2
# Processing Run Nr. 149, CESM2, NCAR, LE2-1251_017,
#
# Run time:  0 m 0.3 s
# CESM2
# Processing Run Nr. 150, CESM2, NCAR, LE2-1251_018,
#
# Run time:  0 m 0.3 s
# CESM2
# Processing Run Nr. 151, CESM2, NCAR, LE2-1251_019,
#
# Run time:  0 m 0.4 s
# CESM2
# Processing Run Nr. 152, CESM2, NCAR, LE2-1251_020,
#
# Run time:  0 m 0.3 s
# CESM2
# Processing Run Nr. 153, CESM2, NCAR, LE2-1281_001,
#
# Run time:  0 m 0.3 s
# CESM2
# Processing Run Nr. 154, CESM2, NCAR, LE2-1281_002,
#
# Run time:  0 m 0.3 s
# CESM2
# Processing Run Nr. 155, CESM2, NCAR, LE2-1281_003,
#
# Run time:  0 m 0.4 s
# CESM2
# Processing Run Nr. 156, CESM2, NCAR, LE2-1281_004,
#
# Run time:  0 m 0.5 s
# CESM2
# Processing Run Nr. 157, CESM2, NCAR, LE2-1281_005,
#
# Run time:  0 m 0.4 s
# CESM2
# Processing Run Nr. 158, CESM2, NCAR, LE2-1281_006,
#
# Run time:  0 m 0.4 s
# CESM2
# Processing Run Nr. 159, CESM2, NCAR, LE2-1281_007,
#
# Run time:  0 m 0.4 s
# CESM2
# Processing Run Nr. 160, CESM2, NCAR, LE2-1281_008,
#
# Run time:  0 m 0.4 s
# CESM2
# Processing Run Nr. 161, CESM2, NCAR, LE2-1281_009,
#
# Run time:  0 m 0.4 s
# CESM2
# Processing Run Nr. 162, CESM2, NCAR, LE2-1281_010,
#
# Run time:  0 m 0.3 s
# CESM2
# Processing Run Nr. 163, CESM2, NCAR, LE2-1281_011,
#
# Run time:  0 m 0.3 s
# CESM2
# Processing Run Nr. 164, CESM2, NCAR, LE2-1281_012,
#
# Run time:  0 m 0.4 s
# CESM2
# Processing Run Nr. 165, CESM2, NCAR, LE2-1281_013,
#
# Run time:  0 m 0.4 s
# CESM2
# Processing Run Nr. 166, CESM2, NCAR, LE2-1281_014,
#
# Run time:  0 m 0.4 s
# CESM2
# Processing Run Nr. 167, CESM2, NCAR, LE2-1281_015,
#
# Run time:  0 m 0.3 s
# CESM2
# Processing Run Nr. 168, CESM2, NCAR, LE2-1281_016,
#
# Run time:  0 m 0.6 s
# CESM2
# Processing Run Nr. 169, CESM2, NCAR, LE2-1281_017,
#
# Run time:  0 m 0.3 s
# CESM2
# Processing Run Nr. 170, CESM2, NCAR, LE2-1281_018,
#
# Run time:  0 m 0.3 s
# CESM2
# Processing Run Nr. 171, CESM2, NCAR, LE2-1281_019,
#
# Run time:  0 m 0.4 s
# CESM2
# Processing Run Nr. 172, CESM2, NCAR, LE2-1281_020,
#
# Run time:  0 m 0.4 s
# CESM2
# Processing Run Nr. 173, CESM2, NCAR, LE2-1301_001,
#
# Run time:  0 m 0.3 s
# CESM2
# Processing Run Nr. 174, CESM2, NCAR, LE2-1301_002,
#
# Run time:  0 m 0.3 s
# CESM2
# Processing Run Nr. 175, CESM2, NCAR, LE2-1301_003,
#
# Run time:  0 m 0.4 s
# CESM2
# Processing Run Nr. 176, CESM2, NCAR, LE2-1301_004,
#
# Run time:  0 m 0.6 s
# CESM2
# Processing Run Nr. 177, CESM2, NCAR, LE2-1301_005,
#
# Run time:  0 m 0.4 s
# CESM2
# Processing Run Nr. 178, CESM2, NCAR, LE2-1301_006,
#
# Run time:  0 m 0.4 s
# CESM2
# Processing Run Nr. 179, CESM2, NCAR, LE2-1301_007,
#
# Run time:  0 m 0.4 s
# CESM2
# Processing Run Nr. 180, CESM2, NCAR, LE2-1301_008,
#
# Run time:  0 m 0.3 s
# CESM2
# Processing Run Nr. 181, CESM2, NCAR, LE2-1301_009,
#
# Run time:  0 m 0.4 s
# CESM2
# Processing Run Nr. 182, CESM2, NCAR, LE2-1301_010,
#
# Run time:  0 m 0.4 s
# CESM2
# Processing Run Nr. 183, CESM2, NCAR, LE2-1301_011,
#
# Run time:  0 m 0.3 s
# CESM2
# Processing Run Nr. 184, CESM2, NCAR, LE2-1301_012,
#
# Run time:  0 m 0.3 s
# CESM2
# Processing Run Nr. 185, CESM2, NCAR, LE2-1301_013,
#
# Run time:  0 m 0.4 s
# CESM2
# Processing Run Nr. 186, CESM2, NCAR, LE2-1301_014,
#
# Run time:  0 m 0.6 s
# CESM2
# Processing Run Nr. 187, CESM2, NCAR, LE2-1301_015,
#
# Run time:  0 m 0.4 s
# CESM2
# Processing Run Nr. 188, CESM2, NCAR, LE2-1301_016,
#
# Run time:  0 m 0.4 s
# CESM2
# Processing Run Nr. 189, CESM2, NCAR, LE2-1301_017,
#
# Run time:  0 m 0.4 s
# CESM2
# Processing Run Nr. 190, CESM2, NCAR, LE2-1301_018,
#
# Run time:  0 m 0.3 s
# CESM2
# Processing Run Nr. 191, CESM2, NCAR, LE2-1301_019,
#
# Run time:  0 m 0.4 s
# CESM2
# Processing Run Nr. 192, CESM2, NCAR, LE2-1301_020,
#
# Run time:  0 m 0.3 s

# %%
ts_output
# Out:
# <xarray.Dataset> Size: 321kB
# Dimensions:        (time: 3650)
# Coordinates:
#     crs            int64 8B 4326
#     gridtype       <U6 24B 'lonlat'
#   * time           (time) datetime64[ns] 29kB 2039-01-01 ... 2048-12-31
#     ESM            <U5 20B 'CESM2'
#     run            <U12 48B 'LE2-1301_020'
#     ESM_run        <U18 72B 'CESM2_LE2-1301_020'
#     country        float64 8B 9.0
#     period         <U7 28B 'week'
# Data variables:
#     temp           (time) float64 29kB 10.53 9.434 6.732 ... 3.702 1.779 0.5124
#     demand         (time) float64 29kB 1.386e+03 1.4e+03 ... 1.498e+03 1.514e+03
#     sfcWind        (time) float32 15kB 9.212 7.138 4.391 ... 3.958 3.397 3.844
#     rsds           (time) float32 15kB 14.61 25.63 31.22 ... 10.67 19.67 29.59
#     tas            (time) float32 15kB 10.17 9.077 6.751 ... 4.129 2.368 1.183
#     tasmax         (time) float32 15kB 12.59 11.5 9.471 6.316 ... 5.195 3.78 3.6
#     wind_off_prod  (time) float64 29kB 214.4 146.5 11.47 ... 20.56 23.87 51.63
#     wind_on_prod   (time) float64 29kB 931.7 503.4 108.1 ... 94.94 57.59 89.7
#     solar_prod     (time) float64 29kB 19.7 41.17 55.78 ... 17.47 30.85 60.56
#     total_prod     (time) float64 29kB 1.166e+03 691.1 175.3 ... 112.3 201.9
#     Netto          (time) float64 29kB -219.7 -709.3 ... -1.386e+03 -1.312e+03
#     Residual_load  (time) float64 29kB 219.7 709.3 ... 1.386e+03 1.312e+03

# %% [markdown]
# #### Some plots to check everything is alright

# %%
def setup_gridlines(ax, deg = 1, alpha = 0.4):
    gl = ax.gridlines(draw_labels=True, crs=ccrs.PlateCarree(), alpha=alpha)
    gl.top_labels = False
    gl.right_labels = False
    gl.xlabel_style = {'size': 8}
    gl.ylabel_style = {'size': 8}
    gl.xformatter = LONGITUDE_FORMATTER
    gl.yformatter = LATITUDE_FORMATTER
    gl.xlocator = MultipleLocator(deg)
    gl.ylocator = MultipleLocator(deg)

# %%
# Just a plot of one timestep of the wind and the approximated on- and offshore wind power capacity

lon_edges = combined_ds['lon'].values
lat_edges = combined_ds['lat'].values

vmin = 0 
vmax = 1

# Plot the data
timestep = 1 # 201

fig, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3, figsize=(9, 6), subplot_kw={'projection': ccrs.Robinson()})

# First subplot
ax1.coastlines()
ax1.add_feature(cfeature.BORDERS, linestyle=':', edgecolor='black')
xxx1 = combined_ds['sfcWind'].isel(time=timestep)
im1 = ax1.pcolormesh(lon_edges, lat_edges, xxx1, transform=ccrs.PlateCarree(), cmap='Reds', vmin=vmin)
setup_gridlines(ax1)
cbar1 = fig.colorbar(im1, ax=ax1, orientation='horizontal', pad=0.05, shrink=0.7, aspect=50)
ax1.set_title('Surface Wind in m/s')

# Second subplot
ax2.coastlines()
ax2.add_feature(cfeature.BORDERS, linestyle=':', edgecolor='black')
xxx2 = wepot_off['wind_off_pot'].isel(time=timestep)
im2 = ax2.pcolormesh(lon_edges, lat_edges, xxx2, transform=ccrs.PlateCarree(), cmap='Reds', vmin=vmin, vmax=vmax)
setup_gridlines(ax2)
cbar2 = fig.colorbar(im2, ax=ax2, orientation='horizontal', pad=0.05, shrink=0.7, aspect=50)
ax2.set_title('Approximated Wind Power Capacity')

# Third subplot
ax3.coastlines()
ax3.add_feature(cfeature.BORDERS, linestyle=':', edgecolor='black')
xxx3 = wepot_on['wind_on_pot'].isel(time=timestep)
im3 = ax3.pcolormesh(lon_edges, lat_edges, xxx3, transform=ccrs.PlateCarree(), cmap='Reds', vmin=vmin, vmax=vmax)
setup_gridlines(ax3)
cbar3 = fig.colorbar(im3, ax=ax3, orientation='horizontal', pad=0.05, shrink=0.7, aspect=50)
ax3.set_title('Approximated Wind Power Capacity')

plt.tight_layout()
plt.show()

# %%
# Just a plot of one timestep of the solar radiation and the approximated solar power capacity
# Filter sepot so only the grids with pv data are left (mainly for plotting)
sepot_plot = sepot.where(grid_solar > 0)

# '''
lon_edges = combined_ds['lon'].values # - (combined_ds['lon'].lon.diff(dim='lon') / 2).pad({'lon': (1, 0)}, mode='edge')
lat_edges = combined_ds['lat'].values # - (combined_ds['lat'].lat.diff(dim='lat') / 2).pad({'lat': (1, 0)}, mode='edge')

vmin = 0 
vmax = 1

# Plot the data
timestep = 90# 29937# 1# 10000 # 24507

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 6), subplot_kw={'projection': ccrs.Robinson()})

# First subplot
ax1.coastlines()
ax1.add_feature(cfeature.BORDERS, linestyle=':', edgecolor='black')
xxx1 = combined_ds['rsds'].isel(time=timestep)
im1 = ax1.pcolormesh(lon_edges, lat_edges, xxx1, transform=ccrs.PlateCarree(), cmap='Reds', vmin=vmin)
setup_gridlines(ax1)
cbar1 = fig.colorbar(im1, ax=ax1, orientation='horizontal', pad=0.05, shrink=0.7, aspect=50)
ax1.set_title('Downward Short-Wave Radiation in W/m^2')

# Second subplot
ax2.coastlines()
ax2.add_feature(cfeature.BORDERS, linestyle=':', edgecolor='black')
xxx2 = sepot_plot.isel(time=timestep)
im2 = ax2.pcolormesh(lon_edges, lat_edges, xxx2, transform=ccrs.PlateCarree(), cmap='Reds', vmin=vmin, vmax=vmax)
setup_gridlines(ax2)
cbar2 = fig.colorbar(im2, ax=ax2, orientation='horizontal', pad=0.05, shrink=0.7, aspect=50)
ax2.set_title('Approximated Solar Power Capacity')

plt.tight_layout()
plt.show()
# '''

# %%
demand_ds['demand'][0:365].plot()

# %%
# Plot time series (time against temp and demand)
fig, ax1 = plt.subplots(figsize=(12, 6))

a = 0
b = 364

# Plot temperature on the first y-axis
ax1.plot(demand_ds['time'][a:b], demand_ds['temp'][a:b], label='Temperature', color='r')
ax1.set_ylabel('Temperature [°C]', color='r')
ax1.set_xlabel('Time')
ax1.tick_params(axis='y', labelcolor='r')

# Create a second y-axis to plot demand
ax2 = ax1.twinx()
ax2.plot(demand_ds['time'][a:b], demand_ds['demand'][a:b], label='Demand', color='b')
ax2.set_ylabel('Demand [GWh]', color='b')
ax2.tick_params(axis='y', labelcolor='b')
# ax2.set_ylim(1000, 2200)  # Adjust y-axis limits for demand

fig.tight_layout()
plt.show()

# %%
# Define your slice (adjust these to your desired time range)
# a = 191 + 365 * 81
# b = 7 + 365 * 82
# a = 365 * 164
# b = 365 * 165
a = 0
b = 364
# a = 365
# b = 365 * 2

# Extract time and variables for the chosen range
time = timeseries_ds['time'][a:b]
demand = timeseries_ds['demand'][a:b]
wind_off = timeseries_ds['wind_off_prod'][a:b]
wind_on = timeseries_ds['wind_on_prod'][a:b]
solar = timeseries_ds['solar_prod'][a:b]
total_prod = timeseries_ds['total_prod'][a:b]
Residual_load = timeseries_ds['Residual_load'][a:b]

# Create the figure and axis
fig, ax = plt.subplots(figsize=(12, 6))

# Plot each variable
ax.plot(time, demand, label='Demand', color='b')
ax.plot(time, wind_off, label='Offshore Wind Production', color='g')
ax.plot(time, wind_on, label='Onshore Wind Production', color='c')
ax.plot(time, solar, label='Solar Production', color='y')
ax.plot(time, total_prod, label='Total Production', color='purple')
ax.plot(time, Residual_load, label='Residual_load', color='r')

# Labeling
ax.set_xlabel('')
ax.set_ylabel('Energy (GWh)')
ax.set_title('Time Series Plot')
ax.legend()

# Formatting
fig.tight_layout()
plt.grid(True)
plt.show()
