# %% [markdown]
# Title: sfcWind_dist_comp.ipynb
#
# Purpose: Compare the distribution of sfcWind in current and future climate
#
# Author: Onno Nennecke on 02.06.2025 Modified: 12.05.2026
#
# Input data:
#
# - sfcWind Data from CMIP
#     - These files lie here: /climca/people/onennecke/not_debiased_data/
#     - These files lie here: /climca/people/onennecke/not_debiased_data_future/
# - Used Runs File: CMIP6_runs_future.csv and CESM2_LE_runs.csv
#     - These files lie here: /home/onennecke/CMIP_models/
#
# Output data:
#
# - Some plots to compare

# %% [markdown]
# ### Load libraries and functions

# %%
# Importing libraries
import xarray as xr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import ks_2samp, wasserstein_distance
import os

# %% [markdown]
# ### Define var name

# %%
variable_name = 'sfcWind'

# %% [markdown]
# ### Read data

# %%
# Read the dataframe from the csv file
used_runs_fut = pd.read_csv('/home/onennecke/CMIP_models/CMIP6_runs_future.csv')
used_runs_CESM_LE = pd.read_csv('/home/onennecke/CMIP_models/CESM2_LE_runs.csv')


used_runs = pd.concat([used_runs_fut, used_runs_CESM_LE], ignore_index=True)
# Add one row with ERA5 using pd.concat
era5_row = pd.DataFrame([{
    'ESM': 'ERA5',
    'Institution': 'ECMWF',
    'run': 'hist'
}])
used_runs = pd.concat([used_runs, era5_row], ignore_index=True)
# Change the ref column to 1 for the first instance of each model
# used_runs['Ref'] = used_runs.groupby(['ESM', 'Institution']).cumcount().apply(lambda x: 1 if x == 0 else 0)

ESMs = used_runs['ESM'].unique()

# %%
base_path_fut = '/climca/people/onennecke/not_debiased_data_future/'
base_path_cur = '/climca/people/onennecke/not_debiased_data/'

# Build a list of file names from the used_runs dataframe
file_names = []
for index, row in used_runs.iterrows():
    esm = row['ESM']
    # institution = row['Institution']
    run = row['run']
    
    # Construct the file name based on the ESM, institution, and run
    file_name_pattern = f'{esm}_{run}_{variable_name}.nc'
    
    # Append the file name pattern to the list
    file_names.append(file_name_pattern)
# file_names

# %%
# Load installed capacity data
grid_offshore = xr.open_dataset('/climca/people/onennecke/Wind_Solar_MaStR/processed_data/wind_offshore_ic.nc')
grid_offshore = grid_offshore['wind_off_cap']
mask_offshore = xr.where(np.isfinite(grid_offshore), 1, 0)
grid_onshore = xr.open_dataset('/climca/people/onennecke/Wind_Solar_MaStR/processed_data/wind_onshore_ic.nc')
grid_onshore = grid_onshore['wind_on_cap']
mask_onshore = xr.where(np.isfinite(grid_onshore), 1, 0)
grid_solar = xr.open_dataset('/climca/people/onennecke/Wind_Solar_MaStR/processed_data/solar_ic_netto.nc')
# grid_solar = xr.open_dataset('/climca/people/onennecke/Wind_Solar_MaStR/processed_data/solar_ic.nc')
grid_solar = grid_solar['solar_cap']
mask_solar = xr.where(np.isfinite(grid_solar), 1, 0)
population = xr.open_dataset('/climca/people/onennecke/population_data/population_regrid_weights.nc')
population = population['population']
mask_population = xr.where(np.isfinite(population), 1, 0)
# Overall mask
overall_mask = mask_offshore + mask_onshore + mask_solar + mask_population
overall_mask = xr.where(overall_mask > 0, 1, 0)

# %%
ds_list = []
counter = 1
for file_name in file_names:
    file_path = os.path.join(base_path_cur, file_name)
    print(f'{counter}/{len(file_names)}: Processing file: {file_path}')
    if os.path.exists(file_path):
        ds = xr.open_dataset(file_path)
        esm_run = ds.ESM_run.values
        if '_LE2' in str(esm_run):
            esm_run = str(esm_run).replace('_LE2', '')
            ds["ESM"] = "CESM2"
        # Select only 6 winter months (October to March)
        ds = ds.sel(time=ds['time.month'].isin([10, 11, 12, 1, 2, 3]))
        # Mask the data with the overall mask
        ds = ds.where(overall_mask == 1)        
        # Calculate the spatial mean over the dimension
        mean_ds = ds.mean(dim=['lat', 'lon'], keep_attrs=True)
        
        ts_output = mean_ds.expand_dims(ESM_run=[esm_run]).assign_coords(ESM_run=[esm_run])
        ds_list.append(ts_output)
    else:
        print(f'File not found: {file_path}')
    counter += 1
esm_ds_cur = xr.concat(ds_list, dim="ESM_run")

ds_list = []
counter = 1
for file_name in file_names:
    file_path = os.path.join(base_path_fut, file_name)
    print(f'{counter}/{len(file_names)}: Processing file: {file_path}')
    if os.path.exists(file_path):
        ds = xr.open_dataset(file_path)
        esm_run = ds.ESM_run.values
        if '_LE2' in str(esm_run):
            esm_run = str(esm_run).replace('_LE2', '')
            ds["ESM"] = "CESM2"
        # Select only 6 winter months (October to March)
        ds = ds.sel(time=ds['time.month'].isin([10, 11, 12, 1, 2, 3]))
        # Mask the data with the overall mask
        ds = ds.where(overall_mask == 1)        
        # Calculate the spatial mean over the dimension
        mean_ds = ds.mean(dim=['lat', 'lon'], keep_attrs=True)

        ts_output = mean_ds.expand_dims(ESM_run=[esm_run]).assign_coords(ESM_run=[esm_run])
        ds_list.append(ts_output)
    else:
        print(f'File not found: {file_path}')
    counter += 1
esm_ds_fut = xr.concat(ds_list, dim="ESM_run")
# Out:
# 1/193: Processing file: /climca/people/onennecke/not_debiased_data/ACCESS-CM2_r4i1p1f1_sfcWind.nc
# 2/193: Processing file: /climca/people/onennecke/not_debiased_data/ACCESS-CM2_r5i1p1f1_sfcWind.nc
# 3/193: Processing file: /climca/people/onennecke/not_debiased_data/ACCESS-CM2_r1i1p1f1_sfcWind.nc
# 4/193: Processing file: /climca/people/onennecke/not_debiased_data/BCC-CSM2-MR_r1i1p1f1_sfcWind.nc
# 5/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_r4i1p1f1_sfcWind.nc
# 6/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_r10i1p1f1_sfcWind.nc
# 7/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_r11i1p1f1_sfcWind.nc
# 8/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r149i1p1f1_sfcWind.nc
# 9/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r4i1p1f1_sfcWind.nc
# 10/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r148i1p1f1_sfcWind.nc
# 11/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r105i1p1f1_sfcWind.nc
# 12/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r134i1p1f1_sfcWind.nc
# 13/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r141i1p1f1_sfcWind.nc
# 14/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r146i1p1f1_sfcWind.nc
# 15/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r112i1p1f1_sfcWind.nc
# 16/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r117i1p1f1_sfcWind.nc
# 17/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r125i1p1f1_sfcWind.nc
# 18/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r113i1p1f1_sfcWind.nc
# 19/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r106i1p1f1_sfcWind.nc
# 20/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r138i1p1f1_sfcWind.nc
# 21/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r5i1p1f1_sfcWind.nc
# 22/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r137i1p1f1_sfcWind.nc
# 23/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r145i1p1f1_sfcWind.nc
# 24/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r114i1p1f1_sfcWind.nc
# 25/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r120i1p1f1_sfcWind.nc
# 26/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r128i1p1f1_sfcWind.nc
# 27/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r135i1p1f1_sfcWind.nc
# 28/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r110i1p1f1_sfcWind.nc
# 29/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r129i1p1f1_sfcWind.nc
# 30/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r132i1p1f1_sfcWind.nc
# 31/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r101i1p1f1_sfcWind.nc
# 32/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r124i1p1f1_sfcWind.nc
# 33/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r127i1p1f1_sfcWind.nc
# 34/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r116i1p1f1_sfcWind.nc
# 35/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r131i1p1f1_sfcWind.nc
# 36/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r121i1p1f1_sfcWind.nc
# 37/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r142i1p1f1_sfcWind.nc
# 38/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r102i1p1f1_sfcWind.nc
# 39/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r133i1p1f1_sfcWind.nc
# 40/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r111i1p1f1_sfcWind.nc
# 41/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r140i1p1f1_sfcWind.nc
# 42/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r136i1p1f1_sfcWind.nc
# 43/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r108i1p1f1_sfcWind.nc
# 44/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r130i1p1f1_sfcWind.nc
# 45/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r150i1p1f1_sfcWind.nc
# 46/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r104i1p1f1_sfcWind.nc
# 47/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r118i1p1f1_sfcWind.nc
# 48/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r109i1p1f1_sfcWind.nc
# 49/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r143i1p1f1_sfcWind.nc
# 50/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r147i1p1f1_sfcWind.nc
# 51/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r3i1p1f1_sfcWind.nc
# 52/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r126i1p1f1_sfcWind.nc
# 53/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r119i1p1f1_sfcWind.nc
# 54/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r1i1p1f1_sfcWind.nc
# 55/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r123i1p1f1_sfcWind.nc
# 56/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r122i1p1f1_sfcWind.nc
# 57/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r115i1p1f1_sfcWind.nc
# 58/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r103i1p1f1_sfcWind.nc
# 59/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r144i1p1f1_sfcWind.nc
# 60/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r139i1p1f1_sfcWind.nc
# 61/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r107i1p1f1_sfcWind.nc
# 62/193: Processing file: /climca/people/onennecke/not_debiased_data/GFDL-ESM4_r1i1p1f1_sfcWind.nc
# 63/193: Processing file: /climca/people/onennecke/not_debiased_data/KACE-1-0-G_r2i1p1f1_sfcWind.nc
# 64/193: Processing file: /climca/people/onennecke/not_debiased_data/KACE-1-0-G_r3i1p1f1_sfcWind.nc
# 65/193: Processing file: /climca/people/onennecke/not_debiased_data/KACE-1-0-G_r1i1p1f1_sfcWind.nc
# 66/193: Processing file: /climca/people/onennecke/not_debiased_data/MPI-ESM1-2-HR_r6i1p1f1_sfcWind.nc
# 67/193: Processing file: /climca/people/onennecke/not_debiased_data/MPI-ESM1-2-HR_r4i1p1f1_sfcWind.nc
# 68/193: Processing file: /climca/people/onennecke/not_debiased_data/MPI-ESM1-2-HR_r9i1p1f1_sfcWind.nc
# 69/193: Processing file: /climca/people/onennecke/not_debiased_data/MPI-ESM1-2-HR_r10i1p1f1_sfcWind.nc
# 70/193: Processing file: /climca/people/onennecke/not_debiased_data/MPI-ESM1-2-HR_r5i1p1f1_sfcWind.nc
# 71/193: Processing file: /climca/people/onennecke/not_debiased_data/MPI-ESM1-2-HR_r8i1p1f1_sfcWind.nc
# 72/193: Processing file: /climca/people/onennecke/not_debiased_data/MPI-ESM1-2-HR_r2i1p1f1_sfcWind.nc
# 73/193: Processing file: /climca/people/onennecke/not_debiased_data/MPI-ESM1-2-HR_r7i1p1f1_sfcWind.nc
# 74/193: Processing file: /climca/people/onennecke/not_debiased_data/MPI-ESM1-2-HR_r3i1p1f1_sfcWind.nc
# 75/193: Processing file: /climca/people/onennecke/not_debiased_data/MPI-ESM1-2-HR_r1i1p1f1_sfcWind.nc
# 76/193: Processing file: /climca/people/onennecke/not_debiased_data/MRI-ESM2-0_r4i1p1f1_sfcWind.nc
# 77/193: Processing file: /climca/people/onennecke/not_debiased_data/MRI-ESM2-0_r5i1p1f1_sfcWind.nc
# 78/193: Processing file: /climca/people/onennecke/not_debiased_data/MRI-ESM2-0_r2i1p1f1_sfcWind.nc
# 79/193: Processing file: /climca/people/onennecke/not_debiased_data/MRI-ESM2-0_r3i1p1f1_sfcWind.nc
# 80/193: Processing file: /climca/people/onennecke/not_debiased_data/MRI-ESM2-0_r1i1p1f1_sfcWind.nc
# 81/193: Processing file: /climca/people/onennecke/not_debiased_data/TaiESM1_r1i1p1f1_sfcWind.nc
# 82/193: Processing file: /climca/people/onennecke/not_debiased_data/UKESM1-0-LL_r4i1p1f2_sfcWind.nc
# 83/193: Processing file: /climca/people/onennecke/not_debiased_data/UKESM1-0-LL_r1i1p1f2_sfcWind.nc
# 84/193: Processing file: /climca/people/onennecke/not_debiased_data/UKESM1-0-LL_r7i1p1f2_sfcWind.nc
# 85/193: Processing file: /climca/people/onennecke/not_debiased_data/UKESM1-0-LL_r6i1p1f2_sfcWind.nc
# 86/193: Processing file: /climca/people/onennecke/not_debiased_data/UKESM1-0-LL_r2i1p1f2_sfcWind.nc
# 87/193: Processing file: /climca/people/onennecke/not_debiased_data/UKESM1-0-LL_r5i1p1f2_sfcWind.nc
# 88/193: Processing file: /climca/people/onennecke/not_debiased_data/UKESM1-0-LL_r3i1p1f2_sfcWind.nc
# 89/193: Processing file: /climca/people/onennecke/not_debiased_data/UKESM1-0-LL_r8i1p1f2_sfcWind.nc
# 90/193: Processing file: /climca/people/onennecke/not_debiased_data/UKESM1-0-LL_r15i1p1f2_sfcWind.nc
# 91/193: Processing file: /climca/people/onennecke/not_debiased_data/UKESM1-0-LL_r13i1p1f2_sfcWind.nc
# 92/193: Processing file: /climca/people/onennecke/not_debiased_data/UKESM1-0-LL_r14i1p1f2_sfcWind.nc
# 93/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1001_001_sfcWind.nc
# 94/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1011_001_sfcWind.nc
# 95/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1021_002_sfcWind.nc
# 96/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1031_002_sfcWind.nc
# 97/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1041_003_sfcWind.nc
# 98/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1051_003_sfcWind.nc
# 99/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1061_004_sfcWind.nc
# 100/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1071_004_sfcWind.nc
# 101/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1081_005_sfcWind.nc
# 102/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1091_005_sfcWind.nc
# 103/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1101_006_sfcWind.nc
# 104/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1111_006_sfcWind.nc
# 105/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1121_007_sfcWind.nc
# 106/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1131_007_sfcWind.nc
# 107/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1141_008_sfcWind.nc
# 108/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1151_008_sfcWind.nc
# 109/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1161_009_sfcWind.nc
# 110/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1171_009_sfcWind.nc
# 111/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1181_010_sfcWind.nc
# 112/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1191_010_sfcWind.nc
# 113/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1231_001_sfcWind.nc
# 114/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1231_002_sfcWind.nc
# 115/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1231_003_sfcWind.nc
# 116/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1231_004_sfcWind.nc
# 117/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1231_005_sfcWind.nc
# 118/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1231_006_sfcWind.nc
# 119/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1231_007_sfcWind.nc
# 120/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1231_008_sfcWind.nc
# 121/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1231_009_sfcWind.nc
# 122/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1231_010_sfcWind.nc
# 123/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1231_011_sfcWind.nc
# 124/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1231_012_sfcWind.nc
# 125/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1231_013_sfcWind.nc
# 126/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1231_014_sfcWind.nc
# 127/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1231_015_sfcWind.nc
# 128/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1231_016_sfcWind.nc
# 129/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1231_017_sfcWind.nc
# 130/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1231_018_sfcWind.nc
# 131/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1231_019_sfcWind.nc
# 132/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1231_020_sfcWind.nc
# 133/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1251_001_sfcWind.nc
# 134/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1251_002_sfcWind.nc
# 135/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1251_003_sfcWind.nc
# 136/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1251_004_sfcWind.nc
# 137/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1251_005_sfcWind.nc
# 138/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1251_006_sfcWind.nc
# 139/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1251_007_sfcWind.nc
# 140/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1251_008_sfcWind.nc
# 141/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1251_009_sfcWind.nc
# 142/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1251_010_sfcWind.nc
# 143/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1251_011_sfcWind.nc
# 144/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1251_012_sfcWind.nc
# 145/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1251_013_sfcWind.nc
# 146/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1251_014_sfcWind.nc
# 147/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1251_015_sfcWind.nc
# 148/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1251_016_sfcWind.nc
# 149/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1251_017_sfcWind.nc
# 150/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1251_018_sfcWind.nc
# 151/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1251_019_sfcWind.nc
# 152/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1251_020_sfcWind.nc
# 153/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1281_001_sfcWind.nc
# 154/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1281_002_sfcWind.nc
# 155/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1281_003_sfcWind.nc
# 156/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1281_004_sfcWind.nc
# 157/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1281_005_sfcWind.nc
# 158/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1281_006_sfcWind.nc
# 159/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1281_007_sfcWind.nc
# 160/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1281_008_sfcWind.nc
# 161/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1281_009_sfcWind.nc
# 162/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1281_010_sfcWind.nc
# 163/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1281_011_sfcWind.nc
# 164/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1281_012_sfcWind.nc
# 165/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1281_013_sfcWind.nc
# 166/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1281_014_sfcWind.nc
# 167/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1281_015_sfcWind.nc
# 168/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1281_016_sfcWind.nc
# 169/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1281_017_sfcWind.nc
# 170/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1281_018_sfcWind.nc
# 171/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1281_019_sfcWind.nc
# 172/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1281_020_sfcWind.nc
# 173/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1301_001_sfcWind.nc
# 174/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1301_002_sfcWind.nc
# 175/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1301_003_sfcWind.nc
# 176/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1301_004_sfcWind.nc
# 177/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1301_005_sfcWind.nc
# 178/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1301_006_sfcWind.nc
# 179/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1301_007_sfcWind.nc
# 180/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1301_008_sfcWind.nc
# 181/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1301_009_sfcWind.nc
# 182/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1301_010_sfcWind.nc
# 183/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1301_011_sfcWind.nc
# 184/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1301_012_sfcWind.nc
# 185/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1301_013_sfcWind.nc
# 186/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1301_014_sfcWind.nc
# 187/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1301_015_sfcWind.nc
# 188/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1301_016_sfcWind.nc
# 189/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1301_017_sfcWind.nc
# 190/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1301_018_sfcWind.nc
# 191/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1301_019_sfcWind.nc
# 192/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1301_020_sfcWind.nc
# 193/193: Processing file: /climca/people/onennecke/not_debiased_data/ERA5_hist_sfcWind.nc
# 1/193: Processing file: /climca/people/onennecke/not_debiased_data_future/ACCESS-CM2_r4i1p1f1_sfcWind.nc
# 2/193: Processing file: /climca/people/onennecke/not_debiased_data_future/ACCESS-CM2_r5i1p1f1_sfcWind.nc
# 3/193: Processing file: /climca/people/onennecke/not_debiased_data_future/ACCESS-CM2_r1i1p1f1_sfcWind.nc
# 4/193: Processing file: /climca/people/onennecke/not_debiased_data_future/BCC-CSM2-MR_r1i1p1f1_sfcWind.nc
# 5/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_r4i1p1f1_sfcWind.nc
# 6/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_r10i1p1f1_sfcWind.nc
# 7/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_r11i1p1f1_sfcWind.nc
# 8/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r149i1p1f1_sfcWind.nc
# 9/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r4i1p1f1_sfcWind.nc
# 10/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r148i1p1f1_sfcWind.nc
# 11/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r105i1p1f1_sfcWind.nc
# 12/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r134i1p1f1_sfcWind.nc
# 13/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r141i1p1f1_sfcWind.nc
# 14/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r146i1p1f1_sfcWind.nc
# 15/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r112i1p1f1_sfcWind.nc
# 16/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r117i1p1f1_sfcWind.nc
# 17/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r125i1p1f1_sfcWind.nc
# 18/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r113i1p1f1_sfcWind.nc
# 19/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r106i1p1f1_sfcWind.nc
# 20/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r138i1p1f1_sfcWind.nc
# 21/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r5i1p1f1_sfcWind.nc
# 22/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r137i1p1f1_sfcWind.nc
# 23/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r145i1p1f1_sfcWind.nc
# 24/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r114i1p1f1_sfcWind.nc
# 25/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r120i1p1f1_sfcWind.nc
# 26/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r128i1p1f1_sfcWind.nc
# 27/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r135i1p1f1_sfcWind.nc
# 28/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r110i1p1f1_sfcWind.nc
# 29/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r129i1p1f1_sfcWind.nc
# 30/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r132i1p1f1_sfcWind.nc
# 31/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r101i1p1f1_sfcWind.nc
# 32/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r124i1p1f1_sfcWind.nc
# 33/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r127i1p1f1_sfcWind.nc
# 34/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r116i1p1f1_sfcWind.nc
# 35/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r131i1p1f1_sfcWind.nc
# 36/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r121i1p1f1_sfcWind.nc
# 37/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r142i1p1f1_sfcWind.nc
# 38/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r102i1p1f1_sfcWind.nc
# 39/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r133i1p1f1_sfcWind.nc
# 40/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r111i1p1f1_sfcWind.nc
# 41/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r140i1p1f1_sfcWind.nc
# 42/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r136i1p1f1_sfcWind.nc
# 43/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r108i1p1f1_sfcWind.nc
# 44/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r130i1p1f1_sfcWind.nc
# 45/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r150i1p1f1_sfcWind.nc
# 46/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r104i1p1f1_sfcWind.nc
# 47/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r118i1p1f1_sfcWind.nc
# 48/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r109i1p1f1_sfcWind.nc
# 49/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r143i1p1f1_sfcWind.nc
# 50/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r147i1p1f1_sfcWind.nc
# 51/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r3i1p1f1_sfcWind.nc
# 52/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r126i1p1f1_sfcWind.nc
# 53/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r119i1p1f1_sfcWind.nc
# 54/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r1i1p1f1_sfcWind.nc
# 55/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r123i1p1f1_sfcWind.nc
# 56/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r122i1p1f1_sfcWind.nc
# 57/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r115i1p1f1_sfcWind.nc
# 58/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r103i1p1f1_sfcWind.nc
# 59/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r144i1p1f1_sfcWind.nc
# 60/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r139i1p1f1_sfcWind.nc
# 61/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r107i1p1f1_sfcWind.nc
# 62/193: Processing file: /climca/people/onennecke/not_debiased_data_future/GFDL-ESM4_r1i1p1f1_sfcWind.nc
# 63/193: Processing file: /climca/people/onennecke/not_debiased_data_future/KACE-1-0-G_r2i1p1f1_sfcWind.nc
# 64/193: Processing file: /climca/people/onennecke/not_debiased_data_future/KACE-1-0-G_r3i1p1f1_sfcWind.nc
# 65/193: Processing file: /climca/people/onennecke/not_debiased_data_future/KACE-1-0-G_r1i1p1f1_sfcWind.nc
# 66/193: Processing file: /climca/people/onennecke/not_debiased_data_future/MPI-ESM1-2-HR_r6i1p1f1_sfcWind.nc
# 67/193: Processing file: /climca/people/onennecke/not_debiased_data_future/MPI-ESM1-2-HR_r4i1p1f1_sfcWind.nc
# 68/193: Processing file: /climca/people/onennecke/not_debiased_data_future/MPI-ESM1-2-HR_r9i1p1f1_sfcWind.nc
# 69/193: Processing file: /climca/people/onennecke/not_debiased_data_future/MPI-ESM1-2-HR_r10i1p1f1_sfcWind.nc
# 70/193: Processing file: /climca/people/onennecke/not_debiased_data_future/MPI-ESM1-2-HR_r5i1p1f1_sfcWind.nc
# 71/193: Processing file: /climca/people/onennecke/not_debiased_data_future/MPI-ESM1-2-HR_r8i1p1f1_sfcWind.nc
# 72/193: Processing file: /climca/people/onennecke/not_debiased_data_future/MPI-ESM1-2-HR_r2i1p1f1_sfcWind.nc
# 73/193: Processing file: /climca/people/onennecke/not_debiased_data_future/MPI-ESM1-2-HR_r7i1p1f1_sfcWind.nc
# 74/193: Processing file: /climca/people/onennecke/not_debiased_data_future/MPI-ESM1-2-HR_r3i1p1f1_sfcWind.nc
# 75/193: Processing file: /climca/people/onennecke/not_debiased_data_future/MPI-ESM1-2-HR_r1i1p1f1_sfcWind.nc
# 76/193: Processing file: /climca/people/onennecke/not_debiased_data_future/MRI-ESM2-0_r4i1p1f1_sfcWind.nc
# 77/193: Processing file: /climca/people/onennecke/not_debiased_data_future/MRI-ESM2-0_r5i1p1f1_sfcWind.nc
# 78/193: Processing file: /climca/people/onennecke/not_debiased_data_future/MRI-ESM2-0_r2i1p1f1_sfcWind.nc
# 79/193: Processing file: /climca/people/onennecke/not_debiased_data_future/MRI-ESM2-0_r3i1p1f1_sfcWind.nc
# 80/193: Processing file: /climca/people/onennecke/not_debiased_data_future/MRI-ESM2-0_r1i1p1f1_sfcWind.nc
# 81/193: Processing file: /climca/people/onennecke/not_debiased_data_future/TaiESM1_r1i1p1f1_sfcWind.nc
# 82/193: Processing file: /climca/people/onennecke/not_debiased_data_future/UKESM1-0-LL_r4i1p1f2_sfcWind.nc
# 83/193: Processing file: /climca/people/onennecke/not_debiased_data_future/UKESM1-0-LL_r1i1p1f2_sfcWind.nc
# 84/193: Processing file: /climca/people/onennecke/not_debiased_data_future/UKESM1-0-LL_r7i1p1f2_sfcWind.nc
# 85/193: Processing file: /climca/people/onennecke/not_debiased_data_future/UKESM1-0-LL_r6i1p1f2_sfcWind.nc
# 86/193: Processing file: /climca/people/onennecke/not_debiased_data_future/UKESM1-0-LL_r2i1p1f2_sfcWind.nc
# 87/193: Processing file: /climca/people/onennecke/not_debiased_data_future/UKESM1-0-LL_r5i1p1f2_sfcWind.nc
# 88/193: Processing file: /climca/people/onennecke/not_debiased_data_future/UKESM1-0-LL_r3i1p1f2_sfcWind.nc
# 89/193: Processing file: /climca/people/onennecke/not_debiased_data_future/UKESM1-0-LL_r8i1p1f2_sfcWind.nc
# 90/193: Processing file: /climca/people/onennecke/not_debiased_data_future/UKESM1-0-LL_r15i1p1f2_sfcWind.nc
# 91/193: Processing file: /climca/people/onennecke/not_debiased_data_future/UKESM1-0-LL_r13i1p1f2_sfcWind.nc
# 92/193: Processing file: /climca/people/onennecke/not_debiased_data_future/UKESM1-0-LL_r14i1p1f2_sfcWind.nc
# 93/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1001_001_sfcWind.nc
# 94/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1011_001_sfcWind.nc
# 95/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1021_002_sfcWind.nc
# 96/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1031_002_sfcWind.nc
# 97/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1041_003_sfcWind.nc
# 98/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1051_003_sfcWind.nc
# 99/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1061_004_sfcWind.nc
# 100/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1071_004_sfcWind.nc
# 101/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1081_005_sfcWind.nc
# 102/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1091_005_sfcWind.nc
# 103/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1101_006_sfcWind.nc
# 104/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1111_006_sfcWind.nc
# 105/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1121_007_sfcWind.nc
# 106/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1131_007_sfcWind.nc
# 107/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1141_008_sfcWind.nc
# 108/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1151_008_sfcWind.nc
# 109/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1161_009_sfcWind.nc
# 110/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1171_009_sfcWind.nc
# 111/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1181_010_sfcWind.nc
# 112/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1191_010_sfcWind.nc
# 113/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1231_001_sfcWind.nc
# 114/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1231_002_sfcWind.nc
# 115/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1231_003_sfcWind.nc
# 116/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1231_004_sfcWind.nc
# 117/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1231_005_sfcWind.nc
# 118/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1231_006_sfcWind.nc
# 119/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1231_007_sfcWind.nc
# 120/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1231_008_sfcWind.nc
# 121/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1231_009_sfcWind.nc
# 122/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1231_010_sfcWind.nc
# 123/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1231_011_sfcWind.nc
# 124/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1231_012_sfcWind.nc
# 125/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1231_013_sfcWind.nc
# 126/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1231_014_sfcWind.nc
# 127/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1231_015_sfcWind.nc
# 128/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1231_016_sfcWind.nc
# 129/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1231_017_sfcWind.nc
# 130/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1231_018_sfcWind.nc
# 131/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1231_019_sfcWind.nc
# 132/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1231_020_sfcWind.nc
# 133/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1251_001_sfcWind.nc
# 134/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1251_002_sfcWind.nc
# 135/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1251_003_sfcWind.nc
# 136/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1251_004_sfcWind.nc
# 137/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1251_005_sfcWind.nc
# 138/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1251_006_sfcWind.nc
# 139/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1251_007_sfcWind.nc
# 140/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1251_008_sfcWind.nc
# 141/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1251_009_sfcWind.nc
# 142/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1251_010_sfcWind.nc
# 143/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1251_011_sfcWind.nc
# 144/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1251_012_sfcWind.nc
# 145/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1251_013_sfcWind.nc
# 146/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1251_014_sfcWind.nc
# 147/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1251_015_sfcWind.nc
# 148/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1251_016_sfcWind.nc
# 149/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1251_017_sfcWind.nc
# 150/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1251_018_sfcWind.nc
# 151/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1251_019_sfcWind.nc
# 152/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1251_020_sfcWind.nc
# 153/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1281_001_sfcWind.nc
# 154/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1281_002_sfcWind.nc
# 155/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1281_003_sfcWind.nc
# 156/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1281_004_sfcWind.nc
# 157/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1281_005_sfcWind.nc
# 158/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1281_006_sfcWind.nc
# 159/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1281_007_sfcWind.nc
# 160/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1281_008_sfcWind.nc
# 161/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1281_009_sfcWind.nc
# 162/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1281_010_sfcWind.nc
# 163/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1281_011_sfcWind.nc
# 164/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1281_012_sfcWind.nc
# 165/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1281_013_sfcWind.nc
# 166/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1281_014_sfcWind.nc
# 167/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1281_015_sfcWind.nc
# 168/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1281_016_sfcWind.nc
# 169/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1281_017_sfcWind.nc
# 170/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1281_018_sfcWind.nc
# 171/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1281_019_sfcWind.nc
# 172/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1281_020_sfcWind.nc
# 173/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1301_001_sfcWind.nc
# 174/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1301_002_sfcWind.nc
# 175/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1301_003_sfcWind.nc
# 176/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1301_004_sfcWind.nc
# 177/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1301_005_sfcWind.nc
# 178/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1301_006_sfcWind.nc
# 179/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1301_007_sfcWind.nc
# 180/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1301_008_sfcWind.nc
# 181/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1301_009_sfcWind.nc
# 182/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1301_010_sfcWind.nc
# 183/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1301_011_sfcWind.nc
# 184/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1301_012_sfcWind.nc
# 185/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1301_013_sfcWind.nc
# 186/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1301_014_sfcWind.nc
# 187/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1301_015_sfcWind.nc
# 188/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1301_016_sfcWind.nc
# 189/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1301_017_sfcWind.nc
# 190/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1301_018_sfcWind.nc
# 191/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1301_019_sfcWind.nc
# 192/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1301_020_sfcWind.nc
# 193/193: Processing file: /climca/people/onennecke/not_debiased_data_future/ERA5_hist_sfcWind.nc
# File not found: /climca/people/onennecke/not_debiased_data_future/ERA5_hist_sfcWind.nc

# %%
# Save the datasets to NetCDF files
esm_ds_cur.to_netcdf(f'/climca/people/onennecke/model_output/var_means_masked/winter_data_condensed/{variable_name}_sp_mean_mask_ex_ws_cur.nc')
esm_ds_fut.to_netcdf(f'/climca/people/onennecke/model_output/var_means_masked/winter_data_condensed/{variable_name}_sp_mean_mask_ex_ws_fut.nc')

# %%
esm_ds_cur
# Out:
# <xarray.Dataset> Size: 3MB
# Dimensions:   (ESM_run: 193, time: 1820)
# Coordinates:
#     crs       int64 8B 4326
#     gridtype  <U6 24B 'lonlat'
#   * time      (time) datetime64[ns] 15kB 2015-01-01 2015-01-02 ... 2024-12-31
#     ESM       (ESM_run) <U13 10kB 'ACCESS-CM2' 'ACCESS-CM2' ... 'CESM2' 'ERA5'
#     run       (ESM_run) <U12 9kB 'r4i1p1f1' 'r5i1p1f1' ... 'LE2-1301_020' 'hist'
#     country   float64 8B 9.0
#   * ESM_run   (ESM_run) <U23 18kB 'ACCESS-CM2_r4i1p1f1' ... 'ERA5_hist'
# Data variables:
#     sfcWind   (ESM_run, time) float64 3MB 8.243 7.762 7.568 ... 8.049 8.775

# %%
192*1820
# Out:
# 349440

# %%
esm_ds_fut
# Out:
# <xarray.Dataset> Size: 7MB
# Dimensions:   (ESM_run: 192, time: 4550)
# Coordinates:
#   * time      (time) datetime64[ns] 36kB 2030-01-01 2030-01-02 ... 2054-12-31
#   * ESM_run   (ESM_run) <U23 18kB 'ACCESS-CM2_r4i1p1f1' ... 'CESM2_LE_LE2-130...
#     crs       int64 8B 4326
#     gridtype  <U6 24B 'lonlat'
#     ESM       (ESM_run) <U13 10kB 'ACCESS-CM2' 'ACCESS-CM2' ... 'CESM2_LE'
#     run       (ESM_run) <U12 9kB 'r4i1p1f1' 'r5i1p1f1' ... 'LE2-1301_020'
#     country   float64 8B 9.0
# Data variables:
#     sfcWind   (ESM_run, time) float64 7MB nan nan nan nan ... nan nan nan nan

# %%
np.unique(esm_ds_cur.ESM.values)
# Out:
# array(['ACCESS-CM2', 'BCC-CSM2-MR', 'CESM2', 'CESM2_LE', 'EC-Earth3',
#        'GFDL-ESM4', 'KACE-1-0-G', 'MPI-ESM1-2-HR', 'MRI-ESM2-0',
#        'TaiESM1', 'UKESM1-0-LL'], dtype='<U13')

# %%
esm_data_cur_dict = {}
esm_data_fut_dict = {}

esm_data_cur_dict['All ESMs'] = esm_ds_cur[variable_name].values.ravel()
esm_data_fut = esm_ds_fut[variable_name].values.ravel()
esm_data_fut = esm_data_fut[~np.isnan(esm_data_fut)]
esm_data_fut_dict['All ESMs'] = esm_data_fut

for esm in np.unique(esm_ds_cur.ESM.values):
    esm_data_cur = esm_ds_cur.where(esm_ds_cur.ESM == esm)[variable_name].values.ravel()
    esm_data_cur = esm_data_cur[~np.isnan(esm_data_cur)]
    esm_data_cur_dict[esm] = esm_data_cur
    esm_data_fut = esm_ds_fut.where(esm_ds_fut.ESM == esm)[variable_name].values.ravel()
    esm_data_fut = esm_data_fut[~np.isnan(esm_data_fut)]
    esm_data_fut_dict[esm] = esm_data_fut
    # break

# %%
esm_data_cur_dict.keys()

for key in esm_data_cur_dict.keys():
    print(f'{key}: {len(esm_data_cur_dict[key])} values')
    print(f'{key}: {len(esm_data_cur_dict[key]) / 1820} values')
# Out:
# All ESMs: 351260 values
# All ESMs: 193.0 values
# ACCESS-CM2: 5460 values
# ACCESS-CM2: 3.0 values
# BCC-CSM2-MR: 1820 values
# BCC-CSM2-MR: 1.0 values
# CESM2: 187460 values
# CESM2: 103.0 values
# EC-Earth3: 98280 values
# EC-Earth3: 54.0 values
# ERA5: 1820 values
# ERA5: 1.0 values
# GFDL-ESM4: 1820 values
# GFDL-ESM4: 1.0 values
# KACE-1-0-G: 5460 values
# KACE-1-0-G: 3.0 values
# MPI-ESM1-2-HR: 18200 values
# MPI-ESM1-2-HR: 10.0 values
# MRI-ESM2-0: 9100 values
# MRI-ESM2-0: 5.0 values
# TaiESM1: 1820 values
# TaiESM1: 1.0 values
# UKESM1-0-LL: 20020 values
# UKESM1-0-LL: 11.0 values

# %%
all_keys = list(esm_data_cur_dict.keys())

n = len(all_keys)

# %%
# Plot a boxplot for each ESM for current and future data
plt.figure(figsize=(15, 6))
plt.subplot(1, 2, 1)
sns.boxplot(data=[esm_data_cur_dict[key] for key in all_keys], showfliers=True)
plt.xticks(ticks=np.arange(n), labels=all_keys, rotation=90)
plt.title('Current Data')
plt.ylabel(variable_name)
# Out:
# Text(0, 0.5, 'sfcWind')

# %%
import numpy as np
import pandas as pd
from scipy.stats import ks_2samp

rows = []

for esm in all_keys:
    cur = esm_data_cur_dict[esm]
    fut = esm_data_fut_dict[esm]

    ks_stat, ks_p = ks_2samp(cur, fut)

    rows.append({
        'ESM': esm,
        'Current Mean': np.mean(cur),
        'Future Mean': np.mean(fut),
        'Delta Mean': np.mean(fut) - np.mean(cur),
        'Delta Mean (%)': (np.mean(fut) - np.mean(cur)) / np.mean(cur) * 100,
        'Current Std': np.std(cur),
        'Future Std': np.std(fut),
        'Delta Std': np.std(fut) - np.std(cur),
        'Delta Std (%)': (np.std(fut) - np.std(cur)) / np.std(cur) * 100,
        'KS Statistic': ks_stat,
        'KS p-value': ks_p,
        # 'Wasserstein': wasserstein_distance(cur, fut),
    })

# Convert to DataFrame for easy mean calculation
df = pd.DataFrame(rows)

# Filter out any existing 'All' or 'All_weighted' rows before calculating the weighted average
df_esm_only = df[~df['ESM'].isin(['All ESMs', 'All_weighted'])]

# Append the All_weighted row (only using ESM data)
# rows.append({
#     'ESM': 'All (weighted)',
#     'Current Mean': df_esm_only['Current Mean'].mean(),
#     'Future Mean': df_esm_only['Future Mean'].mean(),
#     'Delta Mean': df_esm_only['Future Mean'].mean() - df_esm_only['Current Mean'].mean(),
#     'Delta Mean (%)': (df_esm_only['Future Mean'].mean() - df_esm_only['Current Mean'].mean()) / df_esm_only['Current Mean'].mean() * 100,
#     'Current Std': df_esm_only['Current Std'].mean(),
#     'Future Std': df_esm_only['Future Std'].mean(),
#     'Delta Std': df_esm_only['Future Std'].mean() - df_esm_only['Current Std'].mean(),
#     'Delta Std (%)': (df_esm_only['Future Std'].mean() - df_esm_only['Current Std'].mean()) / df_esm_only['Current Std'].mean() * 100,
#     'KS Statistic': df_esm_only['KS Statistic'].mean(),
#     'KS p-value': df_esm_only['KS p-value'].mean(),
#     # 'Wasserstein': df_esm_only['Wasserstein'].mean(),
# })
summary_df = pd.DataFrame(rows)

# Change position of the All (weighted) row to the top
summary_df = pd.concat([summary_df[summary_df['ESM'] == 'All (weighted)'], summary_df[summary_df['ESM'] != 'All (weighted)']], ignore_index=True)

# Change the position of ERA5 to the top of the dataframe
summary_df = pd.concat([summary_df[summary_df['ESM'] == 'ERA5'], summary_df[summary_df['ESM'] != 'ERA5']], ignore_index=True)


print(summary_df)
# Out:
#               ESM  Current Mean  Future Mean  Delta Mean  Delta Mean (%)  \
# 0            ERA5      6.338730          NaN         NaN             NaN
# 1        All ESMs      5.767180     5.769924    0.002744        0.047579
# 2      ACCESS-CM2      5.732692     5.675693   -0.056999       -0.994285
# 3     BCC-CSM2-MR      6.588217     6.809249    0.221032        3.354961
# 4           CESM2      5.197128     5.225565    0.028437        0.547166
# 5       EC-Earth3      6.688601     6.688903    0.000302        0.004511
# 6       GFDL-ESM4      7.048868     6.863641   -0.185227       -2.627754
# 7      KACE-1-0-G      6.786740     6.862891    0.076151        1.122050
# 8   MPI-ESM1-2-HR      6.308161     6.246894   -0.061267       -0.971230
# 9      MRI-ESM2-0      5.712453     5.700541   -0.011913       -0.208537
# 10        TaiESM1      5.163454     5.100033   -0.063421       -1.228269
# 11    UKESM1-0-LL      5.657787     5.548286   -0.109501       -1.935402
#
#     Current Std  Future Std  Delta Std  Delta Std (%)  KS Statistic  \
# 0      2.312808         NaN        NaN            NaN           NaN
# 1      2.164288    2.188673   0.024385       1.126690      0.003676
# 2      2.162642    2.181980   0.019337       0.894144      0.016484
# 3      1.930841    1.983183   0.052342       2.710820      0.057143
# 4      1.827644    1.847997   0.020352       1.113573      0.009517
# 5      2.364467    2.432685   0.068218       2.885126      0.012352
# 6      2.368235    2.325655  -0.042580      -1.797965      0.045055
# 7      2.193910    2.176749  -0.017162      -0.782244      0.022527
# 8      2.354647    2.343792  -0.010854      -0.460979      0.015440
# 9      1.921120    1.941423   0.020303       1.056833      0.013736
# 10     1.689623    1.656801  -0.032821      -1.942534      0.023077
# 11     2.124808    2.105125  -0.019683      -0.926352      0.026623
#
#       KS p-value
# 0            NaN
# 1   1.755143e-02
# 2   4.484190e-01
# 3   5.240631e-03
# 4   8.409774e-08
# 5   6.090179e-07
# 6   4.970705e-02
# 7   1.251857e-01
# 8   2.584110e-02
# 9   3.571315e-01
# 10  7.177940e-01
# 11  1.348138e-06
# /tmp/ipykernel_4118475/1968699567.py:11: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   ks_stat, ks_p = ks_2samp(cur, fut)
# /home/onennecke/.conda/envs/env_ma_on/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:3904: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/onennecke/.conda/envs/env_ma_on/lib/python3.12/site-packages/numpy/_core/_methods.py:147: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/onennecke/.conda/envs/env_ma_on/lib/python3.12/site-packages/numpy/_core/_methods.py:227: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/onennecke/.conda/envs/env_ma_on/lib/python3.12/site-packages/numpy/_core/_methods.py:184: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/onennecke/.conda/envs/env_ma_on/lib/python3.12/site-packages/numpy/_core/_methods.py:219: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Patch

# --------------------------------------------------
# Data
# --------------------------------------------------
esms = summary_df['ESM'].values
delta_mean = summary_df['Delta Mean (%)'].values
delta_std = summary_df['Delta Std (%)'].values

n = len(esms)
x = np.arange(n)

current_data = [esm_data_cur_dict[k] for k in esms]
future_data = [esm_data_fut_dict[k] for k in esms]

# --------------------------------------------------
# Figure and axes
# Left axis  -> boxplots (actual variable values)
# Right axis -> percent changes (bars)
# --------------------------------------------------
fig, ax_box = plt.subplots(figsize=(16, 7))
ax_bar = ax_box.twinx()

# --------------------------------------------------
# Background bars (Δ Mean and Δ Std)
# --------------------------------------------------
bar_width = 0.35

ax_bar.bar(
    x - bar_width / 2,
    delta_mean,
    width=bar_width,
    color='tab:blue',
    alpha=0.30,
    label='Δ Mean (%)',
    zorder=1
)

ax_bar.bar(
    x + bar_width / 2,
    delta_std,
    width=bar_width,
    color='tab:red',
    alpha=0.30,
    label='Δ Std (%)',
    zorder=1
)

# --------------------------------------------------
# Boxplots on top
# --------------------------------------------------
offset = 0.12

current_pos = x - offset
future_pos = x + offset

bp1 = ax_box.boxplot(
    current_data,
    positions=current_pos,
    widths=0.18,
    patch_artist=True,
    manage_ticks=False,
    showfliers=True,
    zorder=3
)

bp2 = ax_box.boxplot(
    future_data,
    positions=future_pos,
    widths=0.18,
    patch_artist=True,
    manage_ticks=False,
    showfliers=True,
    zorder=3
)

# --------------------------------------------------
# Styling boxplots
# --------------------------------------------------
for box in bp1['boxes']:
    box.set(facecolor='white', edgecolor='black', alpha=0.9)

for box in bp2['boxes']:
    box.set(facecolor='lightgray', edgecolor='black', alpha=0.9)

# --------------------------------------------------
# Align zero lines on both axes
# --------------------------------------------------

# Boxplot axis limits from data
all_box_values = np.concatenate([
    np.concatenate(current_data),
    np.concatenate(future_data)
])

# box_abs = np.nanmax(np.abs(all_box_values))
# ax_box.set_ylim(-1.1 * box_abs, 1.1 * box_abs)

# # Bar axis limits from percentage changes
# bar_abs = max(
#     np.nanmax(np.abs(delta_mean)),
#     np.nanmax(np.abs(delta_std))
# )

# ax_bar.set_ylim(-1.1 * bar_abs, 1.1 * bar_abs)


box_bar_max = np.nanmax(np.concatenate([np.abs(all_box_values), np.abs(delta_mean), np.abs(delta_std)]))
box_bar_min = np.nanmin(np.concatenate([all_box_values, delta_mean, delta_std]))
ax_box.set_ylim(1.1 * box_bar_min, 1.1 * box_bar_max)
ax_bar.set_ylim(1.1 * box_bar_min, 1.1 * box_bar_max)

# Shared zero line
ax_box.axhline(0, color='black', linewidth=0.8, zorder=2)

# --------------------------------------------------
# Labels
# --------------------------------------------------
ax_box.set_ylabel(variable_name)
ax_bar.set_ylabel('Change (%)')

ax_box.set_xticks(x)
ax_box.set_xticklabels(esms, rotation=45, ha='right')

# --------------------------------------------------
# Put boxplots visually above bars
# --------------------------------------------------
ax_box.set_zorder(2)
ax_bar.set_zorder(1)

ax_box.patch.set_alpha(0)

# --------------------------------------------------
# Legend
# --------------------------------------------------
legend_elements = [
    Patch(facecolor='tab:blue', alpha=0.30, label='Δ Mean (%)'),
    Patch(facecolor='tab:red', alpha=0.30, label='Δ Std (%)'),
    Patch(facecolor='white', edgecolor='black', label='Current'),
    Patch(facecolor='lightgray', edgecolor='black', label='Future')
]

ax_box.legend(handles=legend_elements, loc='upper right')

# --------------------------------------------------
# Title
# --------------------------------------------------
plt.title(
    f'{variable_name}: Current and Future Distributions with '
    'Change in Mean and Standard Deviation'
)

plt.tight_layout()
plt.show()

# %%
rows = []

for esm in all_keys:

    cur = esm_data_cur_dict[esm]
    fut = esm_data_fut_dict[esm]

    ks_stat, ks_p = ks_2samp(cur, fut)

    rows.append({
        'ESM': esm,
        'Current Mean': np.mean(cur),
        'Future Mean': np.mean(fut),
        'Delta Mean': np.mean(fut) - np.mean(cur),
        'Delta Mean (%)': (np.mean(fut) - np.mean(cur)) / np.mean(cur) * 100,
        'Current Std': np.std(cur),
        'Future Std': np.std(fut),
        'Delta Std': np.std(fut) - np.std(cur),
        'Delta Std (%)': (np.std(fut) - np.std(cur)) / np.std(cur) * 100,
        'KS Statistic': ks_stat,
        'KS p-value': ks_p,
        # 'Wasserstein': wasserstein_distance(cur, fut),
    })

summary_df = pd.DataFrame(rows)

print(summary_df)
# Out:
#               ESM  Current Mean  Future Mean  Delta Mean  Delta Mean (%)  \
# 0             All      5.764203     5.769924    0.005721        0.099247
# 1      ACCESS-CM2      5.732692     5.675693   -0.056999       -0.994285
# 2     BCC-CSM2-MR      6.588217     6.809249    0.221032        3.354961
# 3           CESM2      6.880692     6.996945    0.116254        1.689563
# 4        CESM2_LE      5.146621     5.172424    0.025802        0.501346
# 5       EC-Earth3      6.688601     6.688903    0.000302        0.004511
# 6       GFDL-ESM4      7.048868     6.863641   -0.185227       -2.627754
# 7      KACE-1-0-G      6.786740     6.862891    0.076151        1.122050
# 8   MPI-ESM1-2-HR      6.308161     6.246894   -0.061267       -0.971230
# 9      MRI-ESM2-0      5.712453     5.700541   -0.011913       -0.208537
# 10        TaiESM1      5.163454     5.100033   -0.063421       -1.228269
# 11    UKESM1-0-LL      5.657787     5.548286   -0.109501       -1.935402
#
#     Current Std  Future Std  Delta Std  Delta Std (%)  KS Statistic  \
# 0      2.163093    2.188673   0.025580       1.182582      0.003277
# 1      2.162642    2.181980   0.019337       0.894144      0.016484
# 2      1.930841    1.983183   0.052342       2.710820      0.057143
# 3      2.429496    2.423418  -0.006077      -0.250147      0.024725
# 4      1.782088    1.801221   0.019133       1.073654      0.009214
# 5      2.364467    2.432685   0.068218       2.885126      0.012352
# 6      2.368235    2.325655  -0.042580      -1.797965      0.045055
# 7      2.193910    2.176749  -0.017162      -0.782244      0.022527
# 8      2.354647    2.343792  -0.010854      -0.460979      0.015440
# 9      1.921120    1.941423   0.020303       1.056833      0.013736
# 10     1.689623    1.656801  -0.032821      -1.942534      0.023077
# 11     2.124808    2.105125  -0.019683      -0.926352      0.026623
#
#       KS p-value
# 0   4.684819e-02
# 1   4.484190e-01
# 2   5.240631e-03
# 3   7.101644e-02
# 4   3.867038e-07
# 5   6.090179e-07
# 6   4.970705e-02
# 7   1.251857e-01
# 8   2.584110e-02
# 9   3.571315e-01
# 10  7.177940e-01
# 11  1.348138e-06

# %%
# Assuming summary_df is already created
# Extract data
esms = summary_df['ESM']
delta_mean = summary_df['Delta Mean (%)']
delta_std = summary_df['Delta Std (%)']

max_pos = max(max(delta_mean), max(delta_std))
min_neg = min(min(delta_mean), min(delta_std))
y_limit = max(abs(max_pos), abs(min_neg)) * 1.1

# Create figure and primary axis
fig, ax1 = plt.subplots(figsize=(12, 6))

# Plot Delta Mean (%) on primary axis
color_mean = 'tab:blue'
ax1.set_xlabel('ESM')
ax1.set_ylabel('Delta Mean (%)', color=color_mean)
ax1.set_ylim(-y_limit, y_limit)
bars_mean = ax1.bar(esms, delta_mean, color=color_mean, width=-0.4, align='edge', alpha=0.7, label='Delta Mean (%)')
ax1.tick_params(axis='y', labelcolor=color_mean)

# Create secondary axis for Delta Std (%)
ax2 = ax1.twinx()
color_std = 'tab:red'
ax2.set_ylabel('Delta Std (%)', color=color_std)
ax2.set_ylim(-y_limit, y_limit)
bars_std = ax2.bar(esms, delta_std, color=color_std, width=0.4,alpha=0.7, align='edge', label='Delta Std (%)')
ax2.tick_params(axis='y', labelcolor=color_std)

# Add legend
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper right')

# Add title
plt.title('Change in Mean and Standard Deviation by ESM')

# Rotate x-axis labels for readability
ax1.set_xticklabels(esms, rotation=45)


# Adjust layout
plt.tight_layout()

# Show plot
plt.show()
# Out:
# /tmp/ipykernel_784201/2986788715.py:39: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(esms, rotation=45)

# %%
print(np.min(summary_df['Delta Mean (%)']))
print(np.max(summary_df['Delta Mean (%)']))
# Out:
# -2.6277536051689365
# 3.354960587430441

# %% [markdown]
# ## Huge plots

# %%
sns.set_style("whitegrid")

fig, axes = plt.subplots(
    nrows=n,
    ncols=2,
    figsize=(12, 4 * n),
    constrained_layout=True
)

# handle case n=1
if n == 1:
    axes = np.array([axes])

for i, esm in enumerate(all_keys):

    cur = esm_data_cur_dict[esm]
    fut = esm_data_fut_dict[esm]

    # -------------------------
    # KDE plot
    # -------------------------
    ax = axes[i, 0]

    sns.kdeplot(cur, ax=ax, label='Current', fill=True, alpha=0.4)
    sns.kdeplot(fut, ax=ax, label='Future', fill=True, alpha=0.4)
    ax.set_xlim(0, 25)
    # metrics
    ks_stat, ks_p = ks_2samp(cur, fut)
    wass = wasserstein_distance(cur, fut)

    ax.set_title(
        f"{esm}\nKS={ks_stat:.3f}, p={ks_p:.2e}, Wasserstein={wass:.2f}"
    )
    ax.set_xlabel(variable_name)
    ax.legend()

    # -------------------------
    # Boxplot
    # -------------------------
    ax2 = axes[i, 1]

    sns.boxplot(
        data=[cur, fut],
        ax=ax2
    )

    ax2.set_xticklabels(['Current', 'Future'])
    ax2.set_title(f"{esm} Boxplots")
    ax2.set_ylabel(variable_name)

plt.show()
# Out:
# /tmp/ipykernel_465126/2707583178.py:51: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(['Current', 'Future'])
# /tmp/ipykernel_465126/2707583178.py:51: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(['Current', 'Future'])
# /tmp/ipykernel_465126/2707583178.py:51: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(['Current', 'Future'])
# /tmp/ipykernel_465126/2707583178.py:51: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(['Current', 'Future'])
# /tmp/ipykernel_465126/2707583178.py:51: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(['Current', 'Future'])
# /tmp/ipykernel_465126/2707583178.py:51: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(['Current', 'Future'])
# /tmp/ipykernel_465126/2707583178.py:51: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(['Current', 'Future'])
# /tmp/ipykernel_465126/2707583178.py:51: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(['Current', 'Future'])
# /tmp/ipykernel_465126/2707583178.py:51: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(['Current', 'Future'])
# /tmp/ipykernel_465126/2707583178.py:51: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(['Current', 'Future'])
# /tmp/ipykernel_465126/2707583178.py:51: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(['Current', 'Future'])
# /tmp/ipykernel_465126/2707583178.py:51: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(['Current', 'Future'])

# %%
fig, axes = plt.subplots(
    nrows=len(all_keys),
    figsize=(7, 3 * len(all_keys)),
    constrained_layout=True
)

if len(all_keys) == 1:
    axes = [axes]

for ax, esm in zip(axes, all_keys):

    cur = esm_data_cur_dict[esm]
    fut = esm_data_fut_dict[esm]

    sns.violinplot(
        data=[cur, fut],
        ax=ax,
        inner='quartile'
    )

    ax.set_xticklabels(['Current', 'Future'])
    ax.set_title(esm)
    ax.set_ylabel(variable_name)

plt.show()
# Out:
# /tmp/ipykernel_465126/4121132350.py:21: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(['Current', 'Future'])
# /tmp/ipykernel_465126/4121132350.py:21: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(['Current', 'Future'])
# /tmp/ipykernel_465126/4121132350.py:21: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(['Current', 'Future'])
# /tmp/ipykernel_465126/4121132350.py:21: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(['Current', 'Future'])
# /tmp/ipykernel_465126/4121132350.py:21: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(['Current', 'Future'])
# /tmp/ipykernel_465126/4121132350.py:21: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(['Current', 'Future'])
# /tmp/ipykernel_465126/4121132350.py:21: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(['Current', 'Future'])
# /tmp/ipykernel_465126/4121132350.py:21: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(['Current', 'Future'])
# /tmp/ipykernel_465126/4121132350.py:21: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(['Current', 'Future'])
# /tmp/ipykernel_465126/4121132350.py:21: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(['Current', 'Future'])
# /tmp/ipykernel_465126/4121132350.py:21: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(['Current', 'Future'])
# /tmp/ipykernel_465126/4121132350.py:21: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(['Current', 'Future'])

# %%
fig, axes = plt.subplots(
    nrows=len(all_keys),
    figsize=(8, 3 * len(all_keys)),
    constrained_layout=True
)

if len(all_keys) == 1:
    axes = [axes]

for ax, esm in zip(axes, all_keys):

    cur = np.sort(esm_data_cur_dict[esm])
    fut = np.sort(esm_data_fut_dict[esm])

    ecdf_cur = np.arange(1, len(cur)+1) / len(cur)
    ecdf_fut = np.arange(1, len(fut)+1) / len(fut)

    ax.plot(cur, ecdf_cur, label='Current')
    ax.plot(fut, ecdf_fut, label='Future')

    ax.set_title(f"ECDF - {esm}")
    ax.set_xlabel(variable_name)
    ax.set_ylabel("F(x)")
    ax.legend()

plt.show()

# %%
quantiles = np.linspace(0.01, 0.99, 99)

fig, axes = plt.subplots(
    nrows=len(all_keys),
    figsize=(8, 3 * len(all_keys)),
    constrained_layout=True
)

if len(all_keys) == 1:
    axes = [axes]

for ax, esm in zip(axes, all_keys):

    cur_q = np.quantile(esm_data_cur_dict[esm], quantiles)
    fut_q = np.quantile(esm_data_fut_dict[esm], quantiles)

    delta = fut_q - cur_q

    ax.plot(quantiles, delta)

    ax.axhline(0, color='black', linestyle='--')

    ax.set_title(f"Quantile Change - {esm}")
    ax.set_xlabel("Quantile")
    ax.set_ylabel("Future - Current")

plt.show()
