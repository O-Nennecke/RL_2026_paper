# %% [markdown]
# Title: tas_dist_comp.ipynb
#
# Purpose: Compare the distribution of tas in current and future climate
#
# Author: Onno Nennecke on 02.06.2025 Modified: 12.05.2026
#
# Input data:
#
# - tas Data from CMIP
#     - These files lie here: /climca/people/onennecke/not_debiased_data/
#     - These files lie here: /climca/people/onennecke/not_debiased_data_future/
# - Used Runs File: CMIP6_runs_future.csv and CESM2_LE_runs.csv
#     - These files lie here: /home/onennecke/CMIP_models/
#
# Output data:
#
# - Some plots to compare

# %% [markdown]
# ### Load libraries and functions

# %%
# Importing libraries
import xarray as xr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import ks_2samp, wasserstein_distance
import os

# %% [markdown]
# ### Define var name

# %%
variable_name = 'tas'

# %% [markdown]
# ### Read data

# %%
# Read the dataframe from the csv file
used_runs_fut = pd.read_csv('/home/onennecke/CMIP_models/CMIP6_runs_future.csv')
used_runs_CESM_LE = pd.read_csv('/home/onennecke/CMIP_models/CESM2_LE_runs.csv')


used_runs = pd.concat([used_runs_fut, used_runs_CESM_LE], ignore_index=True)
# Add one row with ERA5 using pd.concat
era5_row = pd.DataFrame([{
    'ESM': 'ERA5',
    'Institution': 'ECMWF',
    'run': 'hist'
}])
used_runs = pd.concat([used_runs, era5_row], ignore_index=True)
# Change the ref column to 1 for the first instance of each model
# used_runs['Ref'] = used_runs.groupby(['ESM', 'Institution']).cumcount().apply(lambda x: 1 if x == 0 else 0)

ESMs = used_runs['ESM'].unique()

# %%
base_path_fut = '/climca/people/onennecke/not_debiased_data_future/'
base_path_cur = '/climca/people/onennecke/not_debiased_data/'

# Build a list of file names from the used_runs dataframe
file_names = []
for index, row in used_runs.iterrows():
    esm = row['ESM']
    # institution = row['Institution']
    run = row['run']
    
    # Construct the file name based on the ESM, institution, and run
    file_name_pattern = f'{esm}_{run}_{variable_name}.nc'
    
    # Append the file name pattern to the list
    file_names.append(file_name_pattern)
# file_names

# %%
# Load installed capacity data
grid_offshore = xr.open_dataset('/climca/people/onennecke/Wind_Solar_MaStR/processed_data/wind_offshore_ic.nc')
grid_offshore = grid_offshore['wind_off_cap']
mask_offshore = xr.where(np.isfinite(grid_offshore), 1, 0)
grid_onshore = xr.open_dataset('/climca/people/onennecke/Wind_Solar_MaStR/processed_data/wind_onshore_ic.nc')
grid_onshore = grid_onshore['wind_on_cap']
mask_onshore = xr.where(np.isfinite(grid_onshore), 1, 0)
grid_solar = xr.open_dataset('/climca/people/onennecke/Wind_Solar_MaStR/processed_data/solar_ic_netto.nc')
# grid_solar = xr.open_dataset('/climca/people/onennecke/Wind_Solar_MaStR/processed_data/solar_ic.nc')
grid_solar = grid_solar['solar_cap']
mask_solar = xr.where(np.isfinite(grid_solar), 1, 0)
population = xr.open_dataset('/climca/people/onennecke/population_data/population_regrid_weights.nc')
population = population['population']
mask_population = xr.where(np.isfinite(population), 1, 0)
# Overall mask
overall_mask = mask_offshore + mask_onshore + mask_solar + mask_population
overall_mask = xr.where(overall_mask > 0, 1, 0)

# %%
ds_list = []
counter = 1
for file_name in file_names:
    file_path = os.path.join(base_path_cur, file_name)
    print(f'{counter}/{len(file_names)}: Processing file: {file_path}')
    if os.path.exists(file_path):
        ds = xr.open_dataset(file_path)
        esm_run = ds.ESM_run.values
        if '_LE2' in str(esm_run):
            esm_run = str(esm_run).replace('_LE2', '')
            ds["ESM"] = "CESM2"
        # Select only 6 winter months (October to March)
        ds = ds.sel(time=ds['time.month'].isin([10, 11, 12, 1, 2, 3]))
        # Mask the data with the overall mask
        ds = ds.where(overall_mask == 1)        
        # Calculate the spatial mean over the dimension
        mean_ds = ds.mean(dim=['lat', 'lon'], keep_attrs=True)
        
        # Change to C
        mean_ds = mean_ds - 273.15
        
        ts_output = mean_ds.expand_dims(ESM_run=[esm_run]).assign_coords(ESM_run=[esm_run])
        ds_list.append(ts_output)
    else:
        print(f'File not found: {file_path}')
    counter += 1
esm_ds_cur = xr.concat(ds_list, dim="ESM_run")

ds_list = []
counter = 1
for file_name in file_names:
    file_path = os.path.join(base_path_fut, file_name)
    print(f'{counter}/{len(file_names)}: Processing file: {file_path}')
    if os.path.exists(file_path):
        ds = xr.open_dataset(file_path)
        esm_run = ds.ESM_run.values
        if '_LE2' in str(esm_run):
            esm_run = str(esm_run).replace('_LE2', '')
            ds["ESM"] = "CESM2"
        # Select only 6 winter months (October to March)
        ds = ds.sel(time=ds['time.month'].isin([10, 11, 12, 1, 2, 3]))
        # Mask the data with the overall mask
        ds = ds.where(overall_mask == 1)        
        # Calculate the spatial mean over the dimension
        mean_ds = ds.mean(dim=['lat', 'lon'], keep_attrs=True)
        # Change to C
        mean_ds = mean_ds - 273.15
        ts_output = mean_ds.expand_dims(ESM_run=[esm_run]).assign_coords(ESM_run=[esm_run])
        ds_list.append(ts_output)
    else:
        print(f'File not found: {file_path}')
    counter += 1
esm_ds_fut = xr.concat(ds_list, dim="ESM_run")
# Out:
# 1/193: Processing file: /climca/people/onennecke/not_debiased_data/ACCESS-CM2_r4i1p1f1_tas.nc
# 2/193: Processing file: /climca/people/onennecke/not_debiased_data/ACCESS-CM2_r5i1p1f1_tas.nc
# 3/193: Processing file: /climca/people/onennecke/not_debiased_data/ACCESS-CM2_r1i1p1f1_tas.nc
# 4/193: Processing file: /climca/people/onennecke/not_debiased_data/BCC-CSM2-MR_r1i1p1f1_tas.nc
# 5/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_r4i1p1f1_tas.nc
# 6/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_r10i1p1f1_tas.nc
# 7/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_r11i1p1f1_tas.nc
# 8/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r149i1p1f1_tas.nc
# 9/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r4i1p1f1_tas.nc
# 10/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r148i1p1f1_tas.nc
# 11/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r105i1p1f1_tas.nc
# 12/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r134i1p1f1_tas.nc
# 13/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r141i1p1f1_tas.nc
# 14/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r146i1p1f1_tas.nc
# 15/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r112i1p1f1_tas.nc
# 16/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r117i1p1f1_tas.nc
# 17/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r125i1p1f1_tas.nc
# 18/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r113i1p1f1_tas.nc
# 19/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r106i1p1f1_tas.nc
# 20/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r138i1p1f1_tas.nc
# 21/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r5i1p1f1_tas.nc
# 22/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r137i1p1f1_tas.nc
# 23/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r145i1p1f1_tas.nc
# 24/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r114i1p1f1_tas.nc
# 25/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r120i1p1f1_tas.nc
# 26/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r128i1p1f1_tas.nc
# 27/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r135i1p1f1_tas.nc
# 28/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r110i1p1f1_tas.nc
# 29/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r129i1p1f1_tas.nc
# 30/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r132i1p1f1_tas.nc
# 31/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r101i1p1f1_tas.nc
# 32/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r124i1p1f1_tas.nc
# 33/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r127i1p1f1_tas.nc
# 34/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r116i1p1f1_tas.nc
# 35/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r131i1p1f1_tas.nc
# 36/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r121i1p1f1_tas.nc
# 37/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r142i1p1f1_tas.nc
# 38/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r102i1p1f1_tas.nc
# 39/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r133i1p1f1_tas.nc
# 40/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r111i1p1f1_tas.nc
# 41/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r140i1p1f1_tas.nc
# 42/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r136i1p1f1_tas.nc
# 43/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r108i1p1f1_tas.nc
# 44/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r130i1p1f1_tas.nc
# 45/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r150i1p1f1_tas.nc
# 46/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r104i1p1f1_tas.nc
# 47/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r118i1p1f1_tas.nc
# 48/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r109i1p1f1_tas.nc
# 49/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r143i1p1f1_tas.nc
# 50/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r147i1p1f1_tas.nc
# 51/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r3i1p1f1_tas.nc
# 52/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r126i1p1f1_tas.nc
# 53/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r119i1p1f1_tas.nc
# 54/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r1i1p1f1_tas.nc
# 55/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r123i1p1f1_tas.nc
# 56/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r122i1p1f1_tas.nc
# 57/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r115i1p1f1_tas.nc
# 58/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r103i1p1f1_tas.nc
# 59/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r144i1p1f1_tas.nc
# 60/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r139i1p1f1_tas.nc
# 61/193: Processing file: /climca/people/onennecke/not_debiased_data/EC-Earth3_r107i1p1f1_tas.nc
# 62/193: Processing file: /climca/people/onennecke/not_debiased_data/GFDL-ESM4_r1i1p1f1_tas.nc
# 63/193: Processing file: /climca/people/onennecke/not_debiased_data/KACE-1-0-G_r2i1p1f1_tas.nc
# 64/193: Processing file: /climca/people/onennecke/not_debiased_data/KACE-1-0-G_r3i1p1f1_tas.nc
# 65/193: Processing file: /climca/people/onennecke/not_debiased_data/KACE-1-0-G_r1i1p1f1_tas.nc
# 66/193: Processing file: /climca/people/onennecke/not_debiased_data/MPI-ESM1-2-HR_r6i1p1f1_tas.nc
# 67/193: Processing file: /climca/people/onennecke/not_debiased_data/MPI-ESM1-2-HR_r4i1p1f1_tas.nc
# 68/193: Processing file: /climca/people/onennecke/not_debiased_data/MPI-ESM1-2-HR_r9i1p1f1_tas.nc
# 69/193: Processing file: /climca/people/onennecke/not_debiased_data/MPI-ESM1-2-HR_r10i1p1f1_tas.nc
# 70/193: Processing file: /climca/people/onennecke/not_debiased_data/MPI-ESM1-2-HR_r5i1p1f1_tas.nc
# 71/193: Processing file: /climca/people/onennecke/not_debiased_data/MPI-ESM1-2-HR_r8i1p1f1_tas.nc
# 72/193: Processing file: /climca/people/onennecke/not_debiased_data/MPI-ESM1-2-HR_r2i1p1f1_tas.nc
# 73/193: Processing file: /climca/people/onennecke/not_debiased_data/MPI-ESM1-2-HR_r7i1p1f1_tas.nc
# 74/193: Processing file: /climca/people/onennecke/not_debiased_data/MPI-ESM1-2-HR_r3i1p1f1_tas.nc
# 75/193: Processing file: /climca/people/onennecke/not_debiased_data/MPI-ESM1-2-HR_r1i1p1f1_tas.nc
# 76/193: Processing file: /climca/people/onennecke/not_debiased_data/MRI-ESM2-0_r4i1p1f1_tas.nc
# 77/193: Processing file: /climca/people/onennecke/not_debiased_data/MRI-ESM2-0_r5i1p1f1_tas.nc
# 78/193: Processing file: /climca/people/onennecke/not_debiased_data/MRI-ESM2-0_r2i1p1f1_tas.nc
# 79/193: Processing file: /climca/people/onennecke/not_debiased_data/MRI-ESM2-0_r3i1p1f1_tas.nc
# 80/193: Processing file: /climca/people/onennecke/not_debiased_data/MRI-ESM2-0_r1i1p1f1_tas.nc
# 81/193: Processing file: /climca/people/onennecke/not_debiased_data/TaiESM1_r1i1p1f1_tas.nc
# 82/193: Processing file: /climca/people/onennecke/not_debiased_data/UKESM1-0-LL_r4i1p1f2_tas.nc
# 83/193: Processing file: /climca/people/onennecke/not_debiased_data/UKESM1-0-LL_r1i1p1f2_tas.nc
# 84/193: Processing file: /climca/people/onennecke/not_debiased_data/UKESM1-0-LL_r7i1p1f2_tas.nc
# 85/193: Processing file: /climca/people/onennecke/not_debiased_data/UKESM1-0-LL_r6i1p1f2_tas.nc
# 86/193: Processing file: /climca/people/onennecke/not_debiased_data/UKESM1-0-LL_r2i1p1f2_tas.nc
# 87/193: Processing file: /climca/people/onennecke/not_debiased_data/UKESM1-0-LL_r5i1p1f2_tas.nc
# 88/193: Processing file: /climca/people/onennecke/not_debiased_data/UKESM1-0-LL_r3i1p1f2_tas.nc
# 89/193: Processing file: /climca/people/onennecke/not_debiased_data/UKESM1-0-LL_r8i1p1f2_tas.nc
# 90/193: Processing file: /climca/people/onennecke/not_debiased_data/UKESM1-0-LL_r15i1p1f2_tas.nc
# 91/193: Processing file: /climca/people/onennecke/not_debiased_data/UKESM1-0-LL_r13i1p1f2_tas.nc
# 92/193: Processing file: /climca/people/onennecke/not_debiased_data/UKESM1-0-LL_r14i1p1f2_tas.nc
# 93/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1001_001_tas.nc
# 94/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1011_001_tas.nc
# 95/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1021_002_tas.nc
# 96/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1031_002_tas.nc
# 97/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1041_003_tas.nc
# 98/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1051_003_tas.nc
# 99/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1061_004_tas.nc
# 100/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1071_004_tas.nc
# 101/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1081_005_tas.nc
# 102/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1091_005_tas.nc
# 103/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1101_006_tas.nc
# 104/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1111_006_tas.nc
# 105/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1121_007_tas.nc
# 106/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1131_007_tas.nc
# 107/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1141_008_tas.nc
# 108/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1151_008_tas.nc
# 109/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1161_009_tas.nc
# 110/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1171_009_tas.nc
# 111/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1181_010_tas.nc
# 112/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1191_010_tas.nc
# 113/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1231_001_tas.nc
# 114/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1231_002_tas.nc
# 115/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1231_003_tas.nc
# 116/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1231_004_tas.nc
# 117/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1231_005_tas.nc
# 118/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1231_006_tas.nc
# 119/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1231_007_tas.nc
# 120/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1231_008_tas.nc
# 121/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1231_009_tas.nc
# 122/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1231_010_tas.nc
# 123/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1231_011_tas.nc
# 124/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1231_012_tas.nc
# 125/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1231_013_tas.nc
# 126/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1231_014_tas.nc
# 127/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1231_015_tas.nc
# 128/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1231_016_tas.nc
# 129/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1231_017_tas.nc
# 130/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1231_018_tas.nc
# 131/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1231_019_tas.nc
# 132/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1231_020_tas.nc
# 133/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1251_001_tas.nc
# 134/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1251_002_tas.nc
# 135/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1251_003_tas.nc
# 136/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1251_004_tas.nc
# 137/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1251_005_tas.nc
# 138/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1251_006_tas.nc
# 139/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1251_007_tas.nc
# 140/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1251_008_tas.nc
# 141/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1251_009_tas.nc
# 142/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1251_010_tas.nc
# 143/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1251_011_tas.nc
# 144/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1251_012_tas.nc
# 145/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1251_013_tas.nc
# 146/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1251_014_tas.nc
# 147/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1251_015_tas.nc
# 148/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1251_016_tas.nc
# 149/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1251_017_tas.nc
# 150/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1251_018_tas.nc
# 151/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1251_019_tas.nc
# 152/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1251_020_tas.nc
# 153/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1281_001_tas.nc
# 154/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1281_002_tas.nc
# 155/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1281_003_tas.nc
# 156/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1281_004_tas.nc
# 157/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1281_005_tas.nc
# 158/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1281_006_tas.nc
# 159/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1281_007_tas.nc
# 160/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1281_008_tas.nc
# 161/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1281_009_tas.nc
# 162/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1281_010_tas.nc
# 163/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1281_011_tas.nc
# 164/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1281_012_tas.nc
# 165/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1281_013_tas.nc
# 166/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1281_014_tas.nc
# 167/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1281_015_tas.nc
# 168/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1281_016_tas.nc
# 169/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1281_017_tas.nc
# 170/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1281_018_tas.nc
# 171/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1281_019_tas.nc
# 172/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1281_020_tas.nc
# 173/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1301_001_tas.nc
# 174/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1301_002_tas.nc
# 175/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1301_003_tas.nc
# 176/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1301_004_tas.nc
# 177/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1301_005_tas.nc
# 178/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1301_006_tas.nc
# 179/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1301_007_tas.nc
# 180/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1301_008_tas.nc
# 181/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1301_009_tas.nc
# 182/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1301_010_tas.nc
# 183/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1301_011_tas.nc
# 184/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1301_012_tas.nc
# 185/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1301_013_tas.nc
# 186/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1301_014_tas.nc
# 187/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1301_015_tas.nc
# 188/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1301_016_tas.nc
# 189/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1301_017_tas.nc
# 190/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1301_018_tas.nc
# 191/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1301_019_tas.nc
# 192/193: Processing file: /climca/people/onennecke/not_debiased_data/CESM2_LE2-1301_020_tas.nc
# 193/193: Processing file: /climca/people/onennecke/not_debiased_data/ERA5_hist_tas.nc
# 1/193: Processing file: /climca/people/onennecke/not_debiased_data_future/ACCESS-CM2_r4i1p1f1_tas.nc
# 2/193: Processing file: /climca/people/onennecke/not_debiased_data_future/ACCESS-CM2_r5i1p1f1_tas.nc
# 3/193: Processing file: /climca/people/onennecke/not_debiased_data_future/ACCESS-CM2_r1i1p1f1_tas.nc
# 4/193: Processing file: /climca/people/onennecke/not_debiased_data_future/BCC-CSM2-MR_r1i1p1f1_tas.nc
# 5/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_r4i1p1f1_tas.nc
# 6/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_r10i1p1f1_tas.nc
# 7/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_r11i1p1f1_tas.nc
# 8/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r149i1p1f1_tas.nc
# 9/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r4i1p1f1_tas.nc
# 10/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r148i1p1f1_tas.nc
# 11/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r105i1p1f1_tas.nc
# 12/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r134i1p1f1_tas.nc
# 13/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r141i1p1f1_tas.nc
# 14/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r146i1p1f1_tas.nc
# 15/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r112i1p1f1_tas.nc
# 16/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r117i1p1f1_tas.nc
# 17/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r125i1p1f1_tas.nc
# 18/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r113i1p1f1_tas.nc
# 19/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r106i1p1f1_tas.nc
# 20/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r138i1p1f1_tas.nc
# 21/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r5i1p1f1_tas.nc
# 22/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r137i1p1f1_tas.nc
# 23/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r145i1p1f1_tas.nc
# 24/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r114i1p1f1_tas.nc
# 25/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r120i1p1f1_tas.nc
# 26/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r128i1p1f1_tas.nc
# 27/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r135i1p1f1_tas.nc
# 28/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r110i1p1f1_tas.nc
# 29/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r129i1p1f1_tas.nc
# 30/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r132i1p1f1_tas.nc
# 31/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r101i1p1f1_tas.nc
# 32/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r124i1p1f1_tas.nc
# 33/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r127i1p1f1_tas.nc
# 34/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r116i1p1f1_tas.nc
# 35/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r131i1p1f1_tas.nc
# 36/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r121i1p1f1_tas.nc
# 37/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r142i1p1f1_tas.nc
# 38/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r102i1p1f1_tas.nc
# 39/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r133i1p1f1_tas.nc
# 40/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r111i1p1f1_tas.nc
# 41/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r140i1p1f1_tas.nc
# 42/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r136i1p1f1_tas.nc
# 43/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r108i1p1f1_tas.nc
# 44/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r130i1p1f1_tas.nc
# 45/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r150i1p1f1_tas.nc
# 46/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r104i1p1f1_tas.nc
# 47/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r118i1p1f1_tas.nc
# 48/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r109i1p1f1_tas.nc
# 49/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r143i1p1f1_tas.nc
# 50/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r147i1p1f1_tas.nc
# 51/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r3i1p1f1_tas.nc
# 52/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r126i1p1f1_tas.nc
# 53/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r119i1p1f1_tas.nc
# 54/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r1i1p1f1_tas.nc
# 55/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r123i1p1f1_tas.nc
# 56/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r122i1p1f1_tas.nc
# 57/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r115i1p1f1_tas.nc
# 58/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r103i1p1f1_tas.nc
# 59/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r144i1p1f1_tas.nc
# 60/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r139i1p1f1_tas.nc
# 61/193: Processing file: /climca/people/onennecke/not_debiased_data_future/EC-Earth3_r107i1p1f1_tas.nc
# 62/193: Processing file: /climca/people/onennecke/not_debiased_data_future/GFDL-ESM4_r1i1p1f1_tas.nc
# 63/193: Processing file: /climca/people/onennecke/not_debiased_data_future/KACE-1-0-G_r2i1p1f1_tas.nc
# 64/193: Processing file: /climca/people/onennecke/not_debiased_data_future/KACE-1-0-G_r3i1p1f1_tas.nc
# 65/193: Processing file: /climca/people/onennecke/not_debiased_data_future/KACE-1-0-G_r1i1p1f1_tas.nc
# 66/193: Processing file: /climca/people/onennecke/not_debiased_data_future/MPI-ESM1-2-HR_r6i1p1f1_tas.nc
# 67/193: Processing file: /climca/people/onennecke/not_debiased_data_future/MPI-ESM1-2-HR_r4i1p1f1_tas.nc
# 68/193: Processing file: /climca/people/onennecke/not_debiased_data_future/MPI-ESM1-2-HR_r9i1p1f1_tas.nc
# 69/193: Processing file: /climca/people/onennecke/not_debiased_data_future/MPI-ESM1-2-HR_r10i1p1f1_tas.nc
# 70/193: Processing file: /climca/people/onennecke/not_debiased_data_future/MPI-ESM1-2-HR_r5i1p1f1_tas.nc
# 71/193: Processing file: /climca/people/onennecke/not_debiased_data_future/MPI-ESM1-2-HR_r8i1p1f1_tas.nc
# 72/193: Processing file: /climca/people/onennecke/not_debiased_data_future/MPI-ESM1-2-HR_r2i1p1f1_tas.nc
# 73/193: Processing file: /climca/people/onennecke/not_debiased_data_future/MPI-ESM1-2-HR_r7i1p1f1_tas.nc
# 74/193: Processing file: /climca/people/onennecke/not_debiased_data_future/MPI-ESM1-2-HR_r3i1p1f1_tas.nc
# 75/193: Processing file: /climca/people/onennecke/not_debiased_data_future/MPI-ESM1-2-HR_r1i1p1f1_tas.nc
# 76/193: Processing file: /climca/people/onennecke/not_debiased_data_future/MRI-ESM2-0_r4i1p1f1_tas.nc
# 77/193: Processing file: /climca/people/onennecke/not_debiased_data_future/MRI-ESM2-0_r5i1p1f1_tas.nc
# 78/193: Processing file: /climca/people/onennecke/not_debiased_data_future/MRI-ESM2-0_r2i1p1f1_tas.nc
# 79/193: Processing file: /climca/people/onennecke/not_debiased_data_future/MRI-ESM2-0_r3i1p1f1_tas.nc
# 80/193: Processing file: /climca/people/onennecke/not_debiased_data_future/MRI-ESM2-0_r1i1p1f1_tas.nc
# 81/193: Processing file: /climca/people/onennecke/not_debiased_data_future/TaiESM1_r1i1p1f1_tas.nc
# 82/193: Processing file: /climca/people/onennecke/not_debiased_data_future/UKESM1-0-LL_r4i1p1f2_tas.nc
# 83/193: Processing file: /climca/people/onennecke/not_debiased_data_future/UKESM1-0-LL_r1i1p1f2_tas.nc
# 84/193: Processing file: /climca/people/onennecke/not_debiased_data_future/UKESM1-0-LL_r7i1p1f2_tas.nc
# 85/193: Processing file: /climca/people/onennecke/not_debiased_data_future/UKESM1-0-LL_r6i1p1f2_tas.nc
# 86/193: Processing file: /climca/people/onennecke/not_debiased_data_future/UKESM1-0-LL_r2i1p1f2_tas.nc
# 87/193: Processing file: /climca/people/onennecke/not_debiased_data_future/UKESM1-0-LL_r5i1p1f2_tas.nc
# 88/193: Processing file: /climca/people/onennecke/not_debiased_data_future/UKESM1-0-LL_r3i1p1f2_tas.nc
# 89/193: Processing file: /climca/people/onennecke/not_debiased_data_future/UKESM1-0-LL_r8i1p1f2_tas.nc
# 90/193: Processing file: /climca/people/onennecke/not_debiased_data_future/UKESM1-0-LL_r15i1p1f2_tas.nc
# 91/193: Processing file: /climca/people/onennecke/not_debiased_data_future/UKESM1-0-LL_r13i1p1f2_tas.nc
# 92/193: Processing file: /climca/people/onennecke/not_debiased_data_future/UKESM1-0-LL_r14i1p1f2_tas.nc
# 93/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1001_001_tas.nc
# 94/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1011_001_tas.nc
# 95/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1021_002_tas.nc
# 96/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1031_002_tas.nc
# 97/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1041_003_tas.nc
# 98/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1051_003_tas.nc
# 99/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1061_004_tas.nc
# 100/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1071_004_tas.nc
# 101/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1081_005_tas.nc
# 102/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1091_005_tas.nc
# 103/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1101_006_tas.nc
# 104/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1111_006_tas.nc
# 105/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1121_007_tas.nc
# 106/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1131_007_tas.nc
# 107/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1141_008_tas.nc
# 108/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1151_008_tas.nc
# 109/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1161_009_tas.nc
# 110/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1171_009_tas.nc
# 111/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1181_010_tas.nc
# 112/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1191_010_tas.nc
# 113/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1231_001_tas.nc
# 114/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1231_002_tas.nc
# 115/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1231_003_tas.nc
# 116/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1231_004_tas.nc
# 117/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1231_005_tas.nc
# 118/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1231_006_tas.nc
# 119/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1231_007_tas.nc
# 120/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1231_008_tas.nc
# 121/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1231_009_tas.nc
# 122/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1231_010_tas.nc
# 123/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1231_011_tas.nc
# 124/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1231_012_tas.nc
# 125/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1231_013_tas.nc
# 126/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1231_014_tas.nc
# 127/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1231_015_tas.nc
# 128/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1231_016_tas.nc
# 129/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1231_017_tas.nc
# 130/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1231_018_tas.nc
# 131/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1231_019_tas.nc
# 132/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1231_020_tas.nc
# 133/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1251_001_tas.nc
# 134/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1251_002_tas.nc
# 135/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1251_003_tas.nc
# 136/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1251_004_tas.nc
# 137/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1251_005_tas.nc
# 138/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1251_006_tas.nc
# 139/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1251_007_tas.nc
# 140/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1251_008_tas.nc
# 141/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1251_009_tas.nc
# 142/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1251_010_tas.nc
# 143/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1251_011_tas.nc
# 144/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1251_012_tas.nc
# 145/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1251_013_tas.nc
# 146/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1251_014_tas.nc
# 147/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1251_015_tas.nc
# 148/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1251_016_tas.nc
# 149/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1251_017_tas.nc
# 150/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1251_018_tas.nc
# 151/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1251_019_tas.nc
# 152/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1251_020_tas.nc
# 153/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1281_001_tas.nc
# 154/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1281_002_tas.nc
# 155/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1281_003_tas.nc
# 156/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1281_004_tas.nc
# 157/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1281_005_tas.nc
# 158/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1281_006_tas.nc
# 159/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1281_007_tas.nc
# 160/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1281_008_tas.nc
# 161/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1281_009_tas.nc
# 162/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1281_010_tas.nc
# 163/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1281_011_tas.nc
# 164/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1281_012_tas.nc
# 165/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1281_013_tas.nc
# 166/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1281_014_tas.nc
# 167/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1281_015_tas.nc
# 168/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1281_016_tas.nc
# 169/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1281_017_tas.nc
# 170/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1281_018_tas.nc
# 171/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1281_019_tas.nc
# 172/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1281_020_tas.nc
# 173/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1301_001_tas.nc
# 174/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1301_002_tas.nc
# 175/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1301_003_tas.nc
# 176/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1301_004_tas.nc
# 177/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1301_005_tas.nc
# 178/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1301_006_tas.nc
# 179/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1301_007_tas.nc
# 180/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1301_008_tas.nc
# 181/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1301_009_tas.nc
# 182/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1301_010_tas.nc
# 183/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1301_011_tas.nc
# 184/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1301_012_tas.nc
# 185/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1301_013_tas.nc
# 186/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1301_014_tas.nc
# 187/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1301_015_tas.nc
# 188/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1301_016_tas.nc
# 189/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1301_017_tas.nc
# 190/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1301_018_tas.nc
# 191/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1301_019_tas.nc
# 192/193: Processing file: /climca/people/onennecke/not_debiased_data_future/CESM2_LE2-1301_020_tas.nc
# 193/193: Processing file: /climca/people/onennecke/not_debiased_data_future/ERA5_hist_tas.nc
# File not found: /climca/people/onennecke/not_debiased_data_future/ERA5_hist_tas.nc

# %%
# Save the datasets to NetCDF files
esm_ds_cur.to_netcdf(f'/climca/people/onennecke/model_output/var_means_masked/winter_data_condensed/{variable_name}_sp_mean_mask_ex_ws_cur.nc')
esm_ds_fut.to_netcdf(f'/climca/people/onennecke/model_output/var_means_masked/winter_data_condensed/{variable_name}_sp_mean_mask_ex_ws_fut.nc')

# %%
esm_ds_cur.ESM
# Out:
# <xarray.DataArray 'ESM' (ESM_run: 193)> Size: 10kB
# array(['ACCESS-CM2', 'ACCESS-CM2', 'ACCESS-CM2', 'BCC-CSM2-MR', 'CESM2',
#        'CESM2', 'CESM2', 'EC-Earth3', 'EC-Earth3', 'EC-Earth3',
#        'EC-Earth3', 'EC-Earth3', 'EC-Earth3', 'EC-Earth3', 'EC-Earth3',
#        'EC-Earth3', 'EC-Earth3', 'EC-Earth3', 'EC-Earth3', 'EC-Earth3',
#        'EC-Earth3', 'EC-Earth3', 'EC-Earth3', 'EC-Earth3', 'EC-Earth3',
#        'EC-Earth3', 'EC-Earth3', 'EC-Earth3', 'EC-Earth3', 'EC-Earth3',
#        'EC-Earth3', 'EC-Earth3', 'EC-Earth3', 'EC-Earth3', 'EC-Earth3',
#        'EC-Earth3', 'EC-Earth3', 'EC-Earth3', 'EC-Earth3', 'EC-Earth3',
#        'EC-Earth3', 'EC-Earth3', 'EC-Earth3', 'EC-Earth3', 'EC-Earth3',
#        'EC-Earth3', 'EC-Earth3', 'EC-Earth3', 'EC-Earth3', 'EC-Earth3',
#        'EC-Earth3', 'EC-Earth3', 'EC-Earth3', 'EC-Earth3', 'EC-Earth3',
#        'EC-Earth3', 'EC-Earth3', 'EC-Earth3', 'EC-Earth3', 'EC-Earth3',
#        'EC-Earth3', 'GFDL-ESM4', 'KACE-1-0-G', 'KACE-1-0-G', 'KACE-1-0-G',
#        'MPI-ESM1-2-HR', 'MPI-ESM1-2-HR', 'MPI-ESM1-2-HR', 'MPI-ESM1-2-HR',
#        'MPI-ESM1-2-HR', 'MPI-ESM1-2-HR', 'MPI-ESM1-2-HR', 'MPI-ESM1-2-HR',
#        'MPI-ESM1-2-HR', 'MPI-ESM1-2-HR', 'MRI-ESM2-0', 'MRI-ESM2-0',
#        'MRI-ESM2-0', 'MRI-ESM2-0', 'MRI-ESM2-0', 'TaiESM1', 'UKESM1-0-LL',
#        'UKESM1-0-LL', 'UKESM1-0-LL', 'UKESM1-0-LL', 'UKESM1-0-LL',
#        'UKESM1-0-LL', 'UKESM1-0-LL', 'UKESM1-0-LL', 'UKESM1-0-LL',
#        'UKESM1-0-LL', 'UKESM1-0-LL', 'CESM2', 'CESM2', 'CESM2', 'CESM2',
#        'CESM2', 'CESM2', 'CESM2', 'CESM2', 'CESM2', 'CESM2', 'CESM2',
#        'CESM2', 'CESM2', 'CESM2', 'CESM2', 'CESM2', 'CESM2', 'CESM2',
#        'CESM2', 'CESM2', 'CESM2', 'CESM2', 'CESM2', 'CESM2', 'CESM2',
#        'CESM2', 'CESM2', 'CESM2', 'CESM2', 'CESM2', 'CESM2', 'CESM2',
#        'CESM2', 'CESM2', 'CESM2', 'CESM2', 'CESM2', 'CESM2', 'CESM2',
#        'CESM2', 'CESM2', 'CESM2', 'CESM2', 'CESM2', 'CESM2', 'CESM2',
#        'CESM2', 'CESM2', 'CESM2', 'CESM2', 'CESM2', 'CESM2', 'CESM2',
#        'CESM2', 'CESM2', 'CESM2', 'CESM2', 'CESM2', 'CESM2', 'CESM2',
#        'CESM2', 'CESM2', 'CESM2', 'CESM2', 'CESM2', 'CESM2', 'CESM2',
#        'CESM2', 'CESM2', 'CESM2', 'CESM2', 'CESM2', 'CESM2', 'CESM2',
#        'CESM2', 'CESM2', 'CESM2', 'CESM2', 'CESM2', 'CESM2', 'CESM2',
#        'CESM2', 'CESM2', 'CESM2', 'CESM2', 'CESM2', 'CESM2', 'CESM2',
#        'CESM2', 'CESM2', 'CESM2', 'CESM2', 'CESM2', 'CESM2', 'CESM2',
#        'CESM2', 'CESM2', 'CESM2', 'CESM2', 'CESM2', 'ERA5'], dtype='<U13')
# Coordinates:
#     crs       int64 8B 4326
#     gridtype  <U6 24B 'lonlat'
#     ESM       (ESM_run) <U13 10kB 'ACCESS-CM2' 'ACCESS-CM2' ... 'CESM2' 'ERA5'
#     run       (ESM_run) <U12 9kB 'r4i1p1f1' 'r5i1p1f1' ... 'LE2-1301_020' 'hist'
#     country   float64 8B 9.0
#   * ESM_run   (ESM_run) <U23 18kB 'ACCESS-CM2_r4i1p1f1' ... 'ERA5_hist'

# %%
192*1820
# Out:
# 349440

# %%
esm_ds_fut
# Out:
# <xarray.Dataset> Size: 4MB
# Dimensions:   (ESM_run: 192, time: 4550)
# Coordinates:
#   * time      (time) datetime64[ns] 36kB 2030-01-01 2030-01-02 ... 2054-12-31
#   * ESM_run   (ESM_run) <U23 18kB 'ACCESS-CM2_r4i1p1f1' ... 'CESM2_LE_LE2-130...
#     crs       int64 8B 4326
#     gridtype  <U6 24B 'lonlat'
#     ESM       (ESM_run) <U13 10kB 'ACCESS-CM2' 'ACCESS-CM2' ... 'CESM2_LE'
#     run       (ESM_run) <U12 9kB 'r4i1p1f1' 'r5i1p1f1' ... 'LE2-1301_020'
#     country   float64 8B 9.0
# Data variables:
#     tas       (ESM_run, time) float32 3MB nan nan nan nan ... nan nan nan nan
# Attributes:
#     regrid_method:  bilinear

# %%
np.unique(esm_ds_cur.ESM.values)
# Out:
# array(['ACCESS-CM2', 'BCC-CSM2-MR', 'CESM2', 'CESM2_LE', 'EC-Earth3',
#        'GFDL-ESM4', 'KACE-1-0-G', 'MPI-ESM1-2-HR', 'MRI-ESM2-0',
#        'TaiESM1', 'UKESM1-0-LL'], dtype='<U13')

# %%
demand_fit_values = xr.open_dataset('/climca/people/onennecke/population_data/demand_fit_values_week.nc')
minT = demand_fit_values.sel(country = 9, period = 'week').load()['minT']
# In °C
print(minT.values)
minT = minT + 273.15
minT.values

print(f'Everything under {minT.values:.2f} K is doesnt really matter since the energy demand doesnt increase under that temperature')
# Out:
# -12.193476972330895
# Everything under 260.96 K is doesnt really matter since the energy demand doesnt increase under that temperature

# %%
esm_ds_cur
# Out:
# <xarray.Dataset> Size: 1MB
# Dimensions:   (ESM_run: 192, time: 1820)
# Coordinates:
#     crs       int64 8B 4326
#     gridtype  <U6 24B 'lonlat'
#   * time      (time) datetime64[ns] 15kB 2015-01-01 2015-01-02 ... 2024-12-31
#     ESM       (ESM_run) <U13 10kB 'ACCESS-CM2' 'ACCESS-CM2' ... 'CESM2_LE'
#     run       (ESM_run) <U12 9kB 'r4i1p1f1' 'r5i1p1f1' ... 'LE2-1301_020'
#     country   float64 8B 9.0
#   * ESM_run   (ESM_run) <U23 18kB 'ACCESS-CM2_r4i1p1f1' ... 'CESM2_LE_LE2-130...
# Data variables:
#     tas       (ESM_run, time) float32 1MB 276.0 278.1 276.6 ... 277.0 279.7
# Attributes:
#     regrid_method:  bilinear

# %%
esm_data_cur_dict = {}
esm_data_fut_dict = {}

esm_data_cur_dict['All ESMs'] = esm_ds_cur[variable_name].values.ravel()
esm_data_fut = esm_ds_fut[variable_name].values.ravel()
esm_data_fut = esm_data_fut[~np.isnan(esm_data_fut)]
esm_data_fut_dict['All ESMs'] = esm_data_fut

for esm in np.unique(esm_ds_cur.ESM.values):
    esm_data_cur = esm_ds_cur.where(esm_ds_cur.ESM == esm)[variable_name].values.ravel()
    esm_data_cur = esm_data_cur[~np.isnan(esm_data_cur)]
    esm_data_cur_dict[esm] = esm_data_cur
    esm_data_fut = esm_ds_fut.where(esm_ds_fut.ESM == esm)[variable_name].values.ravel()
    esm_data_fut = esm_data_fut[~np.isnan(esm_data_fut)]
    esm_data_fut_dict[esm] = esm_data_fut
    # break

# %%
esm_data_cur_dict.keys()

for key in esm_data_cur_dict.keys():
    print(f'{key}: {len(esm_data_cur_dict[key])} values')
    print(f'{key}: {len(esm_data_cur_dict[key]) / 1820} values')
# Out:
# All ESMs: 351260 values
# All ESMs: 193.0 values
# ACCESS-CM2: 5460 values
# ACCESS-CM2: 3.0 values
# BCC-CSM2-MR: 1820 values
# BCC-CSM2-MR: 1.0 values
# CESM2: 187460 values
# CESM2: 103.0 values
# EC-Earth3: 98280 values
# EC-Earth3: 54.0 values
# ERA5: 1820 values
# ERA5: 1.0 values
# GFDL-ESM4: 1820 values
# GFDL-ESM4: 1.0 values
# KACE-1-0-G: 5460 values
# KACE-1-0-G: 3.0 values
# MPI-ESM1-2-HR: 18200 values
# MPI-ESM1-2-HR: 10.0 values
# MRI-ESM2-0: 9100 values
# MRI-ESM2-0: 5.0 values
# TaiESM1: 1820 values
# TaiESM1: 1.0 values
# UKESM1-0-LL: 20020 values
# UKESM1-0-LL: 11.0 values

# %%
all_keys = list(esm_data_cur_dict.keys())

n = len(all_keys)

# %%
import numpy as np
import pandas as pd
from scipy.stats import ks_2samp

rows = []

for esm in all_keys:
    cur = esm_data_cur_dict[esm]
    fut = esm_data_fut_dict[esm]

    ks_stat, ks_p = ks_2samp(cur, fut)

    rows.append({
        'ESM': esm,
        'Current Mean': np.mean(cur),
        'Future Mean': np.mean(fut),
        'Delta Mean': np.mean(fut) - np.mean(cur),
        'Delta Mean (%)': (np.mean(fut) - np.mean(cur)) / np.mean(cur) * 100,
        'Current Std': np.std(cur),
        'Future Std': np.std(fut),
        'Delta Std': np.std(fut) - np.std(cur),
        'Delta Std (%)': (np.std(fut) - np.std(cur)) / np.std(cur) * 100,
        'KS Statistic': ks_stat,
        'KS p-value': ks_p,
        # 'Wasserstein': wasserstein_distance(cur, fut),
    })

# Convert to DataFrame for easy mean calculation
df = pd.DataFrame(rows)

# Filter out any existing 'All' or 'All_weighted' rows before calculating the weighted average
df_esm_only = df[~df['ESM'].isin(['All ESMs', 'All_weighted'])]

# Append the All_weighted row (only using ESM data)
# rows.append({
#     'ESM': 'All (weighted)',
#     'Current Mean': df_esm_only['Current Mean'].mean(),
#     'Future Mean': df_esm_only['Future Mean'].mean(),
#     'Delta Mean': df_esm_only['Future Mean'].mean() - df_esm_only['Current Mean'].mean(),
#     'Delta Mean (%)': (df_esm_only['Future Mean'].mean() - df_esm_only['Current Mean'].mean()) / df_esm_only['Current Mean'].mean() * 100,
#     'Current Std': df_esm_only['Current Std'].mean(),
#     'Future Std': df_esm_only['Future Std'].mean(),
#     'Delta Std': df_esm_only['Future Std'].mean() - df_esm_only['Current Std'].mean(),
#     'Delta Std (%)': (df_esm_only['Future Std'].mean() - df_esm_only['Current Std'].mean()) / df_esm_only['Current Std'].mean() * 100,
#     'KS Statistic': df_esm_only['KS Statistic'].mean(),
#     'KS p-value': df_esm_only['KS p-value'].mean(),
#     # 'Wasserstein': df_esm_only['Wasserstein'].mean(),
# })
summary_df = pd.DataFrame(rows)

# Change position of the All (weighted) row to the top
summary_df = pd.concat([summary_df[summary_df['ESM'] == 'All (weighted)'], summary_df[summary_df['ESM'] != 'All (weighted)']], ignore_index=True)


# Change the position of ERA5 to the top of the dataframe
summary_df = pd.concat([summary_df[summary_df['ESM'] == 'ERA5'], summary_df[summary_df['ESM'] != 'ERA5']], ignore_index=True)


print(summary_df)
# Out:
#               ESM  Current Mean  Future Mean  Delta Mean  Delta Mean (%)  \
# 0            ERA5      5.108118          NaN         NaN             NaN
# 1        All ESMs      5.336105     6.159636    0.823531       15.433189
# 2      ACCESS-CM2      3.652143     4.838500    1.186357       32.483856
# 3     BCC-CSM2-MR      4.574496     5.826786    1.252290       27.375481
# 4           CESM2      6.460583     7.199090    0.738508       11.430977
# 5       EC-Earth3      4.019309     4.958106    0.938797       23.357162
# 6       GFDL-ESM4      3.609792     4.375816    0.766024       21.220728
# 7      KACE-1-0-G      3.895496     5.185416    1.289920       33.113110
# 8   MPI-ESM1-2-HR      3.633708     4.510311    0.876602       24.124174
# 9      MRI-ESM2-0      5.752363     6.189728    0.437365        7.603224
# 10        TaiESM1      6.173880     7.367743    1.193864       19.337337
# 11    UKESM1-0-LL      3.652499     4.519285    0.866786       23.731316
#
#     Current Std  Future Std  Delta Std  Delta Std (%)  KS Statistic  \
# 0      4.201969         NaN        NaN            NaN           NaN
# 1      4.592158    4.505952  -0.086206      -1.877243      0.075254
# 2      4.233135    4.149608  -0.083527      -1.973173      0.111355
# 3      4.418561    4.317048  -0.101513      -2.297431      0.127473
# 4      4.139094    4.053497  -0.085597      -2.068014      0.073552
# 5      4.766663    4.704490  -0.062173      -1.304337      0.085246
# 6      4.568510    4.422585  -0.145925      -3.194139      0.098352
# 7      4.854356    4.837655  -0.016701      -0.344046      0.111905
# 8      4.628070    4.608038  -0.020031      -0.432825      0.073022
# 9      4.160415    4.226152   0.065737       1.580065      0.038242
# 10     4.052001    3.587193  -0.464808     -11.471068      0.125824
# 11     4.998349    5.021011   0.022662       0.453383      0.077073
#
#        KS p-value
# 0             NaN
# 1    0.000000e+00
# 2    6.905296e-30
# 3    2.666323e-13
# 4    0.000000e+00
# 5   4.025344e-311
# 6    4.416067e-08
# 7    3.524602e-30
# 8    1.213858e-42
# 9    3.313523e-06
# 10   5.722929e-13
# 11   3.660980e-52
# /tmp/ipykernel_1856164/1018923973.py:11: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   ks_stat, ks_p = ks_2samp(cur, fut)
# /home/onennecke/.conda/envs/env_ma_on/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:3904: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/onennecke/.conda/envs/env_ma_on/lib/python3.12/site-packages/numpy/_core/_methods.py:147: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /home/onennecke/.conda/envs/env_ma_on/lib/python3.12/site-packages/numpy/_core/_methods.py:227: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/onennecke/.conda/envs/env_ma_on/lib/python3.12/site-packages/numpy/_core/_methods.py:184: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/onennecke/.conda/envs/env_ma_on/lib/python3.12/site-packages/numpy/_core/_methods.py:219: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Patch

# --------------------------------------------------
# Data
# --------------------------------------------------
esms = summary_df['ESM'].values
delta_mean = summary_df['Delta Mean'].values
delta_std = summary_df['Delta Std'].values

n = len(esms)
x = np.arange(n)

current_data = [esm_data_cur_dict[k] for k in esms]
future_data = [esm_data_fut_dict[k] for k in esms]

# --------------------------------------------------
# Figure and axes
# Left axis  -> boxplots (actual variable values)
# Right axis -> percent changes (bars)
# --------------------------------------------------
fig, ax_box = plt.subplots(figsize=(16, 7))
ax_bar = ax_box.twinx()

# --------------------------------------------------
# Background bars (Δ Mean and Δ Std)
# --------------------------------------------------
bar_width = 0.35

ax_bar.bar(
    x - bar_width / 2,
    delta_mean,
    width=bar_width,
    color='tab:blue',
    alpha=0.30,
    label='Δ Mean',
    zorder=1
)

ax_bar.bar(
    x + bar_width / 2,
    delta_std,
    width=bar_width,
    color='tab:red',
    alpha=0.30,
    label='Δ Std',
    zorder=1
)

# --------------------------------------------------
# Boxplots on top
# --------------------------------------------------
offset = 0.12

current_pos = x - offset
future_pos = x + offset

bp1 = ax_box.boxplot(
    current_data,
    positions=current_pos,
    widths=0.18,
    patch_artist=True,
    manage_ticks=False,
    showfliers=True,
    zorder=3
)

bp2 = ax_box.boxplot(
    future_data,
    positions=future_pos,
    widths=0.18,
    patch_artist=True,
    manage_ticks=False,
    showfliers=True,
    zorder=3
)

# --------------------------------------------------
# Styling boxplots
# --------------------------------------------------
for box in bp1['boxes']:
    box.set(facecolor='white', edgecolor='black', alpha=0.9)

for box in bp2['boxes']:
    box.set(facecolor='lightgray', edgecolor='black', alpha=0.9)

# --------------------------------------------------
# Align zero lines on both axes
# --------------------------------------------------

# Boxplot axis limits from data
all_box_values = np.concatenate([
    np.concatenate(current_data),
    np.concatenate(future_data)
])

# box_abs = np.nanmax(np.abs(all_box_values))
# ax_box.set_ylim(-1.1 * box_abs, 1.1 * box_abs)

# # Bar axis limits from percentage changes
# bar_abs = max(
#     np.nanmax(np.abs(delta_mean)),
#     np.nanmax(np.abs(delta_std))
# )

# ax_bar.set_ylim(-1.1 * bar_abs, 1.1 * bar_abs)


box_bar_max = np.nanmax(np.concatenate([np.abs(all_box_values), np.abs(delta_mean), np.abs(delta_std)]))
box_bar_min = np.nanmin(np.concatenate([all_box_values, delta_mean, delta_std]))
ax_box.set_ylim(1.1 * box_bar_min, 1.1 * box_bar_max)
ax_bar.set_ylim(1.1 * box_bar_min, 1.1 * box_bar_max)

# Shared zero line
ax_box.axhline(0, color='black', linewidth=0.8, zorder=2)

# --------------------------------------------------
# Labels
# --------------------------------------------------
ax_box.set_ylabel(variable_name)
ax_bar.set_ylabel('Change')

ax_box.set_xticks(x)
ax_box.set_xticklabels(esms, rotation=45, ha='right')

# --------------------------------------------------
# Put boxplots visually above bars
# --------------------------------------------------
ax_box.set_zorder(2)
ax_bar.set_zorder(1)

ax_box.patch.set_alpha(0)

# --------------------------------------------------
# Legend
# --------------------------------------------------
legend_elements = [
    Patch(facecolor='tab:blue', alpha=0.30, label='Δ Mean'),
    Patch(facecolor='tab:red', alpha=0.30, label='Δ Std'),
    Patch(facecolor='white', edgecolor='black', label='Current'),
    Patch(facecolor='lightgray', edgecolor='black', label='Future')
]

ax_box.legend(handles=legend_elements, loc='upper right')

# --------------------------------------------------
# Title
# --------------------------------------------------
plt.title(
    f'{variable_name}: Current and Future Distributions with '
    'Change in Mean and Standard Deviation'
)

plt.tight_layout()
plt.show()

# %%
rows = []

for esm in all_keys:

    cur = esm_data_cur_dict[esm]
    fut = esm_data_fut_dict[esm]

    ks_stat, ks_p = ks_2samp(cur, fut)

    rows.append({
        'ESM': esm,
        'Current Mean': np.mean(cur),
        'Future Mean': np.mean(fut),
        'Delta Mean': np.mean(fut) - np.mean(cur),
        'Delta Mean (%)': (np.mean(fut) - np.mean(cur)) / np.mean(cur) * 100,
        'Current Std': np.std(cur),
        'Future Std': np.std(fut),
        'Delta Std': np.std(fut) - np.std(cur),
        'Delta Std (%)': (np.std(fut) - np.std(cur)) / np.std(cur) * 100,
        'KS Statistic': ks_stat,
        'KS p-value': ks_p,
        # 'Wasserstein': wasserstein_distance(cur, fut),
    })

summary_df = pd.DataFrame(rows)

print(summary_df)
# Out:
#   Cell In[18], line 29
#     'Delta Mean': rows['Future Mean'].mean() - rows['Current Mean'].mean(),,
#                                                                            ^
# SyntaxError: invalid syntax

# %%
# Assuming summary_df is already created
# Extract data
esms = summary_df['ESM']
delta_mean = summary_df['Delta Mean']
delta_std = summary_df['Delta Std']

max_pos = max(max(delta_mean), max(delta_std))
min_neg = min(min(delta_mean), min(delta_std))
y_limit = max(abs(max_pos), abs(min_neg)) * 1.1

# Create figure and primary axis
fig, ax1 = plt.subplots(figsize=(12, 6))

# Plot Delta Mean on primary axis
color_mean = 'tab:blue'
ax1.set_xlabel('ESM')
ax1.set_ylabel('Delta Mean', color=color_mean)
ax1.set_ylim(-y_limit, y_limit)
bars_mean = ax1.bar(esms, delta_mean, color=color_mean, width=-0.4, align='edge', alpha=0.7, label='Delta Mean')
ax1.tick_params(axis='y', labelcolor=color_mean)

# Create secondary axis for Delta Std
ax2 = ax1.twinx()
color_std = 'tab:red'
ax2.set_ylabel('Delta Std', color=color_std)
ax2.set_ylim(-y_limit, y_limit)
bars_std = ax2.bar(esms, delta_std, color=color_std, width=0.4,alpha=0.7, align='edge', label='Delta Std')
ax2.tick_params(axis='y', labelcolor=color_std)

# Add legend
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper right')

# Add title
plt.title('Change in Mean and Standard Deviation by ESM')

# Rotate x-axis labels for readability
ax1.set_xticklabels(esms, rotation=45)


# Adjust layout
plt.tight_layout()

# Show plot
plt.show()
# Out:
# /tmp/ipykernel_690967/3647851102.py:39: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(esms, rotation=45)

# %% [markdown]
# ## Huge plots

# %%
sns.set_style("whitegrid")



fig, axes = plt.subplots(
    nrows=n,
    ncols=2,
    figsize=(12, 4 * n),
    constrained_layout=True
)

# handle case n=1
if n == 1:
    axes = np.array([axes])

for i, esm in enumerate(all_keys):

    cur = esm_data_cur_dict[esm]
    fut = esm_data_fut_dict[esm]

    # -------------------------
    # KDE plot
    # -------------------------
    ax = axes[i, 0]

    sns.kdeplot(cur, ax=ax, label='Current', fill=True, alpha=0.4)
    sns.kdeplot(fut, ax=ax, label='Future', fill=True, alpha=0.4)
    ax.set_xlim(250, 300)
    # Draw vertical line at minT
    ax.axvline(minT.values, color='red', linestyle='--', label=f'mint={minT.values:.2f} K')

    # metrics
    ks_stat, ks_p = ks_2samp(cur, fut)
    # wass = wasserstein_distance(cur, fut)

    ax.set_title(
        f"{esm}\nKS={ks_stat:.3f}, p={ks_p:.2e}"
    )
    ax.set_xlabel(variable_name)
    ax.legend()

    # -------------------------
    # Boxplot
    # -------------------------
    ax2 = axes[i, 1]

    sns.boxplot(
        data=[cur, fut],
        ax=ax2
    )

    ax2.set_xticklabels(['Current', 'Future'])
    ax2.set_title(f"{esm} Boxplots")
    ax2.set_ylabel(variable_name)

plt.show()
# Out:
# /tmp/ipykernel_460409/572666098.py:54: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(['Current', 'Future'])
# /tmp/ipykernel_460409/572666098.py:54: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(['Current', 'Future'])
# /tmp/ipykernel_460409/572666098.py:54: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(['Current', 'Future'])
# /tmp/ipykernel_460409/572666098.py:54: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(['Current', 'Future'])
# /tmp/ipykernel_460409/572666098.py:54: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(['Current', 'Future'])
# /tmp/ipykernel_460409/572666098.py:54: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(['Current', 'Future'])
# /tmp/ipykernel_460409/572666098.py:54: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(['Current', 'Future'])
# /tmp/ipykernel_460409/572666098.py:54: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(['Current', 'Future'])
# /tmp/ipykernel_460409/572666098.py:54: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(['Current', 'Future'])
# /tmp/ipykernel_460409/572666098.py:54: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(['Current', 'Future'])
# /tmp/ipykernel_460409/572666098.py:54: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(['Current', 'Future'])
# /tmp/ipykernel_460409/572666098.py:54: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(['Current', 'Future'])

# %%
fig, axes = plt.subplots(
    nrows=len(all_keys),
    figsize=(7, 3 * len(all_keys)),
    constrained_layout=True
)

if len(all_keys) == 1:
    axes = [axes]

for ax, esm in zip(axes, all_keys):

    cur = esm_data_cur_dict[esm]
    fut = esm_data_fut_dict[esm]

    sns.violinplot(
        data=[cur, fut],
        ax=ax,
        inner='quartile'
    )
    # Draw a horizontal line at minT
    ax.axhline(minT.values, color='red', linestyle='--', label=f'mint={minT.values:.2f} K')

    ax.set_xticklabels(['Current', 'Future'])
    ax.set_title(esm)
    ax.set_ylabel(variable_name)

plt.show()
# Out:
# /tmp/ipykernel_460409/197334188.py:23: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(['Current', 'Future'])
# /tmp/ipykernel_460409/197334188.py:23: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(['Current', 'Future'])
# /tmp/ipykernel_460409/197334188.py:23: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(['Current', 'Future'])
# /tmp/ipykernel_460409/197334188.py:23: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(['Current', 'Future'])
# /tmp/ipykernel_460409/197334188.py:23: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(['Current', 'Future'])
# /tmp/ipykernel_460409/197334188.py:23: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(['Current', 'Future'])
# /tmp/ipykernel_460409/197334188.py:23: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(['Current', 'Future'])
# /tmp/ipykernel_460409/197334188.py:23: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(['Current', 'Future'])
# /tmp/ipykernel_460409/197334188.py:23: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(['Current', 'Future'])
# /tmp/ipykernel_460409/197334188.py:23: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(['Current', 'Future'])
# /tmp/ipykernel_460409/197334188.py:23: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(['Current', 'Future'])
# /tmp/ipykernel_460409/197334188.py:23: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(['Current', 'Future'])

# %%
fig, axes = plt.subplots(
    nrows=len(all_keys),
    figsize=(8, 3 * len(all_keys)),
    constrained_layout=True
)

if len(all_keys) == 1:
    axes = [axes]

for ax, esm in zip(axes, all_keys):

    cur = np.sort(esm_data_cur_dict[esm])
    fut = np.sort(esm_data_fut_dict[esm])

    ecdf_cur = np.arange(1, len(cur)+1) / len(cur)
    ecdf_fut = np.arange(1, len(fut)+1) / len(fut)

    ax.plot(cur, ecdf_cur, label='Current')
    ax.plot(fut, ecdf_fut, label='Future')

    # Draw vertical line at minT
    ax.axvline(minT.values, color='red', linestyle='--', label=f'mint={minT.values:.2f} K')

    ax.set_title(f"ECDF - {esm}")
    ax.set_xlabel(variable_name)
    ax.set_ylabel("F(x)")
    ax.legend()

plt.show()

# %%
quantiles = np.linspace(0.01, 0.99, 99)

fig, axes = plt.subplots(
    nrows=len(all_keys),
    figsize=(8, 3 * len(all_keys)),
    constrained_layout=True
)

if len(all_keys) == 1:
    axes = [axes]

for ax, esm in zip(axes, all_keys):

    cur_q = np.quantile(esm_data_cur_dict[esm], quantiles)
    fut_q = np.quantile(esm_data_fut_dict[esm], quantiles)

    delta = fut_q - cur_q

    ax.plot(quantiles, delta)

    ax.axhline(0, color='black', linestyle='--')

    ax.set_title(f"Quantile Change - {esm}")
    ax.set_xlabel("Quantile")
    ax.set_ylabel("Future - Current")

plt.show()
